# %% [markdown]
# # Best attack parameters given a hardware
#
# We assume the attack parameters are $n$ and $l$. Also, denote $g$ to be the number of ignored bits.
#
# $p = \frac{2^l}{2^n}$ , this is a geometric random variable, thus we expect a collision after   $\#queries = \frac{2^n}{2^l} $
#
# Assume, we only accept digests that have certain number of zeros, denoted as $d$. Thus, we can pretend as we are working on small digests
# $$
# \begin{align}
# &\#queries = \frac{2^n}{2^l} \\
# &\#queries_{sec} \cdot t_{sec} = \frac{2^n}{2^l}
# \end{align}
# $$
#
#
# We have three point of views of $\#queries$
# - Senders: How many hashes they generate?
#     - Their speed will be affected by difficulty, but from their perspective the overall attack time doesn't change if the difficulty change (add explanation, later)
#
#     - $\#snd\_queries_{sec} = \frac{\#senders \cdot \#gen\_hashes_{sec}} {2^{d}}$
#     - so, $\#queries_{sec} \cdot t_{sec} = \frac{2^n}{2^{l}}$
#
# - Receivers: How many hashes they can query the dicitonary.
#     - In their world, the higher the difficulty the better chance of hitting collision (since digests are technically shorter).
#     - $\#rcv\_queries_{sec} = \#receivers \cdot \#dict\_queries_{sec} $
#     - but $\#queries_{sec} \cdot t_{sec} = \frac{2^n}{2^{l+d}}$
#
# - Bandwith: This is how many hashes the network can carry in a second.
#     - From their perspective, difficulty reduces the rate of transmitted messages.
#     - $bdwth_queries_{sec} $
#
#
# Thus,
#
# $$\#queries_{sec} := min\left(snd\_queries_{sec}, rcv\_queries_{sec}, bdwth\_queries_{sec}\right)$$

# %%
# Numbers from Gros cluster, nancy, grid5000.fr
# find_dist overhead = 7%-9%
# hash_16x_avx (nancy: gros) ≈ 2^24.87hash/sec
# dict_add≈2^23.41 elm/sec
# dict_lookup ≈ 2^24.9337 elm/sec
# mpi_recv overhead = 10.71% (for regenerating message)


nservers = 32
server_memory = (196 - 20)*10^9 # 96 GB
ncores_per_server = 32
hashes_sec_core = 2^25.015134275003597
dict_queries_sec = 2^21.863350
t_sec =  2 * 24 * 3600
# how many hashes can oure compressed file 
hashes_sec_phase_i = 2^25 # 2^24.72
dict_add_sec = 2^23.41

# %%
# 1 core hashing power
# thd2 sha_avx512_16way  elapsed 1.78sec i.e. 898392.92 hashes/sec = 2^19.777 hashes, 57.4971 M


# Querying 100000000, took 2.22 sec i.e. 44977939.99 elm/sec = 2^25.4227 elm/sec 


def seconds_2_time(t):
    from math import floor
    t = float(t)
    days  = floor(t/(3600*24))
    t = t - days*24*3600
    hours = floor(t/3600)
    t = t - hours*3600
    minutes = floor(t/60)
    t = t - minutes*60

    return f"{days} days, {hours} hours, {minutes} mins, {floor(t)} sec"

print(f"server_memory={server_memory}")
# Out:
# server_memory=176000000000

# %%
def regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored):
    """ return number of seconds needed to regenerate the long message"""
    nsecs_sender = nhashes_stored / (nsenders*hashes_sec_core)
    nsecs_receiver = (nhashes_stored/(2**difficulty)) 
    nsecs_receiver = nsecs_receiver / (nreceivers*dict_add_sec)
#     print(f"nhashes=2^{log2(nhashes_stored)}")
#     print(f"nsecs_sender={nsecs_sender}")
#     print(f"nsecs_receiver={nsecs_receiver}")
    return max(nsecs_receiver, nsecs_sender)


def regen_msg_l(difficulty,
                nhashes_stored):
    """ return the max l can be constructed with difficulty """
    from math import log2
    
    return log2( (nhashes_stored/(2**difficulty)) )
    
def nqueries_sender(nsenders, hashes_sec_core, difficulty):
    """ Return how many queries senders can generate per second """

    return nsenders*hashes_sec_core/(2**difficulty)


def nqueries_receiver(nreceivers, dict_queries_sec):
    """
    Return how many queries receivers can make in a second
    """
    return nreceivers * dict_queries_sec

def phase_i_time(l, difficulty, hashes_sec_phase_i):
    """
    Return how many seconds it takes to complete phase_i
    """
    return 2^l * 2^difficulty / (hashes_sec_phase_i)


def nqueries_sender(nsenders, hashes_sec_core, difficulty):
    """ Return how many queries senders can generate per second """

    return nsenders*hashes_sec_core/(2**difficulty)


def nqueries_receiver(nreceivers, dict_queries_sec):
    """
    Return how many queries receivers can make in a second
    """
    return nreceivers * dict_queries_sec


def nqueries(n, # as number of bits
             nsenders,
             nreceivers,
             nhashes_stored,
             hashes_sec_core, 
             dict_queries_sec,
             difficulty):
    nqueries_sec =  min(nqueries_sender(nsenders, hashes_sec_core, difficulty),
                      nqueries_receiver(nreceivers, dict_queries_sec) )
    
    return 2**n / (nqueries_sec*nhashes_stored)

# %%
# regen_msg_time(1,
#                1,
#                hashes_sec_core,
#                dict_add_sec,
#                6,
#                2^29)
# seconds_2_time(phase_i_time(40, 0, hashes_sec_phase_i))

# %%
# phase_i time?
# phase_ii time?

# %%
print("Regenerating the long message will take ... ")
from math import log2
nservers = 4
ncores_per_server = 32
nhashes_stored = 2^36
n = 72
best_total_time = float('inf')
best_nsenders = 0
best_nreceivers = 0
best_diff = 0

for nreceivers in range(nservers, nservers*ncores_per_server - nservers, nservers):
    nsenders = (ncores_per_server)*nservers - nreceivers
    #nreceivers = 2*nservers
    for diff in range(10):

        time_rgen_msg = regen_msg_time(nsenders,
                                      nreceivers, # nsenders
                                      hashes_sec_core,
                                      dict_add_sec,
                                      diff, # difficulty
                                      nhashes_stored,
                                     ) # 25 our experimented interval, 4 because sha2-16way, log2(nsenders) that how  we truncate the #states 

        time_phase_i  = phase_i_time(log2(nhashes_stored), 0, hashes_sec_phase_i) # no need to account for difficulty
        time_phase_ii =  nqueries(n, nsenders, nreceivers, nhashes_stored,
                                  hashes_sec_core, dict_queries_sec, diff)
        total_time = time_phase_i+time_rgen_msg+time_phase_ii
        
        
        if total_time < best_total_time and diff < 8:
            best_total_time = total_time
            best_nsenders = nsenders
            best_nreceivers = nreceivers
            best_diff = diff
            
        print("-------------------------------------------------------------------------------------")
        print(f"difficulty={diff} => rgen_msg {round(time_rgen_msg)} sec, nreceivers={nreceivers}, nsenders={nsenders}")
        print(f"phase_i={round(time_phase_i)} sec, phase_ii={round(time_phase_ii)} sec")
        print(f"total time = {seconds_2_time(total_time)}")
        print(f"rgen_msg+phase_ii={seconds_2_time(time_rgen_msg+time_phase_ii)} sec")

    print("=============================================")
# Out:
# Regenerating the long message will take ...
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 1541 sec, nreceivers=4, nsenders=124
# phase_i=2048.0 sec, phase_ii=4503 sec
# total time = 0 days, 2 hours, 14 mins, 52 sec
# rgen_msg+phase_ii=0 days, 1 hours, 40 mins, 44 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 771 sec, nreceivers=4, nsenders=124
# phase_i=2048.0 sec, phase_ii=4503 sec
# total time = 0 days, 2 hours, 2 mins, 1 sec
# rgen_msg+phase_ii=0 days, 1 hours, 27 mins, 53 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 385 sec, nreceivers=4, nsenders=124
# phase_i=2048.0 sec, phase_ii=4503 sec
# total time = 0 days, 1 hours, 55 mins, 36 sec
# rgen_msg+phase_ii=0 days, 1 hours, 21 mins, 28 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 193 sec, nreceivers=4, nsenders=124
# phase_i=2048.0 sec, phase_ii=4503 sec
# total time = 0 days, 1 hours, 52 mins, 23 sec
# rgen_msg+phase_ii=0 days, 1 hours, 18 mins, 15 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 96 sec, nreceivers=4, nsenders=124
# phase_i=2048.0 sec, phase_ii=4503 sec
# total time = 0 days, 1 hours, 50 mins, 47 sec
# rgen_msg+phase_ii=0 days, 1 hours, 16 mins, 39 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 48 sec, nreceivers=4, nsenders=124
# phase_i=2048.0 sec, phase_ii=4503 sec
# total time = 0 days, 1 hours, 49 mins, 59 sec
# rgen_msg+phase_ii=0 days, 1 hours, 15 mins, 51 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 24 sec, nreceivers=4, nsenders=124
# phase_i=2048.0 sec, phase_ii=4503 sec
# total time = 0 days, 1 hours, 49 mins, 35 sec
# rgen_msg+phase_ii=0 days, 1 hours, 15 mins, 27 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 16 sec, nreceivers=4, nsenders=124
# phase_i=2048.0 sec, phase_ii=4503 sec
# total time = 0 days, 1 hours, 49 mins, 27 sec
# rgen_msg+phase_ii=0 days, 1 hours, 15 mins, 19 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 16 sec, nreceivers=4, nsenders=124
# phase_i=2048.0 sec, phase_ii=4503 sec
# total time = 0 days, 1 hours, 49 mins, 27 sec
# rgen_msg+phase_ii=0 days, 1 hours, 15 mins, 19 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 16 sec, nreceivers=4, nsenders=124
# phase_i=2048.0 sec, phase_ii=8368 sec
# total time = 0 days, 2 hours, 53 mins, 52 sec
# rgen_msg+phase_ii=0 days, 2 hours, 19 mins, 44 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 771 sec, nreceivers=8, nsenders=120
# phase_i=2048.0 sec, phase_ii=2251 sec
# total time = 0 days, 1 hours, 24 mins, 30 sec
# rgen_msg+phase_ii=0 days, 0 hours, 50 mins, 22 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 385 sec, nreceivers=8, nsenders=120
# phase_i=2048.0 sec, phase_ii=2251 sec
# total time = 0 days, 1 hours, 18 mins, 4 sec
# rgen_msg+phase_ii=0 days, 0 hours, 43 mins, 56 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 193 sec, nreceivers=8, nsenders=120
# phase_i=2048.0 sec, phase_ii=2251 sec
# total time = 0 days, 1 hours, 14 mins, 52 sec
# rgen_msg+phase_ii=0 days, 0 hours, 40 mins, 44 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 96 sec, nreceivers=8, nsenders=120
# phase_i=2048.0 sec, phase_ii=2251 sec
# total time = 0 days, 1 hours, 13 mins, 15 sec
# rgen_msg+phase_ii=0 days, 0 hours, 39 mins, 7 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 48 sec, nreceivers=8, nsenders=120
# phase_i=2048.0 sec, phase_ii=2251 sec
# total time = 0 days, 1 hours, 12 mins, 27 sec
# rgen_msg+phase_ii=0 days, 0 hours, 38 mins, 19 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 24 sec, nreceivers=8, nsenders=120
# phase_i=2048.0 sec, phase_ii=2251 sec
# total time = 0 days, 1 hours, 12 mins, 3 sec
# rgen_msg+phase_ii=0 days, 0 hours, 37 mins, 55 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 17 sec, nreceivers=8, nsenders=120
# phase_i=2048.0 sec, phase_ii=2251 sec
# total time = 0 days, 1 hours, 11 mins, 56 sec
# rgen_msg+phase_ii=0 days, 0 hours, 37 mins, 48 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 17 sec, nreceivers=8, nsenders=120
# phase_i=2048.0 sec, phase_ii=2251 sec
# total time = 0 days, 1 hours, 11 mins, 56 sec
# rgen_msg+phase_ii=0 days, 0 hours, 37 mins, 48 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 17 sec, nreceivers=8, nsenders=120
# phase_i=2048.0 sec, phase_ii=4323 sec
# total time = 0 days, 1 hours, 46 mins, 28 sec
# rgen_msg+phase_ii=0 days, 1 hours, 12 mins, 20 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 17 sec, nreceivers=8, nsenders=120
# phase_i=2048.0 sec, phase_ii=8647 sec
# total time = 0 days, 2 hours, 58 mins, 31 sec
# rgen_msg+phase_ii=0 days, 2 hours, 24 mins, 23 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 514 sec, nreceivers=12, nsenders=116
# phase_i=2048.0 sec, phase_ii=1501 sec
# total time = 0 days, 1 hours, 7 mins, 42 sec
# rgen_msg+phase_ii=0 days, 0 hours, 33 mins, 34 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 257 sec, nreceivers=12, nsenders=116
# phase_i=2048.0 sec, phase_ii=1501 sec
# total time = 0 days, 1 hours, 3 mins, 25 sec
# rgen_msg+phase_ii=0 days, 0 hours, 29 mins, 17 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 128 sec, nreceivers=12, nsenders=116
# phase_i=2048.0 sec, phase_ii=1501 sec
# total time = 0 days, 1 hours, 1 mins, 17 sec
# rgen_msg+phase_ii=0 days, 0 hours, 27 mins, 9 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 64 sec, nreceivers=12, nsenders=116
# phase_i=2048.0 sec, phase_ii=1501 sec
# total time = 0 days, 1 hours, 0 mins, 13 sec
# rgen_msg+phase_ii=0 days, 0 hours, 26 mins, 5 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 32 sec, nreceivers=12, nsenders=116
# phase_i=2048.0 sec, phase_ii=1501 sec
# total time = 0 days, 0 hours, 59 mins, 41 sec
# rgen_msg+phase_ii=0 days, 0 hours, 25 mins, 33 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 17 sec, nreceivers=12, nsenders=116
# phase_i=2048.0 sec, phase_ii=1501 sec
# total time = 0 days, 0 hours, 59 mins, 26 sec
# rgen_msg+phase_ii=0 days, 0 hours, 25 mins, 18 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 17 sec, nreceivers=12, nsenders=116
# phase_i=2048.0 sec, phase_ii=1501 sec
# total time = 0 days, 0 hours, 59 mins, 26 sec
# rgen_msg+phase_ii=0 days, 0 hours, 25 mins, 18 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 17 sec, nreceivers=12, nsenders=116
# phase_i=2048.0 sec, phase_ii=2236 sec
# total time = 0 days, 1 hours, 11 mins, 41 sec
# rgen_msg+phase_ii=0 days, 0 hours, 37 mins, 33 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 17 sec, nreceivers=12, nsenders=116
# phase_i=2048.0 sec, phase_ii=4473 sec
# total time = 0 days, 1 hours, 48 mins, 58 sec
# rgen_msg+phase_ii=0 days, 1 hours, 14 mins, 50 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 17 sec, nreceivers=12, nsenders=116
# phase_i=2048.0 sec, phase_ii=8945 sec
# total time = 0 days, 3 hours, 3 mins, 30 sec
# rgen_msg+phase_ii=0 days, 2 hours, 29 mins, 22 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 385 sec, nreceivers=16, nsenders=112
# phase_i=2048.0 sec, phase_ii=1126 sec
# total time = 0 days, 0 hours, 59 mins, 19 sec
# rgen_msg+phase_ii=0 days, 0 hours, 25 mins, 11 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 193 sec, nreceivers=16, nsenders=112
# phase_i=2048.0 sec, phase_ii=1126 sec
# total time = 0 days, 0 hours, 56 mins, 6 sec
# rgen_msg+phase_ii=0 days, 0 hours, 21 mins, 58 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 96 sec, nreceivers=16, nsenders=112
# phase_i=2048.0 sec, phase_ii=1126 sec
# total time = 0 days, 0 hours, 54 mins, 30 sec
# rgen_msg+phase_ii=0 days, 0 hours, 20 mins, 22 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 48 sec, nreceivers=16, nsenders=112
# phase_i=2048.0 sec, phase_ii=1126 sec
# total time = 0 days, 0 hours, 53 mins, 41 sec
# rgen_msg+phase_ii=0 days, 0 hours, 19 mins, 33 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 24 sec, nreceivers=16, nsenders=112
# phase_i=2048.0 sec, phase_ii=1126 sec
# total time = 0 days, 0 hours, 53 mins, 17 sec
# rgen_msg+phase_ii=0 days, 0 hours, 19 mins, 9 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 18 sec, nreceivers=16, nsenders=112
# phase_i=2048.0 sec, phase_ii=1126 sec
# total time = 0 days, 0 hours, 53 mins, 11 sec
# rgen_msg+phase_ii=0 days, 0 hours, 19 mins, 3 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 18 sec, nreceivers=16, nsenders=112
# phase_i=2048.0 sec, phase_ii=1158 sec
# total time = 0 days, 0 hours, 53 mins, 44 sec
# rgen_msg+phase_ii=0 days, 0 hours, 19 mins, 36 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 18 sec, nreceivers=16, nsenders=112
# phase_i=2048.0 sec, phase_ii=2316 sec
# total time = 0 days, 1 hours, 13 mins, 2 sec
# rgen_msg+phase_ii=0 days, 0 hours, 38 mins, 54 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 18 sec, nreceivers=16, nsenders=112
# phase_i=2048.0 sec, phase_ii=4632 sec
# total time = 0 days, 1 hours, 51 mins, 38 sec
# rgen_msg+phase_ii=0 days, 1 hours, 17 mins, 30 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 18 sec, nreceivers=16, nsenders=112
# phase_i=2048.0 sec, phase_ii=9265 sec
# total time = 0 days, 3 hours, 8 mins, 50 sec
# rgen_msg+phase_ii=0 days, 2 hours, 34 mins, 42 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 308 sec, nreceivers=20, nsenders=108
# phase_i=2048.0 sec, phase_ii=901 sec
# total time = 0 days, 0 hours, 54 mins, 16 sec
# rgen_msg+phase_ii=0 days, 0 hours, 20 mins, 8 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 154 sec, nreceivers=20, nsenders=108
# phase_i=2048.0 sec, phase_ii=901 sec
# total time = 0 days, 0 hours, 51 mins, 42 sec
# rgen_msg+phase_ii=0 days, 0 hours, 17 mins, 34 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 77 sec, nreceivers=20, nsenders=108
# phase_i=2048.0 sec, phase_ii=901 sec
# total time = 0 days, 0 hours, 50 mins, 25 sec
# rgen_msg+phase_ii=0 days, 0 hours, 16 mins, 17 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 39 sec, nreceivers=20, nsenders=108
# phase_i=2048.0 sec, phase_ii=901 sec
# total time = 0 days, 0 hours, 49 mins, 47 sec
# rgen_msg+phase_ii=0 days, 0 hours, 15 mins, 39 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 19 sec, nreceivers=20, nsenders=108
# phase_i=2048.0 sec, phase_ii=901 sec
# total time = 0 days, 0 hours, 49 mins, 27 sec
# rgen_msg+phase_ii=0 days, 0 hours, 15 mins, 19 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 19 sec, nreceivers=20, nsenders=108
# phase_i=2048.0 sec, phase_ii=901 sec
# total time = 0 days, 0 hours, 49 mins, 27 sec
# rgen_msg+phase_ii=0 days, 0 hours, 15 mins, 19 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 19 sec, nreceivers=20, nsenders=108
# phase_i=2048.0 sec, phase_ii=1201 sec
# total time = 0 days, 0 hours, 54 mins, 27 sec
# rgen_msg+phase_ii=0 days, 0 hours, 20 mins, 19 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 19 sec, nreceivers=20, nsenders=108
# phase_i=2048.0 sec, phase_ii=2402 sec
# total time = 0 days, 1 hours, 14 mins, 28 sec
# rgen_msg+phase_ii=0 days, 0 hours, 40 mins, 20 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 19 sec, nreceivers=20, nsenders=108
# phase_i=2048.0 sec, phase_ii=4804 sec
# total time = 0 days, 1 hours, 54 mins, 30 sec
# rgen_msg+phase_ii=0 days, 1 hours, 20 mins, 22 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 19 sec, nreceivers=20, nsenders=108
# phase_i=2048.0 sec, phase_ii=9608 sec
# total time = 0 days, 3 hours, 14 mins, 34 sec
# rgen_msg+phase_ii=0 days, 2 hours, 40 mins, 26 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 257 sec, nreceivers=24, nsenders=104
# phase_i=2048.0 sec, phase_ii=750 sec
# total time = 0 days, 0 hours, 50 mins, 55 sec
# rgen_msg+phase_ii=0 days, 0 hours, 16 mins, 47 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 128 sec, nreceivers=24, nsenders=104
# phase_i=2048.0 sec, phase_ii=750 sec
# total time = 0 days, 0 hours, 48 mins, 46 sec
# rgen_msg+phase_ii=0 days, 0 hours, 14 mins, 38 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 64 sec, nreceivers=24, nsenders=104
# phase_i=2048.0 sec, phase_ii=750 sec
# total time = 0 days, 0 hours, 47 mins, 42 sec
# rgen_msg+phase_ii=0 days, 0 hours, 13 mins, 34 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 32 sec, nreceivers=24, nsenders=104
# phase_i=2048.0 sec, phase_ii=750 sec
# total time = 0 days, 0 hours, 47 mins, 10 sec
# rgen_msg+phase_ii=0 days, 0 hours, 13 mins, 2 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 19 sec, nreceivers=24, nsenders=104
# phase_i=2048.0 sec, phase_ii=750 sec
# total time = 0 days, 0 hours, 46 mins, 57 sec
# rgen_msg+phase_ii=0 days, 0 hours, 12 mins, 49 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 19 sec, nreceivers=24, nsenders=104
# phase_i=2048.0 sec, phase_ii=750 sec
# total time = 0 days, 0 hours, 46 mins, 57 sec
# rgen_msg+phase_ii=0 days, 0 hours, 12 mins, 49 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 19 sec, nreceivers=24, nsenders=104
# phase_i=2048.0 sec, phase_ii=1247 sec
# total time = 0 days, 0 hours, 55 mins, 14 sec
# rgen_msg+phase_ii=0 days, 0 hours, 21 mins, 6 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 19 sec, nreceivers=24, nsenders=104
# phase_i=2048.0 sec, phase_ii=2494 sec
# total time = 0 days, 1 hours, 16 mins, 1 sec
# rgen_msg+phase_ii=0 days, 0 hours, 41 mins, 53 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 19 sec, nreceivers=24, nsenders=104
# phase_i=2048.0 sec, phase_ii=4989 sec
# total time = 0 days, 1 hours, 57 mins, 36 sec
# rgen_msg+phase_ii=0 days, 1 hours, 23 mins, 28 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 19 sec, nreceivers=24, nsenders=104
# phase_i=2048.0 sec, phase_ii=9977 sec
# total time = 0 days, 3 hours, 20 mins, 44 sec
# rgen_msg+phase_ii=0 days, 2 hours, 46 mins, 36 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 220 sec, nreceivers=28, nsenders=100
# phase_i=2048.0 sec, phase_ii=643 sec
# total time = 0 days, 0 hours, 48 mins, 31 sec
# rgen_msg+phase_ii=0 days, 0 hours, 14 mins, 23 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 110 sec, nreceivers=28, nsenders=100
# phase_i=2048.0 sec, phase_ii=643 sec
# total time = 0 days, 0 hours, 46 mins, 41 sec
# rgen_msg+phase_ii=0 days, 0 hours, 12 mins, 33 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 55 sec, nreceivers=28, nsenders=100
# phase_i=2048.0 sec, phase_ii=643 sec
# total time = 0 days, 0 hours, 45 mins, 46 sec
# rgen_msg+phase_ii=0 days, 0 hours, 11 mins, 38 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 28 sec, nreceivers=28, nsenders=100
# phase_i=2048.0 sec, phase_ii=643 sec
# total time = 0 days, 0 hours, 45 mins, 18 sec
# rgen_msg+phase_ii=0 days, 0 hours, 11 mins, 10 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 20 sec, nreceivers=28, nsenders=100
# phase_i=2048.0 sec, phase_ii=643 sec
# total time = 0 days, 0 hours, 45 mins, 11 sec
# rgen_msg+phase_ii=0 days, 0 hours, 11 mins, 3 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 20 sec, nreceivers=28, nsenders=100
# phase_i=2048.0 sec, phase_ii=649 sec
# total time = 0 days, 0 hours, 45 mins, 16 sec
# rgen_msg+phase_ii=0 days, 0 hours, 11 mins, 8 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 20 sec, nreceivers=28, nsenders=100
# phase_i=2048.0 sec, phase_ii=1297 sec
# total time = 0 days, 0 hours, 56 mins, 5 sec
# rgen_msg+phase_ii=0 days, 0 hours, 21 mins, 57 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 20 sec, nreceivers=28, nsenders=100
# phase_i=2048.0 sec, phase_ii=2594 sec
# total time = 0 days, 1 hours, 17 mins, 42 sec
# rgen_msg+phase_ii=0 days, 0 hours, 43 mins, 34 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 20 sec, nreceivers=28, nsenders=100
# phase_i=2048.0 sec, phase_ii=5188 sec
# total time = 0 days, 2 hours, 0 mins, 56 sec
# rgen_msg+phase_ii=0 days, 1 hours, 26 mins, 48 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 20 sec, nreceivers=28, nsenders=100
# phase_i=2048.0 sec, phase_ii=10376 sec
# total time = 0 days, 3 hours, 27 mins, 24 sec
# rgen_msg+phase_ii=0 days, 2 hours, 53 mins, 16 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 193 sec, nreceivers=32, nsenders=96
# phase_i=2048.0 sec, phase_ii=563 sec
# total time = 0 days, 0 hours, 46 mins, 43 sec
# rgen_msg+phase_ii=0 days, 0 hours, 12 mins, 35 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 96 sec, nreceivers=32, nsenders=96
# phase_i=2048.0 sec, phase_ii=563 sec
# total time = 0 days, 0 hours, 45 mins, 7 sec
# rgen_msg+phase_ii=0 days, 0 hours, 10 mins, 59 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 48 sec, nreceivers=32, nsenders=96
# phase_i=2048.0 sec, phase_ii=563 sec
# total time = 0 days, 0 hours, 44 mins, 19 sec
# rgen_msg+phase_ii=0 days, 0 hours, 10 mins, 11 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 24 sec, nreceivers=32, nsenders=96
# phase_i=2048.0 sec, phase_ii=563 sec
# total time = 0 days, 0 hours, 43 mins, 54 sec
# rgen_msg+phase_ii=0 days, 0 hours, 9 mins, 46 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 21 sec, nreceivers=32, nsenders=96
# phase_i=2048.0 sec, phase_ii=563 sec
# total time = 0 days, 0 hours, 43 mins, 51 sec
# rgen_msg+phase_ii=0 days, 0 hours, 9 mins, 43 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 21 sec, nreceivers=32, nsenders=96
# phase_i=2048.0 sec, phase_ii=676 sec
# total time = 0 days, 0 hours, 45 mins, 44 sec
# rgen_msg+phase_ii=0 days, 0 hours, 11 mins, 36 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 21 sec, nreceivers=32, nsenders=96
# phase_i=2048.0 sec, phase_ii=1351 sec
# total time = 0 days, 0 hours, 57 mins, 0 sec
# rgen_msg+phase_ii=0 days, 0 hours, 22 mins, 52 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 21 sec, nreceivers=32, nsenders=96
# phase_i=2048.0 sec, phase_ii=2702 sec
# total time = 0 days, 1 hours, 19 mins, 31 sec
# rgen_msg+phase_ii=0 days, 0 hours, 45 mins, 23 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 21 sec, nreceivers=32, nsenders=96
# phase_i=2048.0 sec, phase_ii=5404 sec
# total time = 0 days, 2 hours, 4 mins, 33 sec
# rgen_msg+phase_ii=0 days, 1 hours, 30 mins, 25 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 21 sec, nreceivers=32, nsenders=96
# phase_i=2048.0 sec, phase_ii=10809 sec
# total time = 0 days, 3 hours, 34 mins, 37 sec
# rgen_msg+phase_ii=0 days, 3 hours, 0 mins, 29 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 171 sec, nreceivers=36, nsenders=92
# phase_i=2048.0 sec, phase_ii=500 sec
# total time = 0 days, 0 hours, 45 mins, 19 sec
# rgen_msg+phase_ii=0 days, 0 hours, 11 mins, 11 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 86 sec, nreceivers=36, nsenders=92
# phase_i=2048.0 sec, phase_ii=500 sec
# total time = 0 days, 0 hours, 43 mins, 53 sec
# rgen_msg+phase_ii=0 days, 0 hours, 9 mins, 45 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 43 sec, nreceivers=36, nsenders=92
# phase_i=2048.0 sec, phase_ii=500 sec
# total time = 0 days, 0 hours, 43 mins, 11 sec
# rgen_msg+phase_ii=0 days, 0 hours, 9 mins, 3 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 22 sec, nreceivers=36, nsenders=92
# phase_i=2048.0 sec, phase_ii=500 sec
# total time = 0 days, 0 hours, 42 mins, 50 sec
# rgen_msg+phase_ii=0 days, 0 hours, 8 mins, 42 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 22 sec, nreceivers=36, nsenders=92
# phase_i=2048.0 sec, phase_ii=500 sec
# total time = 0 days, 0 hours, 42 mins, 50 sec
# rgen_msg+phase_ii=0 days, 0 hours, 8 mins, 42 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 22 sec, nreceivers=36, nsenders=92
# phase_i=2048.0 sec, phase_ii=705 sec
# total time = 0 days, 0 hours, 46 mins, 14 sec
# rgen_msg+phase_ii=0 days, 0 hours, 12 mins, 6 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 22 sec, nreceivers=36, nsenders=92
# phase_i=2048.0 sec, phase_ii=1410 sec
# total time = 0 days, 0 hours, 57 mins, 59 sec
# rgen_msg+phase_ii=0 days, 0 hours, 23 mins, 51 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 22 sec, nreceivers=36, nsenders=92
# phase_i=2048.0 sec, phase_ii=2820 sec
# total time = 0 days, 1 hours, 21 mins, 29 sec
# rgen_msg+phase_ii=0 days, 0 hours, 47 mins, 21 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 22 sec, nreceivers=36, nsenders=92
# phase_i=2048.0 sec, phase_ii=5639 sec
# total time = 0 days, 2 hours, 8 mins, 29 sec
# rgen_msg+phase_ii=0 days, 1 hours, 34 mins, 21 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 22 sec, nreceivers=36, nsenders=92
# phase_i=2048.0 sec, phase_ii=11279 sec
# total time = 0 days, 3 hours, 42 mins, 28 sec
# rgen_msg+phase_ii=0 days, 3 hours, 8 mins, 20 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 154 sec, nreceivers=40, nsenders=88
# phase_i=2048.0 sec, phase_ii=450 sec
# total time = 0 days, 0 hours, 44 mins, 12 sec
# rgen_msg+phase_ii=0 days, 0 hours, 10 mins, 4 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 77 sec, nreceivers=40, nsenders=88
# phase_i=2048.0 sec, phase_ii=450 sec
# total time = 0 days, 0 hours, 42 mins, 55 sec
# rgen_msg+phase_ii=0 days, 0 hours, 8 mins, 47 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 39 sec, nreceivers=40, nsenders=88
# phase_i=2048.0 sec, phase_ii=450 sec
# total time = 0 days, 0 hours, 42 mins, 16 sec
# rgen_msg+phase_ii=0 days, 0 hours, 8 mins, 8 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 23 sec, nreceivers=40, nsenders=88
# phase_i=2048.0 sec, phase_ii=450 sec
# total time = 0 days, 0 hours, 42 mins, 1 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 53 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 23 sec, nreceivers=40, nsenders=88
# phase_i=2048.0 sec, phase_ii=450 sec
# total time = 0 days, 0 hours, 42 mins, 1 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 53 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 23 sec, nreceivers=40, nsenders=88
# phase_i=2048.0 sec, phase_ii=737 sec
# total time = 0 days, 0 hours, 46 mins, 47 sec
# rgen_msg+phase_ii=0 days, 0 hours, 12 mins, 39 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 23 sec, nreceivers=40, nsenders=88
# phase_i=2048.0 sec, phase_ii=1474 sec
# total time = 0 days, 0 hours, 59 mins, 4 sec
# rgen_msg+phase_ii=0 days, 0 hours, 24 mins, 56 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 23 sec, nreceivers=40, nsenders=88
# phase_i=2048.0 sec, phase_ii=2948 sec
# total time = 0 days, 1 hours, 23 mins, 38 sec
# rgen_msg+phase_ii=0 days, 0 hours, 49 mins, 30 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 23 sec, nreceivers=40, nsenders=88
# phase_i=2048.0 sec, phase_ii=5896 sec
# total time = 0 days, 2 hours, 12 mins, 46 sec
# rgen_msg+phase_ii=0 days, 1 hours, 38 mins, 38 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 23 sec, nreceivers=40, nsenders=88
# phase_i=2048.0 sec, phase_ii=11791 sec
# total time = 0 days, 3 hours, 51 mins, 2 sec
# rgen_msg+phase_ii=0 days, 3 hours, 16 mins, 54 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 140 sec, nreceivers=44, nsenders=84
# phase_i=2048.0 sec, phase_ii=409 sec
# total time = 0 days, 0 hours, 43 mins, 17 sec
# rgen_msg+phase_ii=0 days, 0 hours, 9 mins, 9 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 70 sec, nreceivers=44, nsenders=84
# phase_i=2048.0 sec, phase_ii=409 sec
# total time = 0 days, 0 hours, 42 mins, 7 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 59 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 35 sec, nreceivers=44, nsenders=84
# phase_i=2048.0 sec, phase_ii=409 sec
# total time = 0 days, 0 hours, 41 mins, 32 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 24 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 24 sec, nreceivers=44, nsenders=84
# phase_i=2048.0 sec, phase_ii=409 sec
# total time = 0 days, 0 hours, 41 mins, 21 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 13 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 24 sec, nreceivers=44, nsenders=84
# phase_i=2048.0 sec, phase_ii=409 sec
# total time = 0 days, 0 hours, 41 mins, 21 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 13 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 24 sec, nreceivers=44, nsenders=84
# phase_i=2048.0 sec, phase_ii=772 sec
# total time = 0 days, 0 hours, 47 mins, 24 sec
# rgen_msg+phase_ii=0 days, 0 hours, 13 mins, 16 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 24 sec, nreceivers=44, nsenders=84
# phase_i=2048.0 sec, phase_ii=1544 sec
# total time = 0 days, 1 hours, 0 mins, 16 sec
# rgen_msg+phase_ii=0 days, 0 hours, 26 mins, 8 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 24 sec, nreceivers=44, nsenders=84
# phase_i=2048.0 sec, phase_ii=3088 sec
# total time = 0 days, 1 hours, 26 mins, 0 sec
# rgen_msg+phase_ii=0 days, 0 hours, 51 mins, 52 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 24 sec, nreceivers=44, nsenders=84
# phase_i=2048.0 sec, phase_ii=6176 sec
# total time = 0 days, 2 hours, 17 mins, 28 sec
# rgen_msg+phase_ii=0 days, 1 hours, 43 mins, 20 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 24 sec, nreceivers=44, nsenders=84
# phase_i=2048.0 sec, phase_ii=12353 sec
# total time = 0 days, 4 hours, 0 mins, 24 sec
# rgen_msg+phase_ii=0 days, 3 hours, 26 mins, 16 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 128 sec, nreceivers=48, nsenders=80
# phase_i=2048.0 sec, phase_ii=375 sec
# total time = 0 days, 0 hours, 42 mins, 31 sec
# rgen_msg+phase_ii=0 days, 0 hours, 8 mins, 23 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 64 sec, nreceivers=48, nsenders=80
# phase_i=2048.0 sec, phase_ii=375 sec
# total time = 0 days, 0 hours, 41 mins, 27 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 19 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 32 sec, nreceivers=48, nsenders=80
# phase_i=2048.0 sec, phase_ii=375 sec
# total time = 0 days, 0 hours, 40 mins, 55 sec
# rgen_msg+phase_ii=0 days, 0 hours, 6 mins, 47 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 25 sec, nreceivers=48, nsenders=80
# phase_i=2048.0 sec, phase_ii=375 sec
# total time = 0 days, 0 hours, 40 mins, 48 sec
# rgen_msg+phase_ii=0 days, 0 hours, 6 mins, 40 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 25 sec, nreceivers=48, nsenders=80
# phase_i=2048.0 sec, phase_ii=405 sec
# total time = 0 days, 0 hours, 41 mins, 18 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 10 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 25 sec, nreceivers=48, nsenders=80
# phase_i=2048.0 sec, phase_ii=811 sec
# total time = 0 days, 0 hours, 48 mins, 3 sec
# rgen_msg+phase_ii=0 days, 0 hours, 13 mins, 55 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 25 sec, nreceivers=48, nsenders=80
# phase_i=2048.0 sec, phase_ii=1621 sec
# total time = 0 days, 1 hours, 1 mins, 34 sec
# rgen_msg+phase_ii=0 days, 0 hours, 27 mins, 26 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 25 sec, nreceivers=48, nsenders=80
# phase_i=2048.0 sec, phase_ii=3243 sec
# total time = 0 days, 1 hours, 28 mins, 35 sec
# rgen_msg+phase_ii=0 days, 0 hours, 54 mins, 27 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 25 sec, nreceivers=48, nsenders=80
# phase_i=2048.0 sec, phase_ii=6485 sec
# total time = 0 days, 2 hours, 22 mins, 38 sec
# rgen_msg+phase_ii=0 days, 1 hours, 48 mins, 30 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 25 sec, nreceivers=48, nsenders=80
# phase_i=2048.0 sec, phase_ii=12970 sec
# total time = 0 days, 4 hours, 10 mins, 43 sec
# rgen_msg+phase_ii=0 days, 3 hours, 36 mins, 35 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 119 sec, nreceivers=52, nsenders=76
# phase_i=2048.0 sec, phase_ii=346 sec
# total time = 0 days, 0 hours, 41 mins, 52 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 44 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 59 sec, nreceivers=52, nsenders=76
# phase_i=2048.0 sec, phase_ii=346 sec
# total time = 0 days, 0 hours, 40 mins, 53 sec
# rgen_msg+phase_ii=0 days, 0 hours, 6 mins, 45 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 30 sec, nreceivers=52, nsenders=76
# phase_i=2048.0 sec, phase_ii=346 sec
# total time = 0 days, 0 hours, 40 mins, 24 sec
# rgen_msg+phase_ii=0 days, 0 hours, 6 mins, 16 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 27 sec, nreceivers=52, nsenders=76
# phase_i=2048.0 sec, phase_ii=346 sec
# total time = 0 days, 0 hours, 40 mins, 21 sec
# rgen_msg+phase_ii=0 days, 0 hours, 6 mins, 13 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 27 sec, nreceivers=52, nsenders=76
# phase_i=2048.0 sec, phase_ii=427 sec
# total time = 0 days, 0 hours, 41 mins, 41 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 33 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 27 sec, nreceivers=52, nsenders=76
# phase_i=2048.0 sec, phase_ii=853 sec
# total time = 0 days, 0 hours, 48 mins, 47 sec
# rgen_msg+phase_ii=0 days, 0 hours, 14 mins, 39 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 27 sec, nreceivers=52, nsenders=76
# phase_i=2048.0 sec, phase_ii=1707 sec
# total time = 0 days, 1 hours, 3 mins, 1 sec
# rgen_msg+phase_ii=0 days, 0 hours, 28 mins, 53 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 27 sec, nreceivers=52, nsenders=76
# phase_i=2048.0 sec, phase_ii=3413 sec
# total time = 0 days, 1 hours, 31 mins, 27 sec
# rgen_msg+phase_ii=0 days, 0 hours, 57 mins, 19 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 27 sec, nreceivers=52, nsenders=76
# phase_i=2048.0 sec, phase_ii=6827 sec
# total time = 0 days, 2 hours, 28 mins, 21 sec
# rgen_msg+phase_ii=0 days, 1 hours, 54 mins, 13 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 27 sec, nreceivers=52, nsenders=76
# phase_i=2048.0 sec, phase_ii=13653 sec
# total time = 0 days, 4 hours, 22 mins, 7 sec
# rgen_msg+phase_ii=0 days, 3 hours, 47 mins, 59 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 110 sec, nreceivers=56, nsenders=72
# phase_i=2048.0 sec, phase_ii=322 sec
# total time = 0 days, 0 hours, 41 mins, 19 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 11 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 55 sec, nreceivers=56, nsenders=72
# phase_i=2048.0 sec, phase_ii=322 sec
# total time = 0 days, 0 hours, 40 mins, 24 sec
# rgen_msg+phase_ii=0 days, 0 hours, 6 mins, 16 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 28 sec, nreceivers=56, nsenders=72
# phase_i=2048.0 sec, phase_ii=322 sec
# total time = 0 days, 0 hours, 39 mins, 57 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 49 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 28 sec, nreceivers=56, nsenders=72
# phase_i=2048.0 sec, phase_ii=322 sec
# total time = 0 days, 0 hours, 39 mins, 57 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 49 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 28 sec, nreceivers=56, nsenders=72
# phase_i=2048.0 sec, phase_ii=450 sec
# total time = 0 days, 0 hours, 42 mins, 6 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 58 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 28 sec, nreceivers=56, nsenders=72
# phase_i=2048.0 sec, phase_ii=901 sec
# total time = 0 days, 0 hours, 49 mins, 36 sec
# rgen_msg+phase_ii=0 days, 0 hours, 15 mins, 28 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 28 sec, nreceivers=56, nsenders=72
# phase_i=2048.0 sec, phase_ii=1801 sec
# total time = 0 days, 1 hours, 4 mins, 37 sec
# rgen_msg+phase_ii=0 days, 0 hours, 30 mins, 29 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 28 sec, nreceivers=56, nsenders=72
# phase_i=2048.0 sec, phase_ii=3603 sec
# total time = 0 days, 1 hours, 34 mins, 39 sec
# rgen_msg+phase_ii=0 days, 1 hours, 0 mins, 31 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 28 sec, nreceivers=56, nsenders=72
# phase_i=2048.0 sec, phase_ii=7206 sec
# total time = 0 days, 2 hours, 34 mins, 41 sec
# rgen_msg+phase_ii=0 days, 2 hours, 0 mins, 33 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 28 sec, nreceivers=56, nsenders=72
# phase_i=2048.0 sec, phase_ii=14412 sec
# total time = 0 days, 4 hours, 34 mins, 47 sec
# rgen_msg+phase_ii=0 days, 4 hours, 0 mins, 39 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 103 sec, nreceivers=60, nsenders=68
# phase_i=2048.0 sec, phase_ii=300 sec
# total time = 0 days, 0 hours, 40 mins, 50 sec
# rgen_msg+phase_ii=0 days, 0 hours, 6 mins, 42 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 51 sec, nreceivers=60, nsenders=68
# phase_i=2048.0 sec, phase_ii=300 sec
# total time = 0 days, 0 hours, 39 mins, 59 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 51 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 30 sec, nreceivers=60, nsenders=68
# phase_i=2048.0 sec, phase_ii=300 sec
# total time = 0 days, 0 hours, 39 mins, 37 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 29 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 30 sec, nreceivers=60, nsenders=68
# phase_i=2048.0 sec, phase_ii=300 sec
# total time = 0 days, 0 hours, 39 mins, 37 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 29 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 30 sec, nreceivers=60, nsenders=68
# phase_i=2048.0 sec, phase_ii=477 sec
# total time = 0 days, 0 hours, 42 mins, 34 sec
# rgen_msg+phase_ii=0 days, 0 hours, 8 mins, 26 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 30 sec, nreceivers=60, nsenders=68
# phase_i=2048.0 sec, phase_ii=954 sec
# total time = 0 days, 0 hours, 50 mins, 31 sec
# rgen_msg+phase_ii=0 days, 0 hours, 16 mins, 23 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 30 sec, nreceivers=60, nsenders=68
# phase_i=2048.0 sec, phase_ii=1907 sec
# total time = 0 days, 1 hours, 6 mins, 25 sec
# rgen_msg+phase_ii=0 days, 0 hours, 32 mins, 17 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 30 sec, nreceivers=60, nsenders=68
# phase_i=2048.0 sec, phase_ii=3815 sec
# total time = 0 days, 1 hours, 38 mins, 12 sec
# rgen_msg+phase_ii=0 days, 1 hours, 4 mins, 4 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 30 sec, nreceivers=60, nsenders=68
# phase_i=2048.0 sec, phase_ii=7630 sec
# total time = 0 days, 2 hours, 41 mins, 47 sec
# rgen_msg+phase_ii=0 days, 2 hours, 7 mins, 39 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 30 sec, nreceivers=60, nsenders=68
# phase_i=2048.0 sec, phase_ii=15259 sec
# total time = 0 days, 4 hours, 48 mins, 57 sec
# rgen_msg+phase_ii=0 days, 4 hours, 14 mins, 49 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 96 sec, nreceivers=64, nsenders=64
# phase_i=2048.0 sec, phase_ii=281 sec
# total time = 0 days, 0 hours, 40 mins, 25 sec
# rgen_msg+phase_ii=0 days, 0 hours, 6 mins, 17 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 48 sec, nreceivers=64, nsenders=64
# phase_i=2048.0 sec, phase_ii=281 sec
# total time = 0 days, 0 hours, 39 mins, 37 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 29 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 32 sec, nreceivers=64, nsenders=64
# phase_i=2048.0 sec, phase_ii=281 sec
# total time = 0 days, 0 hours, 39 mins, 21 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 13 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 32 sec, nreceivers=64, nsenders=64
# phase_i=2048.0 sec, phase_ii=281 sec
# total time = 0 days, 0 hours, 39 mins, 21 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 13 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 32 sec, nreceivers=64, nsenders=64
# phase_i=2048.0 sec, phase_ii=507 sec
# total time = 0 days, 0 hours, 43 mins, 6 sec
# rgen_msg+phase_ii=0 days, 0 hours, 8 mins, 58 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 32 sec, nreceivers=64, nsenders=64
# phase_i=2048.0 sec, phase_ii=1013 sec
# total time = 0 days, 0 hours, 51 mins, 32 sec
# rgen_msg+phase_ii=0 days, 0 hours, 17 mins, 24 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 32 sec, nreceivers=64, nsenders=64
# phase_i=2048.0 sec, phase_ii=2027 sec
# total time = 0 days, 1 hours, 8 mins, 26 sec
# rgen_msg+phase_ii=0 days, 0 hours, 34 mins, 18 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 32 sec, nreceivers=64, nsenders=64
# phase_i=2048.0 sec, phase_ii=4053 sec
# total time = 0 days, 1 hours, 42 mins, 12 sec
# rgen_msg+phase_ii=0 days, 1 hours, 8 mins, 4 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 32 sec, nreceivers=64, nsenders=64
# phase_i=2048.0 sec, phase_ii=8107 sec
# total time = 0 days, 2 hours, 49 mins, 46 sec
# rgen_msg+phase_ii=0 days, 2 hours, 15 mins, 38 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 32 sec, nreceivers=64, nsenders=64
# phase_i=2048.0 sec, phase_ii=16213 sec
# total time = 0 days, 5 hours, 4 mins, 52 sec
# rgen_msg+phase_ii=0 days, 4 hours, 30 mins, 44 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 91 sec, nreceivers=68, nsenders=60
# phase_i=2048.0 sec, phase_ii=265 sec
# total time = 0 days, 0 hours, 40 mins, 3 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 55 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 45 sec, nreceivers=68, nsenders=60
# phase_i=2048.0 sec, phase_ii=265 sec
# total time = 0 days, 0 hours, 39 mins, 18 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 10 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 34 sec, nreceivers=68, nsenders=60
# phase_i=2048.0 sec, phase_ii=265 sec
# total time = 0 days, 0 hours, 39 mins, 6 sec
# rgen_msg+phase_ii=0 days, 0 hours, 4 mins, 58 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 34 sec, nreceivers=68, nsenders=60
# phase_i=2048.0 sec, phase_ii=270 sec
# total time = 0 days, 0 hours, 39 mins, 11 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 3 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 34 sec, nreceivers=68, nsenders=60
# phase_i=2048.0 sec, phase_ii=540 sec
# total time = 0 days, 0 hours, 43 mins, 42 sec
# rgen_msg+phase_ii=0 days, 0 hours, 9 mins, 34 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 34 sec, nreceivers=68, nsenders=60
# phase_i=2048.0 sec, phase_ii=1081 sec
# total time = 0 days, 0 hours, 52 mins, 42 sec
# rgen_msg+phase_ii=0 days, 0 hours, 18 mins, 34 sec sec
# ...
# difficulty=5 => rgen_msg 72 sec, nreceivers=100, nsenders=28
# phase_i=2048.0 sec, phase_ii=2316 sec
# total time = 0 days, 1 hours, 13 mins, 56 sec
# rgen_msg+phase_ii=0 days, 0 hours, 39 mins, 48 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 72 sec, nreceivers=100, nsenders=28
# phase_i=2048.0 sec, phase_ii=4632 sec
# total time = 0 days, 1 hours, 52 mins, 32 sec
# rgen_msg+phase_ii=0 days, 1 hours, 18 mins, 24 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 72 sec, nreceivers=100, nsenders=28
# phase_i=2048.0 sec, phase_ii=9265 sec
# total time = 0 days, 3 hours, 9 mins, 44 sec
# rgen_msg+phase_ii=0 days, 2 hours, 35 mins, 36 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 72 sec, nreceivers=100, nsenders=28
# phase_i=2048.0 sec, phase_ii=18529 sec
# total time = 0 days, 5 hours, 44 mins, 9 sec
# rgen_msg+phase_ii=0 days, 5 hours, 10 mins, 1 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 72 sec, nreceivers=100, nsenders=28
# phase_i=2048.0 sec, phase_ii=37058 sec
# total time = 0 days, 10 hours, 52 mins, 58 sec
# rgen_msg+phase_ii=0 days, 10 hours, 18 mins, 50 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 84 sec, nreceivers=104, nsenders=24
# phase_i=2048.0 sec, phase_ii=173 sec
# total time = 0 days, 0 hours, 38 mins, 25 sec
# rgen_msg+phase_ii=0 days, 0 hours, 4 mins, 17 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 84 sec, nreceivers=104, nsenders=24
# phase_i=2048.0 sec, phase_ii=173 sec
# total time = 0 days, 0 hours, 38 mins, 25 sec
# rgen_msg+phase_ii=0 days, 0 hours, 4 mins, 17 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 84 sec, nreceivers=104, nsenders=24
# phase_i=2048.0 sec, phase_ii=338 sec
# total time = 0 days, 0 hours, 41 mins, 10 sec
# rgen_msg+phase_ii=0 days, 0 hours, 7 mins, 2 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 84 sec, nreceivers=104, nsenders=24
# phase_i=2048.0 sec, phase_ii=676 sec
# total time = 0 days, 0 hours, 46 mins, 47 sec
# rgen_msg+phase_ii=0 days, 0 hours, 12 mins, 39 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 84 sec, nreceivers=104, nsenders=24
# phase_i=2048.0 sec, phase_ii=1351 sec
# total time = 0 days, 0 hours, 58 mins, 3 sec
# rgen_msg+phase_ii=0 days, 0 hours, 23 mins, 55 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 84 sec, nreceivers=104, nsenders=24
# phase_i=2048.0 sec, phase_ii=2702 sec
# total time = 0 days, 1 hours, 20 mins, 34 sec
# rgen_msg+phase_ii=0 days, 0 hours, 46 mins, 26 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 84 sec, nreceivers=104, nsenders=24
# phase_i=2048.0 sec, phase_ii=5404 sec
# total time = 0 days, 2 hours, 5 mins, 36 sec
# rgen_msg+phase_ii=0 days, 1 hours, 31 mins, 28 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 84 sec, nreceivers=104, nsenders=24
# phase_i=2048.0 sec, phase_ii=10809 sec
# total time = 0 days, 3 hours, 35 mins, 41 sec
# rgen_msg+phase_ii=0 days, 3 hours, 1 mins, 33 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 84 sec, nreceivers=104, nsenders=24
# phase_i=2048.0 sec, phase_ii=21617 sec
# total time = 0 days, 6 hours, 35 mins, 49 sec
# rgen_msg+phase_ii=0 days, 6 hours, 1 mins, 41 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 84 sec, nreceivers=104, nsenders=24
# phase_i=2048.0 sec, phase_ii=43235 sec
# total time = 0 days, 12 hours, 36 mins, 7 sec
# rgen_msg+phase_ii=0 days, 12 hours, 1 mins, 59 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 101 sec, nreceivers=108, nsenders=20
# phase_i=2048.0 sec, phase_ii=167 sec
# total time = 0 days, 0 hours, 38 mins, 36 sec
# rgen_msg+phase_ii=0 days, 0 hours, 4 mins, 28 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 101 sec, nreceivers=108, nsenders=20
# phase_i=2048.0 sec, phase_ii=203 sec
# total time = 0 days, 0 hours, 39 mins, 11 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 3 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 101 sec, nreceivers=108, nsenders=20
# phase_i=2048.0 sec, phase_ii=405 sec
# total time = 0 days, 0 hours, 42 mins, 34 sec
# rgen_msg+phase_ii=0 days, 0 hours, 8 mins, 26 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 101 sec, nreceivers=108, nsenders=20
# phase_i=2048.0 sec, phase_ii=811 sec
# total time = 0 days, 0 hours, 49 mins, 19 sec
# rgen_msg+phase_ii=0 days, 0 hours, 15 mins, 11 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 101 sec, nreceivers=108, nsenders=20
# phase_i=2048.0 sec, phase_ii=1621 sec
# total time = 0 days, 1 hours, 2 mins, 50 sec
# rgen_msg+phase_ii=0 days, 0 hours, 28 mins, 42 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 101 sec, nreceivers=108, nsenders=20
# phase_i=2048.0 sec, phase_ii=3243 sec
# total time = 0 days, 1 hours, 29 mins, 51 sec
# rgen_msg+phase_ii=0 days, 0 hours, 55 mins, 43 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 101 sec, nreceivers=108, nsenders=20
# phase_i=2048.0 sec, phase_ii=6485 sec
# total time = 0 days, 2 hours, 23 mins, 54 sec
# rgen_msg+phase_ii=0 days, 1 hours, 49 mins, 46 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 101 sec, nreceivers=108, nsenders=20
# phase_i=2048.0 sec, phase_ii=12970 sec
# total time = 0 days, 4 hours, 11 mins, 59 sec
# rgen_msg+phase_ii=0 days, 3 hours, 37 mins, 51 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 101 sec, nreceivers=108, nsenders=20
# phase_i=2048.0 sec, phase_ii=25941 sec
# total time = 0 days, 7 hours, 48 mins, 10 sec
# rgen_msg+phase_ii=0 days, 7 hours, 14 mins, 2 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 101 sec, nreceivers=108, nsenders=20
# phase_i=2048.0 sec, phase_ii=51882 sec
# total time = 0 days, 15 hours, 0 mins, 31 sec
# rgen_msg+phase_ii=0 days, 14 hours, 26 mins, 23 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 127 sec, nreceivers=112, nsenders=16
# phase_i=2048.0 sec, phase_ii=161 sec
# total time = 0 days, 0 hours, 38 mins, 55 sec
# rgen_msg+phase_ii=0 days, 0 hours, 4 mins, 47 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 127 sec, nreceivers=112, nsenders=16
# phase_i=2048.0 sec, phase_ii=253 sec
# total time = 0 days, 0 hours, 40 mins, 27 sec
# rgen_msg+phase_ii=0 days, 0 hours, 6 mins, 19 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 127 sec, nreceivers=112, nsenders=16
# phase_i=2048.0 sec, phase_ii=507 sec
# total time = 0 days, 0 hours, 44 mins, 41 sec
# rgen_msg+phase_ii=0 days, 0 hours, 10 mins, 33 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 127 sec, nreceivers=112, nsenders=16
# phase_i=2048.0 sec, phase_ii=1013 sec
# total time = 0 days, 0 hours, 53 mins, 7 sec
# rgen_msg+phase_ii=0 days, 0 hours, 18 mins, 59 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 127 sec, nreceivers=112, nsenders=16
# phase_i=2048.0 sec, phase_ii=2027 sec
# total time = 0 days, 1 hours, 10 mins, 1 sec
# rgen_msg+phase_ii=0 days, 0 hours, 35 mins, 53 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 127 sec, nreceivers=112, nsenders=16
# phase_i=2048.0 sec, phase_ii=4053 sec
# total time = 0 days, 1 hours, 43 mins, 47 sec
# rgen_msg+phase_ii=0 days, 1 hours, 9 mins, 39 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 127 sec, nreceivers=112, nsenders=16
# phase_i=2048.0 sec, phase_ii=8107 sec
# total time = 0 days, 2 hours, 51 mins, 21 sec
# rgen_msg+phase_ii=0 days, 2 hours, 17 mins, 13 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 127 sec, nreceivers=112, nsenders=16
# phase_i=2048.0 sec, phase_ii=16213 sec
# total time = 0 days, 5 hours, 6 mins, 27 sec
# rgen_msg+phase_ii=0 days, 4 hours, 32 mins, 19 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 127 sec, nreceivers=112, nsenders=16
# phase_i=2048.0 sec, phase_ii=32426 sec
# total time = 0 days, 9 hours, 36 mins, 40 sec
# rgen_msg+phase_ii=0 days, 9 hours, 2 mins, 32 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 127 sec, nreceivers=112, nsenders=16
# phase_i=2048.0 sec, phase_ii=64852 sec
# total time = 0 days, 18 hours, 37 mins, 6 sec
# rgen_msg+phase_ii=0 days, 18 hours, 2 mins, 58 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 169 sec, nreceivers=116, nsenders=12
# phase_i=2048.0 sec, phase_ii=169 sec
# total time = 0 days, 0 hours, 39 mins, 45 sec
# rgen_msg+phase_ii=0 days, 0 hours, 5 mins, 37 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 169 sec, nreceivers=116, nsenders=12
# phase_i=2048.0 sec, phase_ii=338 sec
# total time = 0 days, 0 hours, 42 mins, 34 sec
# rgen_msg+phase_ii=0 days, 0 hours, 8 mins, 26 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 169 sec, nreceivers=116, nsenders=12
# phase_i=2048.0 sec, phase_ii=676 sec
# total time = 0 days, 0 hours, 48 mins, 12 sec
# rgen_msg+phase_ii=0 days, 0 hours, 14 mins, 4 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 169 sec, nreceivers=116, nsenders=12
# phase_i=2048.0 sec, phase_ii=1351 sec
# total time = 0 days, 0 hours, 59 mins, 27 sec
# rgen_msg+phase_ii=0 days, 0 hours, 25 mins, 19 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 169 sec, nreceivers=116, nsenders=12
# phase_i=2048.0 sec, phase_ii=2702 sec
# total time = 0 days, 1 hours, 21 mins, 59 sec
# rgen_msg+phase_ii=0 days, 0 hours, 47 mins, 51 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 169 sec, nreceivers=116, nsenders=12
# phase_i=2048.0 sec, phase_ii=5404 sec
# total time = 0 days, 2 hours, 7 mins, 1 sec
# rgen_msg+phase_ii=0 days, 1 hours, 32 mins, 53 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 169 sec, nreceivers=116, nsenders=12
# phase_i=2048.0 sec, phase_ii=10809 sec
# total time = 0 days, 3 hours, 37 mins, 5 sec
# rgen_msg+phase_ii=0 days, 3 hours, 2 mins, 57 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 169 sec, nreceivers=116, nsenders=12
# phase_i=2048.0 sec, phase_ii=21617 sec
# total time = 0 days, 6 hours, 37 mins, 14 sec
# rgen_msg+phase_ii=0 days, 6 hours, 3 mins, 6 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 169 sec, nreceivers=116, nsenders=12
# phase_i=2048.0 sec, phase_ii=43235 sec
# total time = 0 days, 12 hours, 37 mins, 31 sec
# rgen_msg+phase_ii=0 days, 12 hours, 3 mins, 23 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 169 sec, nreceivers=116, nsenders=12
# phase_i=2048.0 sec, phase_ii=86469 sec
# total time = 1 days, 0 hours, 38 mins, 6 sec
# rgen_msg+phase_ii=1 days, 0 hours, 3 mins, 58 sec sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => rgen_msg 253 sec, nreceivers=120, nsenders=8
# phase_i=2048.0 sec, phase_ii=253 sec
# total time = 0 days, 0 hours, 42 mins, 34 sec
# rgen_msg+phase_ii=0 days, 0 hours, 8 mins, 26 sec sec
# -------------------------------------------------------------------------------------
# difficulty=1 => rgen_msg 253 sec, nreceivers=120, nsenders=8
# phase_i=2048.0 sec, phase_ii=507 sec
# total time = 0 days, 0 hours, 46 mins, 47 sec
# rgen_msg+phase_ii=0 days, 0 hours, 12 mins, 39 sec sec
# -------------------------------------------------------------------------------------
# difficulty=2 => rgen_msg 253 sec, nreceivers=120, nsenders=8
# phase_i=2048.0 sec, phase_ii=1013 sec
# total time = 0 days, 0 hours, 55 mins, 14 sec
# rgen_msg+phase_ii=0 days, 0 hours, 21 mins, 6 sec sec
# -------------------------------------------------------------------------------------
# difficulty=3 => rgen_msg 253 sec, nreceivers=120, nsenders=8
# phase_i=2048.0 sec, phase_ii=2027 sec
# total time = 0 days, 1 hours, 12 mins, 7 sec
# rgen_msg+phase_ii=0 days, 0 hours, 37 mins, 59 sec sec
# -------------------------------------------------------------------------------------
# difficulty=4 => rgen_msg 253 sec, nreceivers=120, nsenders=8
# phase_i=2048.0 sec, phase_ii=4053 sec
# total time = 0 days, 1 hours, 45 mins, 54 sec
# rgen_msg+phase_ii=0 days, 1 hours, 11 mins, 46 sec sec
# -------------------------------------------------------------------------------------
# difficulty=5 => rgen_msg 253 sec, nreceivers=120, nsenders=8
# phase_i=2048.0 sec, phase_ii=8107 sec
# total time = 0 days, 2 hours, 53 mins, 27 sec
# rgen_msg+phase_ii=0 days, 2 hours, 19 mins, 19 sec sec
# -------------------------------------------------------------------------------------
# difficulty=6 => rgen_msg 253 sec, nreceivers=120, nsenders=8
# phase_i=2048.0 sec, phase_ii=16213 sec
# total time = 0 days, 5 hours, 8 mins, 34 sec
# rgen_msg+phase_ii=0 days, 4 hours, 34 mins, 26 sec sec
# -------------------------------------------------------------------------------------
# difficulty=7 => rgen_msg 253 sec, nreceivers=120, nsenders=8
# phase_i=2048.0 sec, phase_ii=32426 sec
# total time = 0 days, 9 hours, 38 mins, 47 sec
# rgen_msg+phase_ii=0 days, 9 hours, 4 mins, 39 sec sec
# -------------------------------------------------------------------------------------
# difficulty=8 => rgen_msg 253 sec, nreceivers=120, nsenders=8
# phase_i=2048.0 sec, phase_ii=64852 sec
# total time = 0 days, 18 hours, 39 mins, 13 sec
# rgen_msg+phase_ii=0 days, 18 hours, 5 mins, 5 sec sec
# -------------------------------------------------------------------------------------
# difficulty=9 => rgen_msg 253 sec, nreceivers=120, nsenders=8
# phase_i=2048.0 sec, phase_ii=129704 sec
# total time = 1 days, 12 hours, 40 mins, 5 sec
# rgen_msg+phase_ii=1 days, 12 hours, 5 mins, 57 sec sec
# =============================================

# %%
print("-------------------------------------------------------------------------------------")
print(f"difficulty={best_diff} => nreceivers={best_nreceivers}, nsenders={best_nsenders}")
print(f"total time = {seconds_2_time(best_total_time)}")
# Out:
# -------------------------------------------------------------------------------------
# difficulty=1 => nreceivers=96, nsenders=32
# total time = 0 days, 0 hours, 38 mins, 18 sec

# %%
def regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored):
    
    """ return number of seconds needed to regenerate the long message"""
    nsecs_sender = nhashes_stored / (nsenders*hashes_sec_core)
    nsecs_receiver = (nhashes_stored/(2**difficulty)) 
    nsecs_receiver = nsecs_receiver / (nreceivers*dict_add_sec)
    
    return max(nsecs_receiver, nsecs_sender)


def regen_msg_l(difficulty,
                nhashes_stored):
    """ return the max l can be constructed with difficulty """
    from math import log2
    
    return log2( (nhashes_stored/(2**difficulty)) )
    

def largest_n(l,
              nsenders,
              nreceivers,
              dict_queries_sec,
              hashes_sec_core,
              difficulty,
              t_sec):

    """
    Given an attack parameter what is the largest n can be attacked in t_sec
    """
    from math import log2

    nqueries_sec = min(nqueries_sender(nsenders, hashes_sec_core, difficulty),
                   nqueries_receiver(nreceivers, dict_queries_sec))

    return log2(nqueries_sec*t_sec) + l + difficulty



def find_best_parameters(nservers,
              server_memory,
              ncores_per_server,
              nhashes_stored,
              dict_queries_sec,
              dict_add_sec,
              hashes_sec_core,
              hashes_sec_phase_i,
              t_sec,
              phase_i_timeout=365*24*60*60):
    """
    Find the attack parameters that can attack the largest possible n in t_sec
    return dictionary contains attack parameters.
    phase_i_timeout by default 365 days, since it can be done offline
    phase_ii_reconstruct_timeout 
    """

    from math import log2
    from itertools import product

    memory = nservers * server_memory
    val_size_bytes = 4 # one entry size in the dictionary
    filling_rate = 0.93 # how many slots of the dictionary are used
    l_max = log2(filling_rate * memory / val_size_bytes)

    ncores = nservers * ncores_per_server

    best_difficulty = 0
    best_n = 0 # optimize: find largest n
    best_nsenders = 0
    best_time_phase_i = float('inf')
    largest_difficulty = 40
    best_l = 0
    
    for nsenders, difficulty in product(range(1, ncores-nservers + 1), range(0, largest_difficulty)):
        nreceivers = ncores - nsenders
        l = min(l_max, regen_msg_l(difficulty, nhashes_stored))

        #print(f"l={l}, nsenders={nsenders}, difficulty={difficulty}, l_regen = {regen_msg_l( difficulty, nhashes_stored)}")
        t_rgen_msg = regen_msg_time(nsenders,
                                    nreceivers,
                                    hashes_sec_core,
                                    dict_add_sec,
                                    difficulty,
                                    nhashes_stored)
        
        t_sec_after_regen_msg = t_sec - t_rgen_msg
        if ( t_sec_after_regen_msg <= 0):
            continue # skip this iteration since all time have been spent on regenrating the long message
        
        
        n = largest_n(l,
                      nsenders,
                      nreceivers,
                      dict_queries_sec,
                      hashes_sec_core,
                      difficulty,
                      t_sec_after_regen_msg)


        # better n, always update
        t_phase_i = phase_i_time(l, difficulty, hashes_sec_phase_i)
        
        if (n > best_n  and t_phase_i <= phase_i_timeout):
            best_n = n
            best_l = l
            best_difficulty = difficulty
            best_nsenders = nsenders
            #print(f"better_n = {best_n}, better_l={best_l}, better_difficulty={best_difficulty}, better_nsenders={best_nsenders}, t_phase_i={seconds_2_time(t_phase_i)}")
            


    return {"n": best_n, "l": best_l,
            "difficulty": best_difficulty,
            "nsenders": best_nsenders,
            "nreceivers": ncores - nsenders}

# %%
# %%time
# best parameters
best_parms = find_best_parameters(nservers,
                     server_memory,
                     ncores_per_server,
                     nhashes_stored,
                     dict_queries_sec,
                     dict_add_sec,
                     hashes_sec_core,
                     hashes_sec_phase_i,
                     t_sec)

print(best_parms)

nsenders = best_parms["nsenders"]
nreceivers = best_parms["nreceivers"]
difficulty = best_parms["difficulty"]
l = best_parms["l"]
# Out:
# {'n': 82.10628160340188, 'l': 36.0, 'difficulty': 0, 'nsenders': 13, 'nreceivers': 4}
# CPU times: user 83.6 ms, sys: 114 µs, total: 83.7 ms
# Wall time: 83 ms

# %%
# how long phase_i will take using the best parameters?
seconds_2_time(phase_i_time(l, difficulty, hashes_sec_phase_i))
# Out:
# '0 days, 0 hours, 34 mins, 8 sec'

# %%
# how long regenerating the long message again will take?
seconds_2_time(regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored))
# Out:
# '0 days, 0 hours, 25 mins, 41 sec'

# %%
from math import log2
dict_queries_sec = 2^22.963350
log2(33767312.397134)
# Out:
# 25.00912402135891
