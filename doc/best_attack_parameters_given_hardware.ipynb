# %% [markdown]
# # Best attack parameters given a hardware
#
# We assume the attack parameters are $n$ and $l$. Also, denote $g$ to be the number of ignored bits.
#
# $p = \frac{2^l}{2^n}$ , this is a geometric random variable, thus we expect a collision after   $\#queries = \frac{2^n}{2^l} $
#
# Assume, we only accept digests that have certain number of zeros, denoted as $d$. Thus, we can pretend as we are working on small digests
# $$
# \begin{align}
# &\#queries = \frac{2^n}{2^l} \\
# &\#queries_{sec} \cdot t_{sec} = \frac{2^n}{2^l} \\
# \Rightarrow &n = log2\left(\#queries_{sec} \cdot t_{sec} \cdot 2^{n-l-d}  \right)
# \end{align}
# $$
#
#
# We have three point of views of $\#queries$
# - Senders: How many hashes they generate?
#     - Their speed will be affected by difficulty, but from their perspective the overall attack time doesn't change if the difficulty change (add explanation, later)
#     - $\#snd\_queries_{sec} = \frac{\#senders \cdot \#gen\_hashes_{sec}} {2^{d}}$
#
# - Receivers: How many hashes they can query the dicitonary.
#     - In their world, the higher the difficulty the better chance of hitting collision (since digests are technically shorter).
#     - $\#rcv\_queries_{sec} = \#receivers \cdot \#dict\_queries_{sec} $
#
# - Bandwith: This is how many hashes the network can carry in a second.
#     - From their perspective, difficulty reduces the rate of transmitted messages.
#     - $bdwth_queries_{sec} $
#
#
# Thus,
#
# $$\#queries_{sec} := min\left(snd\_queries_{sec}, rcv\_queries_{sec}, bdwth\_queries_{sec}\right)$$

# %%
# Numbers from Gros cluster, nancy, grid5000.fr
# find_dist overhead = 7%-9%
# hash_16x_avx (nancy: gros) ≈ 2^24.87hash/sec
# dict_add≈2^23.41 elm/sec
# dict_lookup ≈ 2^24.9337 elm/sec
# mpi_recv overhead = 10.71% (for regenerating message)


nservers = 124
server_memory = (96 - 20)*10^9 # 96 GB
ncores_per_server = 18
hashes_sec_core = 2^23.87 #2^24.87
dict_queries_sec = 2^21.963350
t_sec =  2 * 24 * 3600
# how many hashes can oure compressed file 
nhashes_stored = 2^60
hashes_sec_phase_i = 2^24.72
dict_add_sec = 2^23.41

# %%
# 1 core hashing power
# thd2 sha_avx512_16way  elapsed 1.78sec i.e. 898392.92 hashes/sec = 2^19.777 hashes, 57.4971 M


# Querying 100000000, took 2.22 sec i.e. 44977939.99 elm/sec = 2^25.4227 elm/sec 


def seconds_2_time(t):
    from math import floor

    t = float(t)
    days  = floor(t/(3600*24))
    t = t - days*24*3600

    hours = floor(t/3600)
    t = t - hours*3600
    minutes = floor(t/60)
    t = t - minutes*60

    return f"{days} days, {hours} hours, {minutes} mins, {floor(t)} sec"

print(f"server_memory={server_memory}")
# Out:
# server_memory=76000000000

# %%
def regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored):
    """ return number of seconds needed to regenerate the long message"""
    nsecs_sender = nhashes_stored / (nsenders*hashes_sec_core)
    nsecs_receiver = (nhashes_stored/(2**difficulty)) 
    nsecs_receiver = nsecs_receiver / (nreceivers*dict_add_sec)
    
    return max(nsecs_receiver, nsecs_sender)


def regen_msg_l(difficulty,
                nhashes_stored):
    """ return the max l can be constructed with difficulty """
    from math import log2
    
    return log2( (nhashes_stored/(2**difficulty)) )
    
def nqueries_sender(nsenders, hashes_sec_core, difficulty):
    """ Return how many queries senders can generate per second """

    return nsenders*hashes_sec_core/(2**difficulty)


def nqueries_receiver(nreceivers, dict_queries_sec):
    """
    Return how many queries receivers can make in a second
    """
    return nreceivers * dict_queries_sec

def phase_i_time(l, difficulty, hashes_sec_phase_i):
    """
    Return how many seconds it takes to complete phase_i
    """
    return 2^l * 2^difficulty / (hashes_sec_phase_i)

# %%
print("Regenerating the long message will take ... ")

nservers = 8
ncores_per_server = 18
for nreceivers in range(nservers, nservers*ncores_per_server - nservers, nservers):
    nsenders = (ncores_per_server)*nservers - nreceivers
    #nreceivers = 2*nservers
    for diff in range(10):

        time_needed = regen_msg_time(nsenders,
                                     nreceivers, # nsenders
                                     hashes_sec_core,
                                     dict_add_sec,
                                     diff, # difficulty
                                     2^33 # nhashes stored
                                    )

        print(f"difficulty={diff} => {time_needed} sec, nreceivers={nreceivers}, nsenders={nsenders}")
    print("=============================================")
# Out:
# Regenerating the long message will take ...
# difficulty=0 => 96.3357918343083 sec, nreceivers=8, nsenders=136
# difficulty=1 => 48.1678959171541 sec, nreceivers=8, nsenders=136
# difficulty=2 => 24.0839479585771 sec, nreceivers=8, nsenders=136
# difficulty=3 => 12.0419739792885 sec, nreceivers=8, nsenders=136
# difficulty=4 => 6.02098698964427 sec, nreceivers=8, nsenders=136
# difficulty=5 => 3.01049349482213 sec, nreceivers=8, nsenders=136
# difficulty=6 => 2.05984696707904 sec, nreceivers=8, nsenders=136
# difficulty=7 => 2.05984696707904 sec, nreceivers=8, nsenders=136
# difficulty=8 => 2.05984696707904 sec, nreceivers=8, nsenders=136
# difficulty=9 => 2.05984696707904 sec, nreceivers=8, nsenders=136
# =============================================
# difficulty=0 => 48.1678959171541 sec, nreceivers=16, nsenders=128
# difficulty=1 => 24.0839479585771 sec, nreceivers=16, nsenders=128
# difficulty=2 => 12.0419739792885 sec, nreceivers=16, nsenders=128
# difficulty=3 => 6.02098698964427 sec, nreceivers=16, nsenders=128
# difficulty=4 => 3.01049349482213 sec, nreceivers=16, nsenders=128
# difficulty=5 => 2.18858740252148 sec, nreceivers=16, nsenders=128
# difficulty=6 => 2.18858740252148 sec, nreceivers=16, nsenders=128
# difficulty=7 => 2.18858740252148 sec, nreceivers=16, nsenders=128
# difficulty=8 => 2.18858740252148 sec, nreceivers=16, nsenders=128
# difficulty=9 => 2.18858740252148 sec, nreceivers=16, nsenders=128
# =============================================
# difficulty=0 => 32.1119306114361 sec, nreceivers=24, nsenders=120
# difficulty=1 => 16.0559653057181 sec, nreceivers=24, nsenders=120
# difficulty=2 => 8.02798265285903 sec, nreceivers=24, nsenders=120
# difficulty=3 => 4.01399132642951 sec, nreceivers=24, nsenders=120
# difficulty=4 => 2.33449322935624 sec, nreceivers=24, nsenders=120
# difficulty=5 => 2.33449322935624 sec, nreceivers=24, nsenders=120
# difficulty=6 => 2.33449322935624 sec, nreceivers=24, nsenders=120
# difficulty=7 => 2.33449322935624 sec, nreceivers=24, nsenders=120
# difficulty=8 => 2.33449322935624 sec, nreceivers=24, nsenders=120
# difficulty=9 => 2.33449322935624 sec, nreceivers=24, nsenders=120
# =============================================
# difficulty=0 => 24.0839479585771 sec, nreceivers=32, nsenders=112
# difficulty=1 => 12.0419739792885 sec, nreceivers=32, nsenders=112
# difficulty=2 => 6.02098698964427 sec, nreceivers=32, nsenders=112
# difficulty=3 => 3.01049349482213 sec, nreceivers=32, nsenders=112
# difficulty=4 => 2.50124274573883 sec, nreceivers=32, nsenders=112
# difficulty=5 => 2.50124274573883 sec, nreceivers=32, nsenders=112
# difficulty=6 => 2.50124274573883 sec, nreceivers=32, nsenders=112
# difficulty=7 => 2.50124274573883 sec, nreceivers=32, nsenders=112
# difficulty=8 => 2.50124274573883 sec, nreceivers=32, nsenders=112
# difficulty=9 => 2.50124274573883 sec, nreceivers=32, nsenders=112
# =============================================
# difficulty=0 => 19.2671583668617 sec, nreceivers=40, nsenders=104
# difficulty=1 => 9.63357918343083 sec, nreceivers=40, nsenders=104
# difficulty=2 => 4.81678959171542 sec, nreceivers=40, nsenders=104
# difficulty=3 => 2.69364603387259 sec, nreceivers=40, nsenders=104
# difficulty=4 => 2.69364603387259 sec, nreceivers=40, nsenders=104
# difficulty=5 => 2.69364603387259 sec, nreceivers=40, nsenders=104
# difficulty=6 => 2.69364603387259 sec, nreceivers=40, nsenders=104
# difficulty=7 => 2.69364603387259 sec, nreceivers=40, nsenders=104
# difficulty=8 => 2.69364603387259 sec, nreceivers=40, nsenders=104
# difficulty=9 => 2.69364603387259 sec, nreceivers=40, nsenders=104
# =============================================
# difficulty=0 => 16.0559653057181 sec, nreceivers=48, nsenders=96
# difficulty=1 => 8.02798265285903 sec, nreceivers=48, nsenders=96
# difficulty=2 => 4.01399132642951 sec, nreceivers=48, nsenders=96
# difficulty=3 => 2.91811653669530 sec, nreceivers=48, nsenders=96
# difficulty=4 => 2.91811653669530 sec, nreceivers=48, nsenders=96
# difficulty=5 => 2.91811653669530 sec, nreceivers=48, nsenders=96
# difficulty=6 => 2.91811653669530 sec, nreceivers=48, nsenders=96
# difficulty=7 => 2.91811653669530 sec, nreceivers=48, nsenders=96
# difficulty=8 => 2.91811653669530 sec, nreceivers=48, nsenders=96
# difficulty=9 => 2.91811653669530 sec, nreceivers=48, nsenders=96
# =============================================
# difficulty=0 => 13.7622559763298 sec, nreceivers=56, nsenders=88
# difficulty=1 => 6.88112798816488 sec, nreceivers=56, nsenders=88
# difficulty=2 => 3.44056399408244 sec, nreceivers=56, nsenders=88
# difficulty=3 => 3.18339985821306 sec, nreceivers=56, nsenders=88
# difficulty=4 => 3.18339985821306 sec, nreceivers=56, nsenders=88
# difficulty=5 => 3.18339985821306 sec, nreceivers=56, nsenders=88
# difficulty=6 => 3.18339985821306 sec, nreceivers=56, nsenders=88
# difficulty=7 => 3.18339985821306 sec, nreceivers=56, nsenders=88
# difficulty=8 => 3.18339985821306 sec, nreceivers=56, nsenders=88
# difficulty=9 => 3.18339985821306 sec, nreceivers=56, nsenders=88
# =============================================
# difficulty=0 => 12.0419739792885 sec, nreceivers=64, nsenders=80
# difficulty=1 => 6.02098698964427 sec, nreceivers=64, nsenders=80
# difficulty=2 => 3.50173984403436 sec, nreceivers=64, nsenders=80
# difficulty=3 => 3.50173984403436 sec, nreceivers=64, nsenders=80
# difficulty=4 => 3.50173984403436 sec, nreceivers=64, nsenders=80
# difficulty=5 => 3.50173984403436 sec, nreceivers=64, nsenders=80
# difficulty=6 => 3.50173984403436 sec, nreceivers=64, nsenders=80
# difficulty=7 => 3.50173984403436 sec, nreceivers=64, nsenders=80
# difficulty=8 => 3.50173984403436 sec, nreceivers=64, nsenders=80
# difficulty=9 => 3.50173984403436 sec, nreceivers=64, nsenders=80
# =============================================
# difficulty=0 => 10.7039768704787 sec, nreceivers=72, nsenders=72
# difficulty=1 => 5.35198843523935 sec, nreceivers=72, nsenders=72
# difficulty=2 => 3.89082204892707 sec, nreceivers=72, nsenders=72
# difficulty=3 => 3.89082204892707 sec, nreceivers=72, nsenders=72
# difficulty=4 => 3.89082204892707 sec, nreceivers=72, nsenders=72
# difficulty=5 => 3.89082204892707 sec, nreceivers=72, nsenders=72
# difficulty=6 => 3.89082204892707 sec, nreceivers=72, nsenders=72
# difficulty=7 => 3.89082204892707 sec, nreceivers=72, nsenders=72
# difficulty=8 => 3.89082204892707 sec, nreceivers=72, nsenders=72
# difficulty=9 => 3.89082204892707 sec, nreceivers=72, nsenders=72
# =============================================
# difficulty=0 => 9.63357918343083 sec, nreceivers=80, nsenders=64
# difficulty=1 => 4.81678959171542 sec, nreceivers=80, nsenders=64
# difficulty=2 => 4.37717480504296 sec, nreceivers=80, nsenders=64
# difficulty=3 => 4.37717480504296 sec, nreceivers=80, nsenders=64
# difficulty=4 => 4.37717480504296 sec, nreceivers=80, nsenders=64
# difficulty=5 => 4.37717480504296 sec, nreceivers=80, nsenders=64
# difficulty=6 => 4.37717480504296 sec, nreceivers=80, nsenders=64
# difficulty=7 => 4.37717480504296 sec, nreceivers=80, nsenders=64
# difficulty=8 => 4.37717480504296 sec, nreceivers=80, nsenders=64
# difficulty=9 => 4.37717480504296 sec, nreceivers=80, nsenders=64
# =============================================
# difficulty=0 => 8.75779925766439 sec, nreceivers=88, nsenders=56
# difficulty=1 => 5.00248549147766 sec, nreceivers=88, nsenders=56
# difficulty=2 => 5.00248549147766 sec, nreceivers=88, nsenders=56
# difficulty=3 => 5.00248549147766 sec, nreceivers=88, nsenders=56
# difficulty=4 => 5.00248549147766 sec, nreceivers=88, nsenders=56
# difficulty=5 => 5.00248549147766 sec, nreceivers=88, nsenders=56
# difficulty=6 => 5.00248549147766 sec, nreceivers=88, nsenders=56
# difficulty=7 => 5.00248549147766 sec, nreceivers=88, nsenders=56
# difficulty=8 => 5.00248549147766 sec, nreceivers=88, nsenders=56
# difficulty=9 => 5.00248549147766 sec, nreceivers=88, nsenders=56
# =============================================
# difficulty=0 => 8.02798265285903 sec, nreceivers=96, nsenders=48
# difficulty=1 => 5.83623307339061 sec, nreceivers=96, nsenders=48
# difficulty=2 => 5.83623307339061 sec, nreceivers=96, nsenders=48
# difficulty=3 => 5.83623307339061 sec, nreceivers=96, nsenders=48
# difficulty=4 => 5.83623307339061 sec, nreceivers=96, nsenders=48
# difficulty=5 => 5.83623307339061 sec, nreceivers=96, nsenders=48
# difficulty=6 => 5.83623307339061 sec, nreceivers=96, nsenders=48
# difficulty=7 => 5.83623307339061 sec, nreceivers=96, nsenders=48
# difficulty=8 => 5.83623307339061 sec, nreceivers=96, nsenders=48
# difficulty=9 => 5.83623307339061 sec, nreceivers=96, nsenders=48
# =============================================
# difficulty=0 => 7.41044552571602 sec, nreceivers=104, nsenders=40
# difficulty=1 => 7.00347968806873 sec, nreceivers=104, nsenders=40
# difficulty=2 => 7.00347968806873 sec, nreceivers=104, nsenders=40
# difficulty=3 => 7.00347968806873 sec, nreceivers=104, nsenders=40
# difficulty=4 => 7.00347968806873 sec, nreceivers=104, nsenders=40
# difficulty=5 => 7.00347968806873 sec, nreceivers=104, nsenders=40
# difficulty=6 => 7.00347968806873 sec, nreceivers=104, nsenders=40
# difficulty=7 => 7.00347968806873 sec, nreceivers=104, nsenders=40
# difficulty=8 => 7.00347968806873 sec, nreceivers=104, nsenders=40
# difficulty=9 => 7.00347968806873 sec, nreceivers=104, nsenders=40
# =============================================
# difficulty=0 => 8.75434961008591 sec, nreceivers=112, nsenders=32
# difficulty=1 => 8.75434961008591 sec, nreceivers=112, nsenders=32
# difficulty=2 => 8.75434961008591 sec, nreceivers=112, nsenders=32
# difficulty=3 => 8.75434961008591 sec, nreceivers=112, nsenders=32
# difficulty=4 => 8.75434961008591 sec, nreceivers=112, nsenders=32
# difficulty=5 => 8.75434961008591 sec, nreceivers=112, nsenders=32
# difficulty=6 => 8.75434961008591 sec, nreceivers=112, nsenders=32
# difficulty=7 => 8.75434961008591 sec, nreceivers=112, nsenders=32
# difficulty=8 => 8.75434961008591 sec, nreceivers=112, nsenders=32
# difficulty=9 => 8.75434961008591 sec, nreceivers=112, nsenders=32
# =============================================
# difficulty=0 => 11.6724661467812 sec, nreceivers=120, nsenders=24
# difficulty=1 => 11.6724661467812 sec, nreceivers=120, nsenders=24
# difficulty=2 => 11.6724661467812 sec, nreceivers=120, nsenders=24
# difficulty=3 => 11.6724661467812 sec, nreceivers=120, nsenders=24
# difficulty=4 => 11.6724661467812 sec, nreceivers=120, nsenders=24
# difficulty=5 => 11.6724661467812 sec, nreceivers=120, nsenders=24
# difficulty=6 => 11.6724661467812 sec, nreceivers=120, nsenders=24
# difficulty=7 => 11.6724661467812 sec, nreceivers=120, nsenders=24
# difficulty=8 => 11.6724661467812 sec, nreceivers=120, nsenders=24
# difficulty=9 => 11.6724661467812 sec, nreceivers=120, nsenders=24
# =============================================
# difficulty=0 => 17.5086992201718 sec, nreceivers=128, nsenders=16
# difficulty=1 => 17.5086992201718 sec, nreceivers=128, nsenders=16
# difficulty=2 => 17.5086992201718 sec, nreceivers=128, nsenders=16
# difficulty=3 => 17.5086992201718 sec, nreceivers=128, nsenders=16
# difficulty=4 => 17.5086992201718 sec, nreceivers=128, nsenders=16
# difficulty=5 => 17.5086992201718 sec, nreceivers=128, nsenders=16
# difficulty=6 => 17.5086992201718 sec, nreceivers=128, nsenders=16
# difficulty=7 => 17.5086992201718 sec, nreceivers=128, nsenders=16
# difficulty=8 => 17.5086992201718 sec, nreceivers=128, nsenders=16
# difficulty=9 => 17.5086992201718 sec, nreceivers=128, nsenders=16
# =============================================

# %%
def regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored):
    """ return number of seconds needed to regenerate the long message"""
    nsecs_sender = nhashes_stored / (nsenders*hashes_sec_core)
    nsecs_receiver = (nhashes_stored/(2**difficulty)) 
    nsecs_receiver = nsecs_receiver / (nreceivers*dict_add_sec)
    
    return max(nsecs_receiver, nsecs_sender)


def regen_msg_l(difficulty,
                nhashes_stored):
    """ return the max l can be constructed with difficulty """
    from math import log2
    
    return log2( (nhashes_stored/(2**difficulty)) )
    
def nqueries_sender(nsenders, hashes_sec_core, difficulty):
    """ Return how many queries senders can generate per second """

    return nsenders*hashes_sec_core/(2**difficulty)


def nqueries_receiver(nreceivers, dict_queries_sec):
    """
    Return how many queries receivers can make in a second
    """
    return nreceivers * dict_queries_sec

def phase_i_time(l, difficulty, hashes_sec_phase_i):
    """
    Return how many seconds it takes to complete phase_i
    """
    return 2^l * 2^difficulty / (hashes_sec_phase_i)


def largest_n(l,
              nsenders,
              nreceivers,
              dict_queries_sec,
              hashes_sec_core,
              difficulty,
              t_sec):

    """
    Given an attack parameter what is the largest n can be attacked in t_sec
    """
    from math import log2

    nqueries_sec = min(nqueries_sender(nsenders, hashes_sec_core, difficulty),
                   nqueries_receiver(nreceivers, dict_queries_sec))

    return log2(nqueries_sec*t_sec) + l + difficulty



def find_best_parameters(nservers,
              server_memory,
              ncores_per_server,
              nhashes_stored,
              dict_queries_sec,
              dict_add_sec,
              hashes_sec_core,
              hashes_sec_phase_i,
              t_sec,
              phase_i_timeout=365*24*60*60):
    """
    Find the attack parameters that can attack the largest possible n in t_sec
    return dictionary contains attack parameters.
    phase_i_timeout by default 365 days, since it can be done offline
    phase_ii_reconstruct_timeout 
    """

    from math import log2
    from itertools import product

    memory = nservers * server_memory
    val_size_bytes = 4 # one entry size in the dictionary
    filling_rate = 0.93 # how many slots of the dictionary are used
    l_max = log2(filling_rate * memory / val_size_bytes)

    ncores = nservers * ncores_per_server

    best_difficulty = 0
    best_n = 0 # optimize: find largest n
    best_nsenders = 0
    best_time_phase_i = float('inf')
    largest_difficulty = 40
    best_l = 0
    
    for nsenders, difficulty in product(range(1, ncores-nservers + 1), range(0, largest_difficulty)):
        nreceivers = ncores - nsenders
        l = min(l_max, regen_msg_l(difficulty, nhashes_stored))

        #print(f"l={l}, nsenders={nsenders}, difficulty={difficulty}, l_regen = {regen_msg_l( difficulty, nhashes_stored)}")
        t_rgen_msg = regen_msg_time(nsenders,
                                    nreceivers,
                                    hashes_sec_core,
                                    dict_add_sec,
                                    difficulty,
                                    nhashes_stored)
        
        t_sec_after_regen_msg = t_sec - t_rgen_msg
        if ( t_sec_after_regen_msg <= 0):
            continue # skip this iteration since all time have been spent on regenrating the long message
        
        
        n = largest_n(l,
                      nsenders,
                      nreceivers,
                      dict_queries_sec,
                      hashes_sec_core,
                      difficulty,
                      t_sec_after_regen_msg)


        # better n, always update
        t_phase_i = phase_i_time(l, difficulty, hashes_sec_phase_i)
        
        if (n > best_n  and t_phase_i <= phase_i_timeout):
            best_n = n
            best_l = l
            best_difficulty = difficulty
            best_nsenders = nsenders
            #print(f"better_n = {best_n}, better_l={best_l}, better_difficulty={best_difficulty}, better_nsenders={best_nsenders}, t_phase_i={seconds_2_time(t_phase_i)}")
            


    return {"n": best_n, "l": best_l,
            "difficulty": best_difficulty,
            "nsenders": best_nsenders,
            "nreceivers": ncores - nsenders}

# %%
# %%time
# best parameters
best_parms = find_best_parameters(nservers,
                     server_memory,
                     ncores_per_server,
                     nhashes_stored,
                     dict_queries_sec,
                     dict_add_sec,
                     hashes_sec_core,
                     hashes_sec_phase_i,
                     t_sec)

print(best_parms)

nsenders = best_parms["nsenders"]
nreceivers = best_parms["nreceivers"]
difficulty = best_parms["difficulty"]
l = best_parms["l"]
# Out:
# {'n': 0, 'l': 0, 'difficulty': 0, 'nsenders': 0, 'nreceivers': 124}
# CPU times: user 507 ms, sys: 0 ns, total: 507 ms
# Wall time: 506 ms

# %%
# how long phase_i will take using the best parameters?
seconds_2_time(phase_i_time(l, difficulty, hashes_sec_phase_i))
# Out:
# '0 days, 0 hours, 0 mins, 0 sec'

# %%
# how long regenerating the long message again will take?
seconds_2_time(regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 # how long regenerating the long message again will take?
# ----> 2 seconds_2_time(regen_msg_time(nsenders,
#       3                    nreceivers,
#       4                    hashes_sec_core,
#       5                    dict_add_sec,
#       6                    difficulty,
#       7                    nhashes_stored))
#
# Input In [2], in seconds_2_time(t)
#       9 from math import floor
#      11 t = float(t)
# ---> 12 days  = floor(t/(Integer(3600)*Integer(24)))
#      13 t = t - days*Integer(24)*Integer(3600)
#      15 hours = floor(t/Integer(3600))
#
# OverflowError: cannot convert float infinity to integer

# %%
from math import log2
dict_queries_sec = 2^22.963350
log2(33767312.397134)
