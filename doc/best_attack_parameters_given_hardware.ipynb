# %% [markdown]
# # Best attack parameters given a hardware
#
# We assume the attack parameters are $n$ and $l$. Also, denote $g$ to be the number of ignored bits.
#
# $p = \frac{2^l}{2^n}$ , this is a geometric random variable, thus we expect a collision after   $\#queries = \frac{2^n}{2^l} $
#
# Assume, we only accept digests that have certain number of zeros, denoted as $d$. Thus, we can pretend as we are working on small digests
# $$
# \begin{align}
# &\#queries = \frac{2^n}{2^l} \\
# &\#queries_{sec} \cdot t_{sec} = \frac{2^n}{2^l}
# \end{align}
# $$
#
#
# We have three point of views of $\#queries$
# - Senders: How many hashes they generate?
#     - Their speed will be affected by difficulty, but from their perspective the overall attack time doesn't change if the difficulty change (add explanation, later)
#
#     - $\#snd\_queries_{sec} = \frac{\#senders \cdot \#gen\_hashes_{sec}} {2^{d}}$
#     - so, $\#queries_{sec} \cdot t_{sec} = \frac{2^n}{2^{l}}$
#
# - Receivers: How many hashes they can query the dicitonary.
#     - In their world, the higher the difficulty the better chance of hitting collision (since digests are technically shorter).
#     - $\#rcv\_queries_{sec} = \#receivers \cdot \#dict\_queries_{sec} $
#     - but $\#queries_{sec} \cdot t_{sec} = \frac{2^n}{2^{l+d}}$
#
# - Bandwith: This is how many hashes the network can carry in a second.
#     - From their perspective, difficulty reduces the rate of transmitted messages.
#     - $bdwth_queries_{sec} $
#
#
# Thus,
#
# $$\#queries_{sec} := min\left(snd\_queries_{sec}, rcv\_queries_{sec}, bdwth\_queries_{sec}\right)$$

# %%
# Numbers from Gros cluster, nancy, grid5000.fr
# find_dist overhead = 7%-9%
# hash_16x_avx (nancy: gros) ≈ 2^24.87hash/sec
# dict_add≈2^23.41 elm/sec
# dict_lookup ≈ 2^24.9337 elm/sec
# mpi_recv overhead = 10.71% (for regenerating message)


nservers = 32
server_memory = (196 - 20)*10^9 # 96 GB
ncores_per_server = 32
hashes_sec_core = 2^25.015134275003597
dict_queries_sec = 2^21.863350
t_sec =  2 * 24 * 3600
# how many hashes can oure compressed file 
hashes_sec_phase_i = 2^25 # 2^24.72
dict_add_sec = 2^23.41

# %%
# 1 core hashing power
# thd2 sha_avx512_16way  elapsed 1.78sec i.e. 898392.92 hashes/sec = 2^19.777 hashes, 57.4971 M


# Querying 100000000, took 2.22 sec i.e. 44977939.99 elm/sec = 2^25.4227 elm/sec 


def seconds_2_time(t):
    from math import floor
    t = float(t)
    days  = floor(t/(3600*24))
    t = t - days*24*3600
    hours = floor(t/3600)
    t = t - hours*3600
    minutes = floor(t/60)
    t = t - minutes*60

    return f"{days} days, {hours} hours, {minutes} mins, {floor(t)} sec"

print(f"server_memory={server_memory}")
# Out:
# server_memory=176000000000

# %%
def regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored):
    """ return number of seconds needed to regenerate the long message"""
    nsecs_sender = nhashes_stored / (nsenders*hashes_sec_core)
    nsecs_receiver = (nhashes_stored/(2**difficulty)) 
    nsecs_receiver = nsecs_receiver / (nreceivers*dict_add_sec)
#     print(f"nhashes=2^{log2(nhashes_stored)}")
#     print(f"nsecs_sender={nsecs_sender}")
#     print(f"nsecs_receiver={nsecs_receiver}")
    return max(nsecs_receiver, nsecs_sender)


def regen_msg_l(difficulty,
                nhashes_stored):
    """ return the max l can be constructed with difficulty """
    from math import log2
    
    return log2( (nhashes_stored/(2**difficulty)) )
    
def nqueries_sender(nsenders, hashes_sec_core, difficulty):
    """ Return how many queries senders can generate per second """

    return nsenders*hashes_sec_core/(2**difficulty)


def nqueries_receiver(nreceivers, dict_queries_sec):
    """
    Return how many queries receivers can make in a second
    """
    return nreceivers * dict_queries_sec

def phase_i_time(l, difficulty, hashes_sec_phase_i):
    """
    Return how many seconds it takes to complete phase_i
    """
    return 2^l * 2^difficulty / (hashes_sec_phase_i)


def nqueries_sender(nsenders, hashes_sec_core, difficulty):
    """ Return how many queries senders can generate per second """

    return nsenders*hashes_sec_core/(2**difficulty)


def nqueries_receiver(nreceivers, dict_queries_sec):
    """
    Return how many queries receivers can make in a second
    """
    return nreceivers * dict_queries_sec


def nqueries(n, # as number of bits
             nsenders,
             nreceivers,
             nhashes_stored,
             hashes_sec_core, 
             dict_queries_sec,
             difficulty):
    nqueries_sec =  min(nqueries_sender(nsenders, hashes_sec_core, difficulty),
                      nqueries_receiver(nreceivers, dict_queries_sec) )
    
    return 2**n / (nqueries_sec*nhashes_stored)

# %%
# regen_msg_time(1,
#                1,
#                hashes_sec_core,
#                dict_add_sec,
#                6,
#                2^29)
# seconds_2_time(phase_i_time(40, 0, hashes_sec_phase_i))

# %%
# phase_i time?
# phase_ii time?

# %%
print("Regenerating the long message will take ... ")
from math import log2
nservers = 16
ncores_per_server = 80
nhashes_stored = 2^40
n = 64
best_total_time = float('inf')
best_nsenders = 0
best_nreceivers = 0
best_diff = 0

for nreceivers in range(nservers, nservers*ncores_per_server - nservers, nservers):
    nsenders = (ncores_per_server)*nservers - nreceivers
    #nreceivers = 2*nservers
    for diff in range(10):

        time_rgen_msg = regen_msg_time(nsenders,
                                      nreceivers, # nsenders
                                      hashes_sec_core,
                                      dict_add_sec,
                                      diff, # difficulty
                                      nhashes_stored,
                                     ) # 25 our experimented interval, 4 because sha2-16way, log2(nsenders) that how  we truncate the #states 

        time_phase_i  = phase_i_time(log2(nhashes_stored), 0, hashes_sec_phase_i) # no need to account for difficulty
        time_phase_ii =  nqueries(n, nsenders, nreceivers, nhashes_stored,
                                  hashes_sec_core, dict_queries_sec, diff)
        total_time = time_phase_i+time_rgen_msg+time_phase_ii
        
        
        if total_time < best_total_time and diff < 8:
            best_total_time = total_time
            best_nsenders = nsenders
            best_nreceivers = nreceivers
            best_diff = diff
            
        print("-------------------------------------------------------------------------------------")
        print(f"difficulty={diff} => {round(time_rgen_msg)} sec, nreceivers={nreceivers}, nsenders={nsenders}")
        print(f"phase_i={round(time_phase_i)} sec, phase_ii={round(time_phase_ii)} sec")
        print(f"total time = {seconds_2_time(total_time)}")
        
    print("=============================================")
# Out:
# Regenerating the long message will take ...
# -------------------------------------------------------------------------------------
# difficulty=0 => 6165 sec, nreceivers=16, nsenders=1264
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 10 hours, 48 mins, 53 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 3083 sec, nreceivers=16, nsenders=1264
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 57 mins, 30 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 1541 sec, nreceivers=16, nsenders=1264
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 31 mins, 49 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 771 sec, nreceivers=16, nsenders=1264
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 18 mins, 58 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 385 sec, nreceivers=16, nsenders=1264
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 33 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 193 sec, nreceivers=16, nsenders=1264
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 9 mins, 20 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 96 sec, nreceivers=16, nsenders=1264
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 44 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 48 sec, nreceivers=16, nsenders=1264
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 56 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 26 sec, nreceivers=16, nsenders=1264
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 33 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 26 sec, nreceivers=16, nsenders=1264
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 33 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 3083 sec, nreceivers=32, nsenders=1248
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 57 mins, 30 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 1541 sec, nreceivers=32, nsenders=1248
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 31 mins, 49 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 771 sec, nreceivers=32, nsenders=1248
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 18 mins, 58 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 385 sec, nreceivers=32, nsenders=1248
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 33 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 193 sec, nreceivers=32, nsenders=1248
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 9 mins, 20 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 96 sec, nreceivers=32, nsenders=1248
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 44 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 48 sec, nreceivers=32, nsenders=1248
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 56 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 26 sec, nreceivers=32, nsenders=1248
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 26 sec, nreceivers=32, nsenders=1248
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 26 sec, nreceivers=32, nsenders=1248
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 34 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 2055 sec, nreceivers=48, nsenders=1232
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 40 mins, 23 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 1028 sec, nreceivers=48, nsenders=1232
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 23 mins, 15 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 514 sec, nreceivers=48, nsenders=1232
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 14 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 257 sec, nreceivers=48, nsenders=1232
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 24 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 128 sec, nreceivers=48, nsenders=1232
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 16 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 64 sec, nreceivers=48, nsenders=1232
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 12 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 32 sec, nreceivers=48, nsenders=1232
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 26 sec, nreceivers=48, nsenders=1232
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 26 sec, nreceivers=48, nsenders=1232
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 26 sec, nreceivers=48, nsenders=1232
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 34 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 1541 sec, nreceivers=64, nsenders=1216
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 31 mins, 49 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 771 sec, nreceivers=64, nsenders=1216
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 18 mins, 58 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 385 sec, nreceivers=64, nsenders=1216
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 33 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 193 sec, nreceivers=64, nsenders=1216
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 9 mins, 20 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 96 sec, nreceivers=64, nsenders=1216
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 44 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 48 sec, nreceivers=64, nsenders=1216
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 56 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 27 sec, nreceivers=64, nsenders=1216
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 27 sec, nreceivers=64, nsenders=1216
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 27 sec, nreceivers=64, nsenders=1216
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 27 sec, nreceivers=64, nsenders=1216
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 34 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 1233 sec, nreceivers=80, nsenders=1200
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 26 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 617 sec, nreceivers=80, nsenders=1200
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 16 mins, 24 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 308 sec, nreceivers=80, nsenders=1200
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 16 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 154 sec, nreceivers=80, nsenders=1200
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 42 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 77 sec, nreceivers=80, nsenders=1200
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 25 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 39 sec, nreceivers=80, nsenders=1200
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 46 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 27 sec, nreceivers=80, nsenders=1200
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 27 sec, nreceivers=80, nsenders=1200
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 27 sec, nreceivers=80, nsenders=1200
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 27 sec, nreceivers=80, nsenders=1200
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 1028 sec, nreceivers=96, nsenders=1184
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 23 mins, 15 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 514 sec, nreceivers=96, nsenders=1184
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 14 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 257 sec, nreceivers=96, nsenders=1184
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 24 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 128 sec, nreceivers=96, nsenders=1184
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 16 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 64 sec, nreceivers=96, nsenders=1184
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 12 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 32 sec, nreceivers=96, nsenders=1184
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 27 sec, nreceivers=96, nsenders=1184
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 27 sec, nreceivers=96, nsenders=1184
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 27 sec, nreceivers=96, nsenders=1184
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 27 sec, nreceivers=96, nsenders=1184
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 881 sec, nreceivers=112, nsenders=1168
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 20 mins, 48 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 440 sec, nreceivers=112, nsenders=1168
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 13 mins, 28 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 220 sec, nreceivers=112, nsenders=1168
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 9 mins, 48 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 110 sec, nreceivers=112, nsenders=1168
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 58 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 55 sec, nreceivers=112, nsenders=1168
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 3 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 28 sec, nreceivers=112, nsenders=1168
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 28 sec, nreceivers=112, nsenders=1168
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 28 sec, nreceivers=112, nsenders=1168
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 28 sec, nreceivers=112, nsenders=1168
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 28 sec, nreceivers=112, nsenders=1168
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 35 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 771 sec, nreceivers=128, nsenders=1152
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 18 mins, 58 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 385 sec, nreceivers=128, nsenders=1152
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 33 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 193 sec, nreceivers=128, nsenders=1152
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 9 mins, 20 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 96 sec, nreceivers=128, nsenders=1152
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 44 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 48 sec, nreceivers=128, nsenders=1152
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 56 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 28 sec, nreceivers=128, nsenders=1152
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 36 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 28 sec, nreceivers=128, nsenders=1152
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 36 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 28 sec, nreceivers=128, nsenders=1152
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 36 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 28 sec, nreceivers=128, nsenders=1152
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 36 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 28 sec, nreceivers=128, nsenders=1152
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 36 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 685 sec, nreceivers=144, nsenders=1136
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 17 mins, 33 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 343 sec, nreceivers=144, nsenders=1136
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 50 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 171 sec, nreceivers=144, nsenders=1136
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 59 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 86 sec, nreceivers=144, nsenders=1136
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 33 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 43 sec, nreceivers=144, nsenders=1136
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 50 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 29 sec, nreceivers=144, nsenders=1136
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 36 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 29 sec, nreceivers=144, nsenders=1136
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 36 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 29 sec, nreceivers=144, nsenders=1136
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 36 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 29 sec, nreceivers=144, nsenders=1136
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 36 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 29 sec, nreceivers=144, nsenders=1136
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 36 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 617 sec, nreceivers=160, nsenders=1120
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 16 mins, 24 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 308 sec, nreceivers=160, nsenders=1120
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 16 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 154 sec, nreceivers=160, nsenders=1120
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 42 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 77 sec, nreceivers=160, nsenders=1120
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 25 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 39 sec, nreceivers=160, nsenders=1120
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 46 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 29 sec, nreceivers=160, nsenders=1120
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 36 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 29 sec, nreceivers=160, nsenders=1120
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 36 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 29 sec, nreceivers=160, nsenders=1120
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 37 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 29 sec, nreceivers=160, nsenders=1120
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 37 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 29 sec, nreceivers=160, nsenders=1120
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 37 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 560 sec, nreceivers=176, nsenders=1104
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 15 mins, 28 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 280 sec, nreceivers=176, nsenders=1104
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 48 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 140 sec, nreceivers=176, nsenders=1104
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 28 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 70 sec, nreceivers=176, nsenders=1104
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 18 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 35 sec, nreceivers=176, nsenders=1104
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 43 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 29 sec, nreceivers=176, nsenders=1104
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 37 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 29 sec, nreceivers=176, nsenders=1104
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 37 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 29 sec, nreceivers=176, nsenders=1104
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 37 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 29 sec, nreceivers=176, nsenders=1104
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 37 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 29 sec, nreceivers=176, nsenders=1104
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 37 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 514 sec, nreceivers=192, nsenders=1088
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 14 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 257 sec, nreceivers=192, nsenders=1088
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 24 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 128 sec, nreceivers=192, nsenders=1088
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 16 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 64 sec, nreceivers=192, nsenders=1088
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 12 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 32 sec, nreceivers=192, nsenders=1088
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 30 sec, nreceivers=192, nsenders=1088
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 37 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 30 sec, nreceivers=192, nsenders=1088
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 37 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 30 sec, nreceivers=192, nsenders=1088
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 37 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 30 sec, nreceivers=192, nsenders=1088
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 37 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 30 sec, nreceivers=192, nsenders=1088
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 474 sec, nreceivers=208, nsenders=1072
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 14 mins, 2 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 237 sec, nreceivers=208, nsenders=1072
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 5 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 119 sec, nreceivers=208, nsenders=1072
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 6 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 59 sec, nreceivers=208, nsenders=1072
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 7 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 30 sec, nreceivers=208, nsenders=1072
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 30 sec, nreceivers=208, nsenders=1072
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 30 sec, nreceivers=208, nsenders=1072
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 30 sec, nreceivers=208, nsenders=1072
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 30 sec, nreceivers=208, nsenders=1072
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 30 sec, nreceivers=208, nsenders=1072
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 440 sec, nreceivers=224, nsenders=1056
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 13 mins, 28 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 220 sec, nreceivers=224, nsenders=1056
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 9 mins, 48 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 110 sec, nreceivers=224, nsenders=1056
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 58 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 55 sec, nreceivers=224, nsenders=1056
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 3 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 31 sec, nreceivers=224, nsenders=1056
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 31 sec, nreceivers=224, nsenders=1056
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 31 sec, nreceivers=224, nsenders=1056
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 31 sec, nreceivers=224, nsenders=1056
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 31 sec, nreceivers=224, nsenders=1056
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 31 sec, nreceivers=224, nsenders=1056
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 38 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 411 sec, nreceivers=240, nsenders=1040
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 59 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 206 sec, nreceivers=240, nsenders=1040
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 9 mins, 33 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 103 sec, nreceivers=240, nsenders=1040
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 50 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 51 sec, nreceivers=240, nsenders=1040
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 59 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 31 sec, nreceivers=240, nsenders=1040
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 39 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 31 sec, nreceivers=240, nsenders=1040
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 39 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 31 sec, nreceivers=240, nsenders=1040
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 39 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 31 sec, nreceivers=240, nsenders=1040
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 39 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 31 sec, nreceivers=240, nsenders=1040
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 39 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 31 sec, nreceivers=240, nsenders=1040
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 39 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 385 sec, nreceivers=256, nsenders=1024
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 33 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 193 sec, nreceivers=256, nsenders=1024
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 9 mins, 20 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 96 sec, nreceivers=256, nsenders=1024
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 44 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 48 sec, nreceivers=256, nsenders=1024
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 56 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 32 sec, nreceivers=256, nsenders=1024
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 39 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 32 sec, nreceivers=256, nsenders=1024
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 39 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 32 sec, nreceivers=256, nsenders=1024
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 39 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 32 sec, nreceivers=256, nsenders=1024
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 39 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 32 sec, nreceivers=256, nsenders=1024
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 39 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 32 sec, nreceivers=256, nsenders=1024
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 39 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 363 sec, nreceivers=272, nsenders=1008
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 10 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 181 sec, nreceivers=272, nsenders=1008
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 9 mins, 9 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 91 sec, nreceivers=272, nsenders=1008
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 38 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 45 sec, nreceivers=272, nsenders=1008
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 53 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 32 sec, nreceivers=272, nsenders=1008
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 32 sec, nreceivers=272, nsenders=1008
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 32 sec, nreceivers=272, nsenders=1008
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 32 sec, nreceivers=272, nsenders=1008
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 32 sec, nreceivers=272, nsenders=1008
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 32 sec, nreceivers=272, nsenders=1008
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 343 sec, nreceivers=288, nsenders=992
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 50 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 171 sec, nreceivers=288, nsenders=992
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 59 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 86 sec, nreceivers=288, nsenders=992
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 33 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 43 sec, nreceivers=288, nsenders=992
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 50 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 33 sec, nreceivers=288, nsenders=992
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 33 sec, nreceivers=288, nsenders=992
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 33 sec, nreceivers=288, nsenders=992
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 33 sec, nreceivers=288, nsenders=992
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 33 sec, nreceivers=288, nsenders=992
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 33 sec, nreceivers=288, nsenders=992
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 40 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 324 sec, nreceivers=304, nsenders=976
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 32 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 162 sec, nreceivers=304, nsenders=976
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 50 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 81 sec, nreceivers=304, nsenders=976
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 29 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 41 sec, nreceivers=304, nsenders=976
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 48 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 33 sec, nreceivers=304, nsenders=976
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 33 sec, nreceivers=304, nsenders=976
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 33 sec, nreceivers=304, nsenders=976
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 33 sec, nreceivers=304, nsenders=976
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 33 sec, nreceivers=304, nsenders=976
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 33 sec, nreceivers=304, nsenders=976
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 41 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 308 sec, nreceivers=320, nsenders=960
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 16 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 154 sec, nreceivers=320, nsenders=960
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 42 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 77 sec, nreceivers=320, nsenders=960
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 25 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 39 sec, nreceivers=320, nsenders=960
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 46 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 34 sec, nreceivers=320, nsenders=960
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 34 sec, nreceivers=320, nsenders=960
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 34 sec, nreceivers=320, nsenders=960
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 34 sec, nreceivers=320, nsenders=960
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 34 sec, nreceivers=320, nsenders=960
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 41 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 34 sec, nreceivers=320, nsenders=960
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 42 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 294 sec, nreceivers=336, nsenders=944
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 1 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 147 sec, nreceivers=336, nsenders=944
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 73 sec, nreceivers=336, nsenders=944
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 7 mins, 21 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 37 sec, nreceivers=336, nsenders=944
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 44 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 34 sec, nreceivers=336, nsenders=944
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 42 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 34 sec, nreceivers=336, nsenders=944
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 42 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 34 sec, nreceivers=336, nsenders=944
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 42 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 34 sec, nreceivers=336, nsenders=944
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 42 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 34 sec, nreceivers=336, nsenders=944
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 42 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 34 sec, nreceivers=336, nsenders=944
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 6 mins, 42 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 280 sec, nreceivers=352, nsenders=928
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 48 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 140 sec, nreceivers=352, nsenders=928
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 8 mins, 28 sec
# -------------------------------------------------------------------------------------
# ...
# total time = 0 days, 9 hours, 9 mins, 54 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 253 sec, nreceivers=1152, nsenders=128
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 21 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 253 sec, nreceivers=1152, nsenders=128
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 21 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 253 sec, nreceivers=1152, nsenders=128
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 21 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 253 sec, nreceivers=1152, nsenders=128
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 21 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 253 sec, nreceivers=1152, nsenders=128
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 21 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 253 sec, nreceivers=1152, nsenders=128
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 21 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 253 sec, nreceivers=1152, nsenders=128
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 21 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 253 sec, nreceivers=1152, nsenders=128
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 21 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 253 sec, nreceivers=1152, nsenders=128
# phase_i=32768.0 sec, phase_ii=1 sec
# total time = 0 days, 9 hours, 10 mins, 22 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 253 sec, nreceivers=1152, nsenders=128
# phase_i=32768.0 sec, phase_ii=2 sec
# total time = 0 days, 9 hours, 10 mins, 23 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 290 sec, nreceivers=1168, nsenders=112
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 57 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 290 sec, nreceivers=1168, nsenders=112
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 57 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 290 sec, nreceivers=1168, nsenders=112
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 57 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 290 sec, nreceivers=1168, nsenders=112
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 57 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 290 sec, nreceivers=1168, nsenders=112
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 57 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 290 sec, nreceivers=1168, nsenders=112
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 57 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 290 sec, nreceivers=1168, nsenders=112
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 10 mins, 57 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 290 sec, nreceivers=1168, nsenders=112
# phase_i=32768.0 sec, phase_ii=1 sec
# total time = 0 days, 9 hours, 10 mins, 58 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 290 sec, nreceivers=1168, nsenders=112
# phase_i=32768.0 sec, phase_ii=1 sec
# total time = 0 days, 9 hours, 10 mins, 58 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 290 sec, nreceivers=1168, nsenders=112
# phase_i=32768.0 sec, phase_ii=2 sec
# total time = 0 days, 9 hours, 10 mins, 59 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 338 sec, nreceivers=1184, nsenders=96
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 45 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 338 sec, nreceivers=1184, nsenders=96
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 45 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 338 sec, nreceivers=1184, nsenders=96
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 45 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 338 sec, nreceivers=1184, nsenders=96
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 45 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 338 sec, nreceivers=1184, nsenders=96
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 45 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 338 sec, nreceivers=1184, nsenders=96
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 45 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 338 sec, nreceivers=1184, nsenders=96
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 11 mins, 46 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 338 sec, nreceivers=1184, nsenders=96
# phase_i=32768.0 sec, phase_ii=1 sec
# total time = 0 days, 9 hours, 11 mins, 46 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 338 sec, nreceivers=1184, nsenders=96
# phase_i=32768.0 sec, phase_ii=1 sec
# total time = 0 days, 9 hours, 11 mins, 47 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 338 sec, nreceivers=1184, nsenders=96
# phase_i=32768.0 sec, phase_ii=3 sec
# total time = 0 days, 9 hours, 11 mins, 48 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 405 sec, nreceivers=1200, nsenders=80
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 53 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 405 sec, nreceivers=1200, nsenders=80
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 53 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 405 sec, nreceivers=1200, nsenders=80
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 53 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 405 sec, nreceivers=1200, nsenders=80
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 53 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 405 sec, nreceivers=1200, nsenders=80
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 53 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 405 sec, nreceivers=1200, nsenders=80
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 53 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 405 sec, nreceivers=1200, nsenders=80
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 12 mins, 53 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 405 sec, nreceivers=1200, nsenders=80
# phase_i=32768.0 sec, phase_ii=1 sec
# total time = 0 days, 9 hours, 12 mins, 54 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 405 sec, nreceivers=1200, nsenders=80
# phase_i=32768.0 sec, phase_ii=2 sec
# total time = 0 days, 9 hours, 12 mins, 54 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 405 sec, nreceivers=1200, nsenders=80
# phase_i=32768.0 sec, phase_ii=3 sec
# total time = 0 days, 9 hours, 12 mins, 56 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 507 sec, nreceivers=1216, nsenders=64
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 14 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 507 sec, nreceivers=1216, nsenders=64
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 14 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 507 sec, nreceivers=1216, nsenders=64
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 14 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 507 sec, nreceivers=1216, nsenders=64
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 14 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 507 sec, nreceivers=1216, nsenders=64
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 14 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 507 sec, nreceivers=1216, nsenders=64
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 14 mins, 34 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 507 sec, nreceivers=1216, nsenders=64
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 14 mins, 35 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 507 sec, nreceivers=1216, nsenders=64
# phase_i=32768.0 sec, phase_ii=1 sec
# total time = 0 days, 9 hours, 14 mins, 35 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 507 sec, nreceivers=1216, nsenders=64
# phase_i=32768.0 sec, phase_ii=2 sec
# total time = 0 days, 9 hours, 14 mins, 36 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 507 sec, nreceivers=1216, nsenders=64
# phase_i=32768.0 sec, phase_ii=4 sec
# total time = 0 days, 9 hours, 14 mins, 38 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 676 sec, nreceivers=1232, nsenders=48
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 17 mins, 23 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 676 sec, nreceivers=1232, nsenders=48
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 17 mins, 23 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 676 sec, nreceivers=1232, nsenders=48
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 17 mins, 23 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 676 sec, nreceivers=1232, nsenders=48
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 17 mins, 23 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 676 sec, nreceivers=1232, nsenders=48
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 17 mins, 23 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 676 sec, nreceivers=1232, nsenders=48
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 17 mins, 23 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 676 sec, nreceivers=1232, nsenders=48
# phase_i=32768.0 sec, phase_ii=1 sec
# total time = 0 days, 9 hours, 17 mins, 24 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 676 sec, nreceivers=1232, nsenders=48
# phase_i=32768.0 sec, phase_ii=1 sec
# total time = 0 days, 9 hours, 17 mins, 24 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 676 sec, nreceivers=1232, nsenders=48
# phase_i=32768.0 sec, phase_ii=3 sec
# total time = 0 days, 9 hours, 17 mins, 26 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 676 sec, nreceivers=1232, nsenders=48
# phase_i=32768.0 sec, phase_ii=5 sec
# total time = 0 days, 9 hours, 17 mins, 28 sec
# =============================================
# -------------------------------------------------------------------------------------
# difficulty=0 => 1013 sec, nreceivers=1248, nsenders=32
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 23 mins, 1 sec
# -------------------------------------------------------------------------------------
# difficulty=1 => 1013 sec, nreceivers=1248, nsenders=32
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 23 mins, 1 sec
# -------------------------------------------------------------------------------------
# difficulty=2 => 1013 sec, nreceivers=1248, nsenders=32
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 23 mins, 1 sec
# -------------------------------------------------------------------------------------
# difficulty=3 => 1013 sec, nreceivers=1248, nsenders=32
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 23 mins, 1 sec
# -------------------------------------------------------------------------------------
# difficulty=4 => 1013 sec, nreceivers=1248, nsenders=32
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 23 mins, 1 sec
# -------------------------------------------------------------------------------------
# difficulty=5 => 1013 sec, nreceivers=1248, nsenders=32
# phase_i=32768.0 sec, phase_ii=0 sec
# total time = 0 days, 9 hours, 23 mins, 1 sec
# -------------------------------------------------------------------------------------
# difficulty=6 => 1013 sec, nreceivers=1248, nsenders=32
# phase_i=32768.0 sec, phase_ii=1 sec
# total time = 0 days, 9 hours, 23 mins, 2 sec
# -------------------------------------------------------------------------------------
# difficulty=7 => 1013 sec, nreceivers=1248, nsenders=32
# phase_i=32768.0 sec, phase_ii=2 sec
# total time = 0 days, 9 hours, 23 mins, 3 sec
# -------------------------------------------------------------------------------------
# difficulty=8 => 1013 sec, nreceivers=1248, nsenders=32
# phase_i=32768.0 sec, phase_ii=4 sec
# total time = 0 days, 9 hours, 23 mins, 5 sec
# -------------------------------------------------------------------------------------
# difficulty=9 => 1013 sec, nreceivers=1248, nsenders=32
# phase_i=32768.0 sec, phase_ii=8 sec
# total time = 0 days, 9 hours, 23 mins, 9 sec
# =============================================

# %%
print("-------------------------------------------------------------------------------------")
print(f"difficulty={best_diff} => nreceivers={best_nreceivers}, nsenders={best_nsenders}")
print(f"total time = {seconds_2_time(best_total_time)}")
# Out:
# -------------------------------------------------------------------------------------
# difficulty=7 => nreceivers=32, nsenders=1248
# total time = 0 days, 9 hours, 6 mins, 34 sec

# %%
def regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored):
    
    """ return number of seconds needed to regenerate the long message"""
    nsecs_sender = nhashes_stored / (nsenders*hashes_sec_core)
    nsecs_receiver = (nhashes_stored/(2**difficulty)) 
    nsecs_receiver = nsecs_receiver / (nreceivers*dict_add_sec)
    
    return max(nsecs_receiver, nsecs_sender)


def regen_msg_l(difficulty,
                nhashes_stored):
    """ return the max l can be constructed with difficulty """
    from math import log2
    
    return log2( (nhashes_stored/(2**difficulty)) )
    

def largest_n(l,
              nsenders,
              nreceivers,
              dict_queries_sec,
              hashes_sec_core,
              difficulty,
              t_sec):

    """
    Given an attack parameter what is the largest n can be attacked in t_sec
    """
    from math import log2

    nqueries_sec = min(nqueries_sender(nsenders, hashes_sec_core, difficulty),
                   nqueries_receiver(nreceivers, dict_queries_sec))

    return log2(nqueries_sec*t_sec) + l + difficulty



def find_best_parameters(nservers,
              server_memory,
              ncores_per_server,
              nhashes_stored,
              dict_queries_sec,
              dict_add_sec,
              hashes_sec_core,
              hashes_sec_phase_i,
              t_sec,
              phase_i_timeout=365*24*60*60):
    """
    Find the attack parameters that can attack the largest possible n in t_sec
    return dictionary contains attack parameters.
    phase_i_timeout by default 365 days, since it can be done offline
    phase_ii_reconstruct_timeout 
    """

    from math import log2
    from itertools import product

    memory = nservers * server_memory
    val_size_bytes = 4 # one entry size in the dictionary
    filling_rate = 0.93 # how many slots of the dictionary are used
    l_max = log2(filling_rate * memory / val_size_bytes)

    ncores = nservers * ncores_per_server

    best_difficulty = 0
    best_n = 0 # optimize: find largest n
    best_nsenders = 0
    best_time_phase_i = float('inf')
    largest_difficulty = 40
    best_l = 0
    
    for nsenders, difficulty in product(range(1, ncores-nservers + 1), range(0, largest_difficulty)):
        nreceivers = ncores - nsenders
        l = min(l_max, regen_msg_l(difficulty, nhashes_stored))

        #print(f"l={l}, nsenders={nsenders}, difficulty={difficulty}, l_regen = {regen_msg_l( difficulty, nhashes_stored)}")
        t_rgen_msg = regen_msg_time(nsenders,
                                    nreceivers,
                                    hashes_sec_core,
                                    dict_add_sec,
                                    difficulty,
                                    nhashes_stored)
        
        t_sec_after_regen_msg = t_sec - t_rgen_msg
        if ( t_sec_after_regen_msg <= 0):
            continue # skip this iteration since all time have been spent on regenrating the long message
        
        
        n = largest_n(l,
                      nsenders,
                      nreceivers,
                      dict_queries_sec,
                      hashes_sec_core,
                      difficulty,
                      t_sec_after_regen_msg)


        # better n, always update
        t_phase_i = phase_i_time(l, difficulty, hashes_sec_phase_i)
        
        if (n > best_n  and t_phase_i <= phase_i_timeout):
            best_n = n
            best_l = l
            best_difficulty = difficulty
            best_nsenders = nsenders
            #print(f"better_n = {best_n}, better_l={best_l}, better_difficulty={best_difficulty}, better_nsenders={best_nsenders}, t_phase_i={seconds_2_time(t_phase_i)}")
            


    return {"n": best_n, "l": best_l,
            "difficulty": best_difficulty,
            "nsenders": best_nsenders,
            "nreceivers": ncores - nsenders}

# %%
# %%time
# best parameters
best_parms = find_best_parameters(nservers,
                     server_memory,
                     ncores_per_server,
                     nhashes_stored,
                     dict_queries_sec,
                     dict_add_sec,
                     hashes_sec_core,
                     hashes_sec_phase_i,
                     t_sec)

print(best_parms)

nsenders = best_parms["nsenders"]
nreceivers = best_parms["nreceivers"]
difficulty = best_parms["difficulty"]
l = best_parms["l"]
# Out:
# {'n': 76.41361356496108, 'l': 32.0, 'difficulty': 0, 'nsenders': 4, 'nreceivers': 1}
# CPU times: user 25 ms, sys: 60 µs, total: 25.1 ms
# Wall time: 24.8 ms

# %%
# how long phase_i will take using the best parameters?
seconds_2_time(phase_i_time(l, difficulty, hashes_sec_phase_i))
# Out:
# '0 days, 0 hours, 2 mins, 8 sec'

# %%
# how long regenerating the long message again will take?
seconds_2_time(regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored))
# Out:
# '0 days, 0 hours, 6 mins, 25 sec'

# %%
from math import log2
dict_queries_sec = 2^22.963350
log2(33767312.397134)
# Out:
# 25.00912402135891
