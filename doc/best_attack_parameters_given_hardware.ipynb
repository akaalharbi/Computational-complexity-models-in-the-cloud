# %% [markdown]
# # Best attack parameters given a hardware
#
# We assume the attack parameters are $n$ and $l$. Also, denote $g$ to be the number of ignored bits.
#
# $p = \frac{2^l}{2^n}$ , this is a geometric random variable, thus we expect a collision after   $\#queries = \frac{2^n}{2^l} $
#
# Assume, we only accept digests that have certain number of zeros, denoted as $d$. Thus, we can pretend as we are working on small digests
# $$
# \begin{align}
# &\#queries = \frac{2^n}{2^l} \\
# &\#queries_{sec} \cdot t_{sec} = \frac{2^n}{2^l} \\
# \Rightarrow &n = log2\left(\#queries_{sec} \cdot t_{sec} \cdot 2^{n-l-d}  \right)
# \end{align}
# $$
#
#
# We have three point of views of $\#queries$
# - Senders: How many hashes they generate?
#     - Their speed will be affected by difficulty, but from their perspective the overall attack time doesn't change if the difficulty change (add explanation, later)
#     - $\#snd\_queries_{sec} = \frac{\#senders \cdot \#gen\_hashes_{sec}} {2^{d}}$
#
# - Receivers: How many hashes they can query the dicitonary.
#     - In their world, the higher the difficulty the better chance of hitting collision (since digests are technically shorter).
#     - $\#rcv\_queries_{sec} = \#receivers \cdot \#dict\_queries_{sec} $
#
# - Bandwith: This is how many hashes the network can carry in a second.
#     - From their perspective, difficulty reduces the rate of transmitted messages.
#     - $bdwth_queries_{sec} $
#
#
# Thus,
#
# $$\#queries_{sec} := min\left(snd\_queries_{sec}, rcv\_queries_{sec}, bdwth\_queries_{sec}\right)$$

# %%
# Numbers from Gros cluster, nancy, grid5000.fr
# find_dist overhead = 7%-9%
# hash_16x_avx (nancy: gros) ≈ 2^24.87hash/sec
# dict_add≈2^23.41 elm/sec
# dict_lookup ≈ 2^24.9337 elm/sec
# mpi_recv overhead = 10.71% (for regenerating message)


nservers = 100
server_memory = (96 - 20)*10^9 # 96 GB
ncores_per_server = 18
hashes_sec_core = 2^24.87
dict_queries_sec = 2^24.9337
t_sec =  2 * 24 * 3600
# how many hashes can oure compressed file 
nhashes_stored = 2^45 
hashes_sec_phase_i = 2^24.72
dict_add_sec = 2^23.41

# %%
# 1 core hashing power
# thd2 sha_avx512_16way  elapsed 1.78sec i.e. 898392.92 hashes/sec = 2^19.777 hashes, 57.4971 M


# Querying 100000000, took 2.22 sec i.e. 44977939.99 elm/sec = 2^25.4227 elm/sec 


def seconds_2_time(t):
    from math import floor

    t = float(t)
    days  = floor(t/(3600*24))
    t = t - days*24*3600

    hours = floor(t/3600)
    t = t - hours*3600
    minutes = floor(t/60)
    t = t - minutes*60

    return f"{days} days, {hours} hours, {minutes} mins, {floor(t)} sec"

print(f"server_memory={server_memory}")
# Out:
# server_memory=76000000000

# %%
def regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored):
    """ return number of seconds needed to regenerate the long message"""
    nsecs_sender = nhashes_stored / (nsenders*hashes_sec_core)
    nsecs_receiver = (nhashes_stored/(2**difficulty)) 
    nsecs_receiver = nsecs_receiver / (nreceivers*dict_add_sec)
    
    return max(nsecs_receiver, nsecs_sender)


def regen_msg_l(difficulty,
                nhashes_stored):
    """ return the max l can be constructed with difficulty """
    from math import log2
    
    return log2( (nhashes_stored/(2**difficulty)) )
    
def nqueries_sender(nsenders, hashes_sec_core, difficulty):
    """ Return how many queries senders can generate per second """

    return nsenders*hashes_sec_core/(2**difficulty)


def nqueries_receiver(nreceivers, dict_queries_sec):
    """
    Return how many queries receivers can make in a second
    """
    return nreceivers * dict_queries_sec

def phase_i_time(l, difficulty, hashes_sec_phase_i):
    """
    Return how many seconds it takes to complete phase_i
    """
    return 2^l * 2^difficulty / (hashes_sec_phase_i)


def largest_n(l,
              nsenders,
              nreceivers,
              dict_queries_sec,
              hashes_sec_core,
              difficulty,
              t_sec):

    """
    Given an attack parameter what is the largest n can be attacked in t_sec
    """
    from math import log2

    nqueries_sec = min(nqueries_sender(nsenders, hashes_sec_core, difficulty),
                   nqueries_receiver(nreceivers, dict_queries_sec))

    return log2(nqueries_sec*t_sec) + l + difficulty



def find_best_parameters(nservers,
              server_memory,
              ncores_per_server,
              nhashes_stored,
              dict_queries_sec,
              dict_add_sec,
              hashes_sec_core,
              hashes_sec_phase_i,
              t_sec,
              phase_i_timeout=36*24*60*60):
    """
    Find the attack parameters that can attack the largest possible n in t_sec
    return dictionary contains attack parameters.
    phase_i_timeout by default 365 days, since it can be done offline
    phase_ii_reconstruct_timeout 
    """

    from math import log2
    from itertools import product

    memory = nservers * server_memory
    val_size_bytes = 4 # one entry size in the dictionary
    filling_rate = 0.93 # how many slots of the dictionary are used
    l_max = log2(filling_rate * memory / val_size_bytes)

    ncores = nservers * ncores_per_server

    best_difficulty = 0
    best_n = 0 # optimize: find largest n
    best_nsenders = 0
    best_time_phase_i = float('inf')
    largest_difficulty = 40
    
    for nsenders, difficulty in product(range(1, ncores-nservers + 1), range(0, largest_difficulty)):
        nreceivers = ncores - nsenders
        l = min(l_max, regen_msg_l(difficulty, nhashes_stored))

        #print(f"l={l}, nsenders={nsenders}, difficulty={difficulty}, l_regen = {regen_msg_l( difficulty, nhashes_stored)}")
        t_rgen_msg = regen_msg_time(nsenders,
                                    nreceivers,
                                    hashes_sec_core,
                                    dict_add_sec,
                                    difficulty,
                                    nhashes_stored)
        
        t_sec_after_regen_msg = t_sec - t_rgen_msg
        if ( t_sec_after_regen_msg <= 0):
            continue # skip this iteration since all time have been spent on regenrating the long message
        
        
        n = largest_n(l,
                      nsenders,
                      nreceivers,
                      dict_queries_sec,
                      hashes_sec_core,
                      difficulty,
                      t_sec_after_regen_msg)


        # better n, always update
        t_phase_i = phase_i_time(l, difficulty, hashes_sec_phase_i)
        
        if (n > best_n  and t_phase_i <= phase_i_timeout):
            best_n = n
            best_l = l
            best_difficulty = difficulty
            best_nsenders = nsenders
            print(f"better_n = {best_n}, better_l={best_l}, better_difficulty={best_difficulty}, better_nsenders={best_nsenders}, t_phase_i={seconds_2_time(t_phase_i)}")
            


    return {"n": best_n, "l": best_l,
            "difficulty": best_difficulty,
            "nsenders": best_nsenders,
            "nreceivers": ncores - nsenders}

# %%
# %%time
# best parameters
best_parms = find_best_parameters(nservers,
                     server_memory,
                     ncores_per_server,
                     nhashes_stored,
                     dict_queries_sec,
                     dict_add_sec,
                     hashes_sec_core,
                     hashes_sec_phase_i,
                     t_sec)

print(best_parms)

nsenders = best_parms["nsenders"]
nreceivers = best_parms["nreceivers"]
difficulty = best_parms["difficulty"]
l = best_parms["l"] #+ best_parms["difficulty"]
# Out:
# better_n = 81.47790334733097, better_l=40.68443917853788, better_difficulty=0, better_nsenders=7, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 83.39643273241275, better_l=40.68443917853788, better_difficulty=0, better_nsenders=8, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 84.19176413330536, better_l=40.68443917853788, better_difficulty=0, better_nsenders=9, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 84.701499699296, better_l=40.68443917853788, better_difficulty=0, better_nsenders=10, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 85.07739972279728, better_l=40.68443917853788, better_difficulty=0, better_nsenders=11, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 85.37532535082369, better_l=40.68443917853788, better_difficulty=0, better_nsenders=12, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 85.62213334878373, better_l=40.68443917853788, better_difficulty=0, better_nsenders=13, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 85.83282271490216, better_l=40.68443917853788, better_difficulty=0, better_nsenders=14, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 86.01662777647414, better_l=40.68443917853788, better_difficulty=0, better_nsenders=15, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 86.17963956454832, better_l=40.68443917853788, better_difficulty=0, better_nsenders=16, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 86.32608813618214, better_l=40.68443917853788, better_difficulty=0, better_nsenders=17, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 86.45903109061462, better_l=40.68443917853788, better_difficulty=0, better_nsenders=18, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 86.58075045452988, better_l=40.68443917853788, better_difficulty=0, better_nsenders=19, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 86.69299465731586, better_l=40.68443917853788, better_difficulty=0, better_nsenders=20, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 86.79713292765405, better_l=40.68443917853788, better_difficulty=0, better_nsenders=21, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 86.89425759424228, better_l=40.68443917853788, better_difficulty=0, better_nsenders=22, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 86.98525405723944, better_l=40.68443917853788, better_difficulty=0, better_nsenders=23, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.07084996507692, better_l=40.68443917853788, better_difficulty=0, better_nsenders=24, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.15165059828615, better_l=40.68443917853788, better_difficulty=0, better_nsenders=25, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.22816485712931, better_l=40.68443917853788, better_difficulty=0, better_nsenders=26, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.30082469682695, better_l=40.68443917853788, better_difficulty=0, better_nsenders=27, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.36999989808196, better_l=40.68443917853788, better_difficulty=0, better_nsenders=28, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.43600945509081, better_l=40.68443917853788, better_difficulty=0, better_nsenders=29, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.49913047000649, better_l=40.68443917853788, better_difficulty=0, better_nsenders=30, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.5596051816485, better_l=40.68443917853788, better_difficulty=0, better_nsenders=31, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.61764657925582, better_l=40.68443917853788, better_difficulty=0, better_nsenders=32, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.67344292991001, better_l=40.68443917853788, better_difficulty=0, better_nsenders=33, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.72716146251858, better_l=40.68443917853788, better_difficulty=0, better_nsenders=34, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.77895139016042, better_l=40.68443917853788, better_difficulty=0, better_nsenders=35, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.82894640845751, better_l=40.68443917853788, better_difficulty=0, better_nsenders=36, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.87726677533738, better_l=40.68443917853788, better_difficulty=0, better_nsenders=37, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.92402105363102, better_l=40.68443917853788, better_difficulty=0, better_nsenders=38, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 87.96930758004424, better_l=40.68443917853788, better_difficulty=0, better_nsenders=39, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.01321571049426, better_l=40.68443917853788, better_difficulty=0, better_nsenders=40, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.05582688146288, better_l=40.68443917853788, better_difficulty=0, better_nsenders=41, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.09721551904968, better_l=40.68443917853788, better_difficulty=0, better_nsenders=42, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.13744982122051, better_l=40.68443917853788, better_difficulty=0, better_nsenders=43, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.17659243390243, better_l=40.68443917853788, better_difficulty=0, better_nsenders=44, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.21470103775536, better_l=40.68443917853788, better_difficulty=0, better_nsenders=45, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.2518288594184, better_l=40.68443917853788, better_difficulty=0, better_nsenders=46, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.28802511860358, better_l=40.68443917853788, better_difficulty=0, better_nsenders=47, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.3233354204614, better_l=40.68443917853788, better_difficulty=0, better_nsenders=48, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.3578021010652, better_l=40.68443917853788, better_difficulty=0, better_nsenders=49, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.3914645325797, better_l=40.68443917853788, better_difficulty=0, better_nsenders=50, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.42435939363097, better_l=40.68443917853788, better_difficulty=0, better_nsenders=51, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.456520909533, better_l=40.68443917853788, better_difficulty=0, better_nsenders=52, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.4879810663166, better_l=40.68443917853788, better_difficulty=0, better_nsenders=53, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.5187698019152, better_l=40.68443917853788, better_difficulty=0, better_nsenders=54, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.54891517737263, better_l=40.68443917853788, better_difficulty=0, better_nsenders=55, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.57844353052683, better_l=40.68443917853788, better_difficulty=0, better_nsenders=56, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.60737961427824, better_l=40.68443917853788, better_difficulty=0, better_nsenders=57, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.63574672126279, better_l=40.68443917853788, better_difficulty=0, better_nsenders=58, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.66356679650193, better_l=40.68443917853788, better_difficulty=0, better_nsenders=59, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.6908605393952, better_l=40.68443917853788, better_difficulty=0, better_nsenders=60, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.71764749624288, better_l=40.68443917853788, better_difficulty=0, better_nsenders=61, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.74394614433427, better_l=40.68443917853788, better_difficulty=0, better_nsenders=62, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.76977396850808, better_l=40.68443917853788, better_difficulty=0, better_nsenders=63, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.79514753097928, better_l=40.68443917853788, better_difficulty=0, better_nsenders=64, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.82008253513098, better_l=40.68443917853788, better_difficulty=0, better_nsenders=65, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.84459388388632, better_l=40.68443917853788, better_difficulty=0, better_nsenders=66, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.86869573320404, better_l=40.68443917853788, better_difficulty=0, better_nsenders=67, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.89240154117843, better_l=40.68443917853788, better_difficulty=0, better_nsenders=68, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.91572411317006, better_l=40.68443917853788, better_difficulty=0, better_nsenders=69, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.93867564334623, better_l=40.68443917853788, better_difficulty=0, better_nsenders=70, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.96126775296854, better_l=40.68443917853788, better_difficulty=0, better_nsenders=71, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 88.98351152572853, better_l=40.68443917853788, better_difficulty=0, better_nsenders=72, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.00541754040034, better_l=40.68443917853788, better_difficulty=0, better_nsenders=73, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.02699590105118, better_l=40.68443917853788, better_difficulty=0, better_nsenders=74, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.04825626502567, better_l=40.68443917853788, better_difficulty=0, better_nsenders=75, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.0692078688979, better_l=40.68443917853788, better_difficulty=0, better_nsenders=76, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.08985955256591, better_l=40.68443917853788, better_difficulty=0, better_nsenders=77, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.11021978164575, better_l=40.68443917853788, better_difficulty=0, better_nsenders=78, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.13029666830732, better_l=40.68443917853788, better_difficulty=0, better_nsenders=79, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.15009799068014, better_l=40.68443917853788, better_difficulty=0, better_nsenders=80, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.16963121094528, better_l=40.68443917853788, better_difficulty=0, better_nsenders=81, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.18890349221886, better_l=40.68443917853788, better_difficulty=0, better_nsenders=82, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.20792171432261, better_l=40.68443917853788, better_difficulty=0, better_nsenders=83, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.22669248852836, better_l=40.68443917853788, better_difficulty=0, better_nsenders=84, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.24522217135564, better_l=40.68443917853788, better_difficulty=0, better_nsenders=85, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.26351687749441, better_l=40.68443917853788, better_difficulty=0, better_nsenders=86, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.28158249191856, better_l=40.68443917853788, better_difficulty=0, better_nsenders=87, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.29942468125034, better_l=40.68443917853788, better_difficulty=0, better_nsenders=88, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.31704890443065, better_l=40.68443917853788, better_difficulty=0, better_nsenders=89, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.33446042274527, better_l=40.68443917853788, better_difficulty=0, better_nsenders=90, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.35166430925341, better_l=40.68443917853788, better_difficulty=0, better_nsenders=91, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.36866545766058, better_l=40.68443917853788, better_difficulty=0, better_nsenders=92, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.38546859067475, better_l=40.68443917853788, better_difficulty=0, better_nsenders=93, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.40207826788138, better_l=40.68443917853788, better_difficulty=0, better_nsenders=94, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.41849889317047, better_l=40.68443917853788, better_difficulty=0, better_nsenders=95, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.43473472174543, better_l=40.68443917853788, better_difficulty=0, better_nsenders=96, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.45078986674207, better_l=40.68443917853788, better_difficulty=0, better_nsenders=97, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.4666683054833, better_l=40.68443917853788, better_difficulty=0, better_nsenders=98, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.4823738853934, better_l=40.68443917853788, better_difficulty=0, better_nsenders=99, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.49791032959368, better_l=40.68443917853788, better_difficulty=0, better_nsenders=100, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.51328124220024, better_l=40.68443917853788, better_difficulty=0, better_nsenders=101, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.52849011334229, better_l=40.68443917853788, better_difficulty=0, better_nsenders=102, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.54354032391882, better_l=40.68443917853788, better_difficulty=0, better_nsenders=103, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.55843515010966, better_l=40.68443917853788, better_difficulty=0, better_nsenders=104, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.57317776765605, better_l=40.68443917853788, better_difficulty=0, better_nsenders=105, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.58777125592468, better_l=40.68443917853788, better_difficulty=0, better_nsenders=106, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.60221860176826, better_l=40.68443917853788, better_difficulty=0, better_nsenders=107, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.61652270319475, better_l=40.68443917853788, better_difficulty=0, better_nsenders=108, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.63068637285633, better_l=40.68443917853788, better_difficulty=0, better_nsenders=109, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.6447123413689, better_l=40.68443917853788, better_difficulty=0, better_nsenders=110, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.65860326047166, better_l=40.68443917853788, better_difficulty=0, better_nsenders=111, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.67236170603616, better_l=40.68443917853788, better_difficulty=0, better_nsenders=112, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.68599018093299, better_l=40.68443917853788, better_difficulty=0, better_nsenders=113, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.69949111776464, better_l=40.68443917853788, better_difficulty=0, better_nsenders=114, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.71286688147137, better_l=40.68443917853788, better_difficulty=0, better_nsenders=115, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.72611977181762, better_l=40.68443917853788, better_difficulty=0, better_nsenders=116, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.73925202576507, better_l=40.68443917853788, better_difficulty=0, better_nsenders=117, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.75226581973874, better_l=40.68443917853788, better_difficulty=0, better_nsenders=118, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.76516327179195, better_l=40.68443917853788, better_difficulty=0, better_nsenders=119, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.77794644367498, better_l=40.68443917853788, better_difficulty=0, better_nsenders=120, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.79061734281329, better_l=40.68443917853788, better_difficulty=0, better_nsenders=121, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.80317792419942, better_l=40.68443917853788, better_difficulty=0, better_nsenders=122, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.81563009220318, better_l=40.68443917853788, better_difficulty=0, better_nsenders=123, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.8279757023046, better_l=40.68443917853788, better_difficulty=0, better_nsenders=124, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.84021656275311, better_l=40.68443917853788, better_difficulty=0, better_nsenders=125, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.85235443615716, better_l=40.68443917853788, better_difficulty=0, better_nsenders=126, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.86439104100731, better_l=40.68443917853788, better_difficulty=0, better_nsenders=127, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.8763280531365, better_l=40.68443917853788, better_difficulty=0, better_nsenders=128, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.88816710712027, better_l=40.68443917853788, better_difficulty=0, better_nsenders=129, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.89990979761996, better_l=40.68443917853788, better_difficulty=0, better_nsenders=130, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.91155768067193, better_l=40.68443917853788, better_difficulty=0, better_nsenders=131, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.92311227492482, better_l=40.68443917853788, better_difficulty=0, better_nsenders=132, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.93457506282792, better_l=40.68443917853788, better_difficulty=0, better_nsenders=133, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.9459474917725, better_l=40.68443917853788, better_difficulty=0, better_nsenders=134, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.95723097518874, better_l=40.68443917853788, better_difficulty=0, better_nsenders=135, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.96842689359981, better_l=40.68443917853788, better_difficulty=0, better_nsenders=136, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.97953659563566, better_l=40.68443917853788, better_difficulty=0, better_nsenders=137, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 89.99056139900779, better_l=40.68443917853788, better_difficulty=0, better_nsenders=138, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.00150259144729, better_l=40.68443917853788, better_difficulty=0, better_nsenders=139, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.01236143160747, better_l=40.68443917853788, better_difficulty=0, better_nsenders=140, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.02313914993269, better_l=40.68443917853788, better_difficulty=0, better_nsenders=141, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.03383694949521, better_l=40.68443917853788, better_difficulty=0, better_nsenders=142, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.044456006801, better_l=40.68443917853788, better_difficulty=0, better_nsenders=143, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.05499747256624, better_l=40.68443917853788, better_difficulty=0, better_nsenders=144, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.06546247246567, better_l=40.68443917853788, better_difficulty=0, better_nsenders=145, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.07585210785388, better_l=40.68443917853788, better_difficulty=0, better_nsenders=146, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.08616745646088, better_l=40.68443917853788, better_difficulty=0, better_nsenders=147, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.09640957306314, better_l=40.68443917853788, better_difficulty=0, better_nsenders=148, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.10657949013057, better_l=40.68443917853788, better_difficulty=0, better_nsenders=149, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.11667821845128, better_l=40.68443917853788, better_difficulty=0, better_nsenders=150, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.12670674773449, better_l=40.68443917853788, better_difficulty=0, better_nsenders=151, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.13666604719236, better_l=40.68443917853788, better_difficulty=0, better_nsenders=152, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.14655706610237, better_l=40.68443917853788, better_difficulty=0, better_nsenders=153, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.15638073435017, better_l=40.68443917853788, better_difficulty=0, better_nsenders=154, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.16613796295411, better_l=40.68443917853788, better_difficulty=0, better_nsenders=155, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.17582964457242, better_l=40.68443917853788, better_difficulty=0, better_nsenders=156, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.1854566539931, better_l=40.68443917853788, better_difficulty=0, better_nsenders=157, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.1950198486079, better_l=40.68443917853788, better_difficulty=0, better_nsenders=158, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.20452006887041, better_l=40.68443917853788, better_difficulty=0, better_nsenders=159, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.21395813873943, better_l=40.68443917853788, better_difficulty=0, better_nsenders=160, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.22333486610769, better_l=40.68443917853788, better_difficulty=0, better_nsenders=161, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.23265104321695, better_l=40.68443917853788, better_difficulty=0, better_nsenders=162, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.24190744705959, better_l=40.68443917853788, better_difficulty=0, better_nsenders=163, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.25110483976752, better_l=40.68443917853788, better_difficulty=0, better_nsenders=164, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.26024396898876, better_l=40.68443917853788, better_difficulty=0, better_nsenders=165, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.26932556825206, better_l=40.68443917853788, better_difficulty=0, better_nsenders=166, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.27835035732028, better_l=40.68443917853788, better_difficulty=0, better_nsenders=167, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.28731904253269, better_l=40.68443917853788, better_difficulty=0, better_nsenders=168, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.29623231713666, better_l=40.68443917853788, better_difficulty=0, better_nsenders=169, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.30509086160929, better_l=40.68443917853788, better_difficulty=0, better_nsenders=170, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.31389534396908, better_l=40.68443917853788, better_difficulty=0, better_nsenders=171, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.32264642007823, better_l=40.68443917853788, better_difficulty=0, better_nsenders=172, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.33134473393591, better_l=40.68443917853788, better_difficulty=0, better_nsenders=173, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.33999091796248, better_l=40.68443917853788, better_difficulty=0, better_nsenders=174, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.34858559327559, better_l=40.68443917853788, better_difficulty=0, better_nsenders=175, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.35712936995776, better_l=40.68443917853788, better_difficulty=0, better_nsenders=176, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.36562284731639, better_l=40.68443917853788, better_difficulty=0, better_nsenders=177, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.37406661413593, better_l=40.68443917853788, better_difficulty=0, better_nsenders=178, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.38246124892284, better_l=40.68443917853788, better_difficulty=0, better_nsenders=179, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.39080732014338, better_l=40.68443917853788, better_difficulty=0, better_nsenders=180, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.39910538645472, better_l=40.68443917853788, better_difficulty=0, better_nsenders=181, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.4073559969292, better_l=40.68443917853788, better_difficulty=0, better_nsenders=182, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.41555969127242, better_l=40.68443917853788, better_difficulty=0, better_nsenders=183, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.42371700003507, better_l=40.68443917853788, better_difficulty=0, better_nsenders=184, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.43182844481882, better_l=40.68443917853788, better_difficulty=0, better_nsenders=185, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.4398945384765, better_l=40.68443917853788, better_difficulty=0, better_nsenders=186, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.44791578530655, better_l=40.68443917853788, better_difficulty=0, better_nsenders=187, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.45589268124237, better_l=40.68443917853788, better_difficulty=0, better_nsenders=188, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.46382571403626, better_l=40.68443917853788, better_difficulty=0, better_nsenders=189, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.47171536343828, better_l=40.68443917853788, better_difficulty=0, better_nsenders=190, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.4795621013705, better_l=40.68443917853788, better_difficulty=0, better_nsenders=191, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.48736639209629, better_l=40.68443917853788, better_difficulty=0, better_nsenders=192, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.49512869238518, better_l=40.68443917853788, better_difficulty=0, better_nsenders=193, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.50284945167326, better_l=40.68443917853788, better_difficulty=0, better_nsenders=194, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.51052911221933, better_l=40.68443917853788, better_difficulty=0, better_nsenders=195, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.518168109257, better_l=40.68443917853788, better_difficulty=0, better_nsenders=196, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.52576687114254, better_l=40.68443917853788, better_difficulty=0, better_nsenders=197, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.53332581949914, better_l=40.68443917853788, better_difficulty=0, better_nsenders=198, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.54084536935724, better_l=40.68443917853788, better_difficulty=0, better_nsenders=199, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.54832592929131, better_l=40.68443917853788, better_difficulty=0, better_nsenders=200, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.55576790155297, better_l=40.68443917853788, better_difficulty=0, better_nsenders=201, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.56317168220086, better_l=40.68443917853788, better_difficulty=0, better_nsenders=202, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.57053766122715, better_l=40.68443917853788, better_difficulty=0, better_nsenders=203, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.57786622268068, better_l=40.68443917853788, better_difficulty=0, better_nsenders=204, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.58515774478727, better_l=40.68443917853788, better_difficulty=0, better_nsenders=205, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.59241260006671, better_l=40.68443917853788, better_difficulty=0, better_nsenders=206, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.59963115544704, better_l=40.68443917853788, better_difficulty=0, better_nsenders=207, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.60681377237592, better_l=40.68443917853788, better_difficulty=0, better_nsenders=208, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.61396080692916, better_l=40.68443917853788, better_difficulty=0, better_nsenders=209, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.62107260991668, better_l=40.68443917853788, better_difficulty=0, better_nsenders=210, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.62814952698588, better_l=40.68443917853788, better_difficulty=0, better_nsenders=211, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.63519189872235, better_l=40.68443917853788, better_difficulty=0, better_nsenders=212, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.64220006074832, better_l=40.68443917853788, better_difficulty=0, better_nsenders=213, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.64917434381857, better_l=40.68443917853788, better_difficulty=0, better_nsenders=214, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.6561150739141, better_l=40.68443917853788, better_difficulty=0, better_nsenders=215, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.6630225723336, better_l=40.68443917853788, better_difficulty=0, better_nsenders=216, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.6698971557827, better_l=40.68443917853788, better_difficulty=0, better_nsenders=217, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.67673913646104, better_l=40.68443917853788, better_difficulty=0, better_nsenders=218, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.68354882214736, better_l=40.68443917853788, better_difficulty=0, better_nsenders=219, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.69032651628265, better_l=40.68443917853788, better_difficulty=0, better_nsenders=220, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.69707251805121, better_l=40.68443917853788, better_difficulty=0, better_nsenders=221, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.7037871224599, better_l=40.68443917853788, better_difficulty=0, better_nsenders=222, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.7104706204156, better_l=40.68443917853788, better_difficulty=0, better_nsenders=223, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.7171232988008, better_l=40.68443917853788, better_difficulty=0, better_nsenders=224, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.72374544054746, better_l=40.68443917853788, better_difficulty=0, better_nsenders=225, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.7303373247093, better_l=40.68443917853788, better_difficulty=0, better_nsenders=226, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.73689922653224, better_l=40.68443917853788, better_difficulty=0, better_nsenders=227, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.74343141752351, better_l=40.68443917853788, better_difficulty=0, better_nsenders=228, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.74993416551892, better_l=40.68443917853788, better_difficulty=0, better_nsenders=229, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.75640773474883, better_l=40.68443917853788, better_difficulty=0, better_nsenders=230, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.76285238590256, better_l=40.68443917853788, better_difficulty=0, better_nsenders=231, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.76926837619139, better_l=40.68443917853788, better_difficulty=0, better_nsenders=232, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.77565595941013, better_l=40.68443917853788, better_difficulty=0, better_nsenders=233, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.78201538599737, better_l=40.68443917853788, better_difficulty=0, better_nsenders=234, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.78834690309444, better_l=40.68443917853788, better_difficulty=0, better_nsenders=235, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.79465075460297, better_l=40.68443917853788, better_difficulty=0, better_nsenders=236, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.8009271812413, better_l=40.68443917853788, better_difficulty=0, better_nsenders=237, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.80717642059969, better_l=40.68443917853788, better_difficulty=0, better_nsenders=238, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.81339870719418, better_l=40.68443917853788, better_difficulty=0, better_nsenders=239, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.81959427251945, better_l=40.68443917853788, better_difficulty=0, better_nsenders=240, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.82576334510054, better_l=40.68443917853788, better_difficulty=0, better_nsenders=241, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.83190615054335, better_l=40.68443917853788, better_difficulty=0, better_nsenders=242, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.8380229115842, better_l=40.68443917853788, better_difficulty=0, better_nsenders=243, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.8441138481383, better_l=40.68443917853788, better_difficulty=0, better_nsenders=244, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.85017917734712, better_l=40.68443917853788, better_difficulty=0, better_nsenders=245, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.85621911362492, better_l=40.68443917853788, better_difficulty=0, better_nsenders=246, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.86223386870418, better_l=40.68443917853788, better_difficulty=0, better_nsenders=247, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.86822365168018, better_l=40.68443917853788, better_difficulty=0, better_nsenders=248, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.87418866905458, better_l=40.68443917853788, better_difficulty=0, better_nsenders=249, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.88012912477811, better_l=40.68443917853788, better_difficulty=0, better_nsenders=250, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.88604522029252, better_l=40.68443917853788, better_difficulty=0, better_nsenders=251, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.89193715457145, better_l=40.68443917853788, better_difficulty=0, better_nsenders=252, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.89780512416064, better_l=40.68443917853788, better_difficulty=0, better_nsenders=253, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.9036493232173, better_l=40.68443917853788, better_difficulty=0, better_nsenders=254, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.90946994354856, better_l=40.68443917853788, better_difficulty=0, better_nsenders=255, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.91526717464936, better_l=40.68443917853788, better_difficulty=0, better_nsenders=256, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.9210412037394, better_l=40.68443917853788, better_difficulty=0, better_nsenders=257, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.92679221579941, better_l=40.68443917853788, better_difficulty=0, better_nsenders=258, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.93252039360672, better_l=40.68443917853788, better_difficulty=0, better_nsenders=259, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.9382259177702, better_l=40.68443917853788, better_difficulty=0, better_nsenders=260, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.94390896676424, better_l=40.68443917853788, better_difficulty=0, better_nsenders=261, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.94956971696249, better_l=40.68443917853788, better_difficulty=0, better_nsenders=262, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.95520834267043, better_l=40.68443917853788, better_difficulty=0, better_nsenders=263, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.96082501615788, better_l=40.68443917853788, better_difficulty=0, better_nsenders=264, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.96641990769032, better_l=40.68443917853788, better_difficulty=0, better_nsenders=265, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.97199318556, better_l=40.68443917853788, better_difficulty=0, better_nsenders=266, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.97754501611624, better_l=40.68443917853788, better_difficulty=0, better_nsenders=267, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.98307556379532, better_l=40.68443917853788, better_difficulty=0, better_nsenders=268, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.98858499114962, better_l=40.68443917853788, better_difficulty=0, better_nsenders=269, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.9940734588763, better_l=40.68443917853788, better_difficulty=0, better_nsenders=270, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 90.99954112584541, better_l=40.68443917853788, better_difficulty=0, better_nsenders=271, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.00498814912758, better_l=40.68443917853788, better_difficulty=0, better_nsenders=272, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.01041468402097, better_l=40.68443917853788, better_difficulty=0, better_nsenders=273, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.01582088407791, better_l=40.68443917853788, better_difficulty=0, better_nsenders=274, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.02120690113094, better_l=40.68443917853788, better_difficulty=0, better_nsenders=275, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.02657288531842, better_l=40.68443917853788, better_difficulty=0, better_nsenders=276, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.03191898510963, better_l=40.68443917853788, better_difficulty=0, better_nsenders=277, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.03724534732942, better_l=40.68443917853788, better_difficulty=0, better_nsenders=278, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.04255211718238, better_l=40.68443917853788, better_difficulty=0, better_nsenders=279, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.04783943827667, better_l=40.68443917853788, better_difficulty=0, better_nsenders=280, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.05310745264723, better_l=40.68443917853788, better_difficulty=0, better_nsenders=281, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.05835630077877, better_l=40.68443917853788, better_difficulty=0, better_nsenders=282, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.06358612162818, better_l=40.68443917853788, better_difficulty=0, better_nsenders=283, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.06879705264664, better_l=40.68443917853788, better_difficulty=0, better_nsenders=284, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.07398922980131, better_l=40.68443917853788, better_difficulty=0, better_nsenders=285, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.07916278759657, better_l=40.68443917853788, better_difficulty=0, better_nsenders=286, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.08431785909497, better_l=40.68443917853788, better_difficulty=0, better_nsenders=287, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.08945457593774, better_l=40.68443917853788, better_difficulty=0, better_nsenders=288, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.09457306836495, better_l=40.68443917853788, better_difficulty=0, better_nsenders=289, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.09967346523536, better_l=40.68443917853788, better_difficulty=0, better_nsenders=290, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.1047558940459, better_l=40.68443917853788, better_difficulty=0, better_nsenders=291, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.10982048095067, better_l=40.68443917853788, better_difficulty=0, better_nsenders=292, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.11486735077993, better_l=40.68443917853788, better_difficulty=0, better_nsenders=293, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.11989662705838, better_l=40.68443917853788, better_difficulty=0, better_nsenders=294, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.12490843202337, better_l=40.68443917853788, better_difficulty=0, better_nsenders=295, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.12990288664278, better_l=40.68443917853788, better_difficulty=0, better_nsenders=296, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.13488011063245, better_l=40.68443917853788, better_difficulty=0, better_nsenders=297, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.13984022247342, better_l=40.68443917853788, better_difficulty=0, better_nsenders=298, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.14478333942893, better_l=40.68443917853788, better_difficulty=0, better_nsenders=299, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.14970957756091, better_l=40.68443917853788, better_difficulty=0, better_nsenders=300, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.15461905174647, better_l=40.68443917853788, better_difficulty=0, better_nsenders=301, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.15951187569391, better_l=40.68443917853788, better_difficulty=0, better_nsenders=302, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.16438816195853, better_l=40.68443917853788, better_difficulty=0, better_nsenders=303, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.16924802195814, better_l=40.68443917853788, better_difficulty=0, better_nsenders=304, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.17409156598842, better_l=40.68443917853788, better_difficulty=0, better_nsenders=305, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.1789189032378, better_l=40.68443917853788, better_difficulty=0, better_nsenders=306, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.18373014180239, better_l=40.68443917853788, better_difficulty=0, better_nsenders=307, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.18852538870036, better_l=40.68443917853788, better_difficulty=0, better_nsenders=308, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.19330474988632, better_l=40.68443917853788, better_difficulty=0, better_nsenders=309, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.19806833026533, better_l=40.68443917853788, better_difficulty=0, better_nsenders=310, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.20281623370673, better_l=40.68443917853788, better_difficulty=0, better_nsenders=311, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.20754856305771, better_l=40.68443917853788, better_difficulty=0, better_nsenders=312, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.21226542015668, better_l=40.68443917853788, better_difficulty=0, better_nsenders=313, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.21696690584643, better_l=40.68443917853788, better_difficulty=0, better_nsenders=314, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.22165311998708, better_l=40.68443917853788, better_difficulty=0, better_nsenders=315, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.2263241614688, better_l=40.68443917853788, better_difficulty=0, better_nsenders=316, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.23098012822425, better_l=40.68443917853788, better_difficulty=0, better_nsenders=317, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.23562111724107, better_l=40.68443917853788, better_difficulty=0, better_nsenders=318, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.24024722457384, better_l=40.68443917853788, better_difficulty=0, better_nsenders=319, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.2448585453561, better_l=40.68443917853788, better_difficulty=0, better_nsenders=320, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.24945517381201, better_l=40.68443917853788, better_difficulty=0, better_nsenders=321, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.25403720326807, better_l=40.68443917853788, better_difficulty=0, better_nsenders=322, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.25860472616424, better_l=40.68443917853788, better_difficulty=0, better_nsenders=323, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.26315783406532, better_l=40.68443917853788, better_difficulty=0, better_nsenders=324, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.26769661767196, better_l=40.68443917853788, better_difficulty=0, better_nsenders=325, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.27222116683134, better_l=40.68443917853788, better_difficulty=0, better_nsenders=326, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.27673157054804, better_l=40.68443917853788, better_difficulty=0, better_nsenders=327, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.28122791699442, better_l=40.68443917853788, better_difficulty=0, better_nsenders=328, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.28571029352098, better_l=40.68443917853788, better_difficulty=0, better_nsenders=329, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.29017878666659, better_l=40.68443917853788, better_difficulty=0, better_nsenders=330, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.29463348216848, better_l=40.68443917853788, better_difficulty=0, better_nsenders=331, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.29907446497211, better_l=40.68443917853788, better_difficulty=0, better_nsenders=332, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.30350181924086, better_l=40.68443917853788, better_difficulty=0, better_nsenders=333, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.3079156283657, better_l=40.68443917853788, better_difficulty=0, better_nsenders=334, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.31231597497452, better_l=40.68443917853788, better_difficulty=0, better_nsenders=335, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.31670294094141, better_l=40.68443917853788, better_difficulty=0, better_nsenders=336, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.3210766073959, better_l=40.68443917853788, better_difficulty=0, better_nsenders=337, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.3254370547318, better_l=40.68443917853788, better_difficulty=0, better_nsenders=338, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.32978436261622, better_l=40.68443917853788, better_difficulty=0, better_nsenders=339, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# better_n = 91.33411860999826, better_l=40.68443917853788, better_difficulty=0, better_nsenders=340, t_phase_i=0 days, 17 hours, 45 mins, 40 sec
# ...
# better_n = 93.58099800661819, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1591, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.58186640695382, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1592, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.58273386892293, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1593, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.58360038784919, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1594, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.58446595894947, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1595, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.58533057733123, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1596, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.58619423798984, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1597, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.58705693580582, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1598, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.58791866554208, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1599, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.58877942184091, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1600, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.5896391992211, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1601, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.59049799207472, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1602, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.59135579466403, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1603, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.59221260111812, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1604, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.59306840542959, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1605, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.59392320145105, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1606, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.59477698289142, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1607, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.59562974331237, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1608, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.59648147612438, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1609, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.59733217458282, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1610, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.59818183178388, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1611, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.59903044066034, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1612, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.59987799397726, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1613, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.60072448432747, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1614, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.60156990412692, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1615, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.60241424560994, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1616, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.60325750082424, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1617, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.60409966162592, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1618, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.60494071967406, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1619, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.60578066642533, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1620, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.60661949312839, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1621, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.60745719081802, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1622, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.60829375030909, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1623, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.60912916219037, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1624, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.60996341681809, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1625, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.6107965043092, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1626, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.61162841453458, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1627, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.61245913711181, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1628, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.61328866139783, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1629, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.61411697648128, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1630, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.61494407117453, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1631, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.61576993400554, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1632, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.61659455320932, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1633, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.6174179167191, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1634, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.61824001215723, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1635, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.61906082682566, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1636, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.61988034769618, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1637, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.62069856140016, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1638, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.62151545421807, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1639, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.6223310120684, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1640, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.62314522049644, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1641, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.62395806466225, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1642, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.6247695293286, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1643, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.62557959884813, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1644, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.62638825715007, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1645, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.62719548772658, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1646, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.62800127361838, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1647, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.62880559739993, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1648, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.62960844116397, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1649, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.6304097865054, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1650, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.63120961450458, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1651, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.63200790571, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1652, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.63280464011996, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1653, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.63359979716392, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1654, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.63439335568273, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1655, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.63518529390815, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1656, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.63597558944154, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1657, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.63676421923165, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1658, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.63755115955132, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1659, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.63833638597339, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1660, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.63911987334546, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1661, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.63990159576343, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1662, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64068152654414, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1663, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64145963819654, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1664, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64223590239175, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1665, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64301028993171, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1666, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64378277071634, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1667, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64455331370934, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1668, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64532188690231, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1669, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64608845727724, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1670, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64685299076731, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1671, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64761545221566, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1672, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64837580533244, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1673, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64913401264961, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1674, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.64989003547372, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1675, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.65064383383626, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1676, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.6513953664416, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1677, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.65214459061252, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1678, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.65289146223274, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1679, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.65363593568682, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1680, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.65437796379686, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1681, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.65511749775605, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1682, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.65585448705876, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1683, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.65658887942698, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1684, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.6573206207329, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1685, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.6580496549175, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1686, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.65877592390467, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1687, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.65949936751065, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1688, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.66021992334879, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1689, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.6609375267289, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1690, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.661652110551, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1691, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.66236360519332, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1692, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.66307193839376, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1693, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.66377703512481, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1694, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.66447881746117, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1695, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.66517720443963, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1696, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.66587211191097, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1697, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# better_n = 93.66656345238277, better_l=40.68443917853788, better_difficulty=4, better_nsenders=1698, t_phase_i=11 days, 20 hours, 10 mins, 45 sec
# {'n': 93.66656345238277, 'l': 40.68443917853788, 'difficulty': 4, 'nsenders': 1698, 'nreceivers': 100}
# CPU times: user 1.1 s, sys: 33.3 ms, total: 1.14 s
# Wall time: 1.1 s

# %%
# how long phase_i will take using the best parameters?
seconds_2_time(phase_i_time(l, difficulty, hashes_sec_phase_i))
# Out:
# '11 days, 20 hours, 10 mins, 45 sec'

# %%
# how long regenerating the long message again will take?
seconds_2_time(regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored))
# Out:
# '0 days, 0 hours, 32 mins, 52 sec'
