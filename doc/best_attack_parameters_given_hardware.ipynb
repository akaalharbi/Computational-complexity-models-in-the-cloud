# %% [markdown]
# # Best attack parameters given a hardware
#
# We assume the attack parameters are $n$ and $l$. Also, denote $g$ to be the number of ignored bits.
#
# $p = \frac{2^l}{2^n}$ , this is a geometric random variable, thus we expect a collision after   $\#queries = \frac{2^n}{2^l} $
#
# Assume, we only accept digests that have certain number of zeros, denoted as $d$. Thus, we can pretend as we are working on small digests
# $$
# \begin{align}
# &\#queries = \frac{2^n}{2^l} \\
# &\#queries_{sec} \cdot t_{sec} = \frac{2^n}{2^l}
# \end{align}
# $$
#
#
# We have three point of views of $\#queries$
# - Senders: How many hashes they generate?
#     - Their speed will be affected by difficulty, but from their perspective the overall attack time doesn't change if the difficulty change (add explanation, later)
#
#     - $\#snd\_queries_{sec} = \frac{\#senders \cdot \#gen\_hashes_{sec}} {2^{d}}$
#     - so, $\#queries_{sec} \cdot t_{sec} = \frac{2^n}{2^{l}}$
#
# - Receivers: How many hashes they can query the dicitonary.
#     - In their world, the higher the difficulty the better chance of hitting collision (since digests are technically shorter).
#     - $\#rcv\_queries_{sec} = \#receivers \cdot \#dict\_queries_{sec} $
#     - but $\#queries_{sec} \cdot t_{sec} = \frac{2^n}{2^{l+d}}$
#
# - Bandwith: This is how many hashes the network can carry in a second.
#     - From their perspective, difficulty reduces the rate of transmitted messages.
#     - $bdwth_queries_{sec} $
#
#
# Thus,
#
# $$\#queries_{sec} := min\left(snd\_queries_{sec}, rcv\_queries_{sec}, bdwth\_queries_{sec}\right)$$

# %%
# Numbers from Gros cluster, nancy, grid5000.fr
# find_dist overhead = 7%-9%
# hash_16x_avx (nancy: gros) ≈ 2^24.87hash/sec
# dict_add≈2^23.41 elm/sec
# dict_lookup ≈ 2^24.9337 elm/sec
# mpi_recv overhead = 10.71% (for regenerating message)


nservers = 32
server_memory = (196 - 20)*10^9 # 96 GB
ncores_per_server = 32
hashes_sec_core = 2^24.87
dict_queries_sec = 2^21.863350
t_sec =  2 * 24 * 3600
# how many hashes can oure compressed file 
nhashes_stored = 2^60
hashes_sec_phase_i = 2^24.72
dict_add_sec = 2^23.41

# %%
# 1 core hashing power
# thd2 sha_avx512_16way  elapsed 1.78sec i.e. 898392.92 hashes/sec = 2^19.777 hashes, 57.4971 M


# Querying 100000000, took 2.22 sec i.e. 44977939.99 elm/sec = 2^25.4227 elm/sec 


def seconds_2_time(t):
    from math import floor
    t = float(t)
    days  = floor(t/(3600*24))
    t = t - days*24*3600
    hours = floor(t/3600)
    t = t - hours*3600
    minutes = floor(t/60)
    t = t - minutes*60

    return f"{days} days, {hours} hours, {minutes} mins, {floor(t)} sec"

print(f"server_memory={server_memory}")
# Out:
# server_memory=176000000000

# %%
def regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored):
    """ return number of seconds needed to regenerate the long message"""
    nsecs_sender = nhashes_stored / (nsenders*hashes_sec_core)
    nsecs_receiver = (nhashes_stored/(2**difficulty)) 
    nsecs_receiver = nsecs_receiver / (nreceivers*dict_add_sec)
    
    return max(nsecs_receiver, nsecs_sender)


def regen_msg_l(difficulty,
                nhashes_stored):
    """ return the max l can be constructed with difficulty """
    from math import log2
    
    return log2( (nhashes_stored/(2**difficulty)) )
    
def nqueries_sender(nsenders, hashes_sec_core, difficulty):
    """ Return how many queries senders can generate per second """

    return nsenders*hashes_sec_core/(2**difficulty)


def nqueries_receiver(nreceivers, dict_queries_sec):
    """
    Return how many queries receivers can make in a second
    """
    return nreceivers * dict_queries_sec

def phase_i_time(l, difficulty, hashes_sec_phase_i):
    """
    Return how many seconds it takes to complete phase_i
    """
    return 2^l * 2^difficulty / (hashes_sec_phase_i)

# %%
regen_msg_time(1,
               1,
               hashes_sec_core,
               dict_add_sec,
               6,
               2^29)
# Out:
# 17.5086992201718

# %%
print("Regenerating the long message will take ... ")
from math import log2
nservers = 32
ncores_per_server = 32
for nreceivers in range(nservers, nservers*ncores_per_server - nservers, nservers):
    nsenders = (ncores_per_server)*nservers - nreceivers
    #nreceivers = 2*nservers
    for diff in range(10):

        time_needed = regen_msg_time(nsenders,
                                     nreceivers, # nsenders
                                     hashes_sec_core,
                                     dict_add_sec,
                                     diff, # difficulty
                                     2^(42) # nhashes stored
                                    ) # 25 our experimented interval, 4 because sha2-16way, log2(nsenders) that how  we truncate the #states 

        print(f"difficulty={diff} => {time_needed} sec, nreceivers={nreceivers}, nsenders={nsenders}")
    print("=============================================")
# Out:
# Regenerating the long message will take ...
# difficulty=0 => 12330.9813547915 sec, nreceivers=32, nsenders=992
# difficulty=1 => 6165.49067739573 sec, nreceivers=32, nsenders=992
# difficulty=2 => 3082.74533869787 sec, nreceivers=32, nsenders=992
# difficulty=3 => 1541.37266934893 sec, nreceivers=32, nsenders=992
# difficulty=4 => 770.686334674466 sec, nreceivers=32, nsenders=992
# difficulty=5 => 385.343167337233 sec, nreceivers=32, nsenders=992
# difficulty=6 => 192.671583668617 sec, nreceivers=32, nsenders=992
# difficulty=7 => 144.587967753677 sec, nreceivers=32, nsenders=992
# difficulty=8 => 144.587967753677 sec, nreceivers=32, nsenders=992
# difficulty=9 => 144.587967753677 sec, nreceivers=32, nsenders=992
# =============================================
# difficulty=0 => 6165.49067739573 sec, nreceivers=64, nsenders=960
# difficulty=1 => 3082.74533869787 sec, nreceivers=64, nsenders=960
# difficulty=2 => 1541.37266934893 sec, nreceivers=64, nsenders=960
# difficulty=3 => 770.686334674466 sec, nreceivers=64, nsenders=960
# difficulty=4 => 385.343167337233 sec, nreceivers=64, nsenders=960
# difficulty=5 => 192.671583668617 sec, nreceivers=64, nsenders=960
# difficulty=6 => 149.407566678800 sec, nreceivers=64, nsenders=960
# difficulty=7 => 149.407566678800 sec, nreceivers=64, nsenders=960
# difficulty=8 => 149.407566678800 sec, nreceivers=64, nsenders=960
# difficulty=9 => 149.407566678800 sec, nreceivers=64, nsenders=960
# =============================================
# difficulty=0 => 4110.32711826382 sec, nreceivers=96, nsenders=928
# difficulty=1 => 2055.16355913191 sec, nreceivers=96, nsenders=928
# difficulty=2 => 1027.58177956596 sec, nreceivers=96, nsenders=928
# difficulty=3 => 513.790889782978 sec, nreceivers=96, nsenders=928
# difficulty=4 => 256.895444891489 sec, nreceivers=96, nsenders=928
# difficulty=5 => 154.559551736689 sec, nreceivers=96, nsenders=928
# difficulty=6 => 154.559551736689 sec, nreceivers=96, nsenders=928
# difficulty=7 => 154.559551736689 sec, nreceivers=96, nsenders=928
# difficulty=8 => 154.559551736689 sec, nreceivers=96, nsenders=928
# difficulty=9 => 154.559551736689 sec, nreceivers=96, nsenders=928
# =============================================
# difficulty=0 => 3082.74533869787 sec, nreceivers=128, nsenders=896
# difficulty=1 => 1541.37266934893 sec, nreceivers=128, nsenders=896
# difficulty=2 => 770.686334674466 sec, nreceivers=128, nsenders=896
# difficulty=3 => 385.343167337233 sec, nreceivers=128, nsenders=896
# difficulty=4 => 192.671583668617 sec, nreceivers=128, nsenders=896
# difficulty=5 => 160.079535727285 sec, nreceivers=128, nsenders=896
# difficulty=6 => 160.079535727285 sec, nreceivers=128, nsenders=896
# difficulty=7 => 160.079535727285 sec, nreceivers=128, nsenders=896
# difficulty=8 => 160.079535727285 sec, nreceivers=128, nsenders=896
# difficulty=9 => 160.079535727285 sec, nreceivers=128, nsenders=896
# =============================================
# difficulty=0 => 2466.19627095829 sec, nreceivers=160, nsenders=864
# difficulty=1 => 1233.09813547915 sec, nreceivers=160, nsenders=864
# difficulty=2 => 616.549067739573 sec, nreceivers=160, nsenders=864
# difficulty=3 => 308.274533869787 sec, nreceivers=160, nsenders=864
# difficulty=4 => 166.008407420888 sec, nreceivers=160, nsenders=864
# difficulty=5 => 166.008407420888 sec, nreceivers=160, nsenders=864
# difficulty=6 => 166.008407420888 sec, nreceivers=160, nsenders=864
# difficulty=7 => 166.008407420888 sec, nreceivers=160, nsenders=864
# difficulty=8 => 166.008407420888 sec, nreceivers=160, nsenders=864
# difficulty=9 => 166.008407420888 sec, nreceivers=160, nsenders=864
# =============================================
# difficulty=0 => 2055.16355913191 sec, nreceivers=192, nsenders=832
# difficulty=1 => 1027.58177956596 sec, nreceivers=192, nsenders=832
# difficulty=2 => 513.790889782978 sec, nreceivers=192, nsenders=832
# difficulty=3 => 256.895444891489 sec, nreceivers=192, nsenders=832
# difficulty=4 => 172.393346167846 sec, nreceivers=192, nsenders=832
# difficulty=5 => 172.393346167846 sec, nreceivers=192, nsenders=832
# difficulty=6 => 172.393346167846 sec, nreceivers=192, nsenders=832
# difficulty=7 => 172.393346167846 sec, nreceivers=192, nsenders=832
# difficulty=8 => 172.393346167846 sec, nreceivers=192, nsenders=832
# difficulty=9 => 172.393346167846 sec, nreceivers=192, nsenders=832
# =============================================
# difficulty=0 => 1761.56876497021 sec, nreceivers=224, nsenders=800
# difficulty=1 => 880.784382485104 sec, nreceivers=224, nsenders=800
# difficulty=2 => 440.392191242552 sec, nreceivers=224, nsenders=800
# difficulty=3 => 220.196095621276 sec, nreceivers=224, nsenders=800
# difficulty=4 => 179.289080014559 sec, nreceivers=224, nsenders=800
# difficulty=5 => 179.289080014559 sec, nreceivers=224, nsenders=800
# difficulty=6 => 179.289080014559 sec, nreceivers=224, nsenders=800
# difficulty=7 => 179.289080014559 sec, nreceivers=224, nsenders=800
# difficulty=8 => 179.289080014559 sec, nreceivers=224, nsenders=800
# difficulty=9 => 179.289080014559 sec, nreceivers=224, nsenders=800
# =============================================
# difficulty=0 => 1541.37266934893 sec, nreceivers=256, nsenders=768
# difficulty=1 => 770.686334674466 sec, nreceivers=256, nsenders=768
# difficulty=2 => 385.343167337233 sec, nreceivers=256, nsenders=768
# difficulty=3 => 192.671583668617 sec, nreceivers=256, nsenders=768
# difficulty=4 => 186.759458348499 sec, nreceivers=256, nsenders=768
# difficulty=5 => 186.759458348499 sec, nreceivers=256, nsenders=768
# difficulty=6 => 186.759458348499 sec, nreceivers=256, nsenders=768
# difficulty=7 => 186.759458348499 sec, nreceivers=256, nsenders=768
# difficulty=8 => 186.759458348499 sec, nreceivers=256, nsenders=768
# difficulty=9 => 186.759458348499 sec, nreceivers=256, nsenders=768
# =============================================
# difficulty=0 => 1370.10903942127 sec, nreceivers=288, nsenders=736
# difficulty=1 => 685.054519710637 sec, nreceivers=288, nsenders=736
# difficulty=2 => 342.527259855318 sec, nreceivers=288, nsenders=736
# difficulty=3 => 194.879434798434 sec, nreceivers=288, nsenders=736
# difficulty=4 => 194.879434798434 sec, nreceivers=288, nsenders=736
# difficulty=5 => 194.879434798434 sec, nreceivers=288, nsenders=736
# difficulty=6 => 194.879434798434 sec, nreceivers=288, nsenders=736
# difficulty=7 => 194.879434798434 sec, nreceivers=288, nsenders=736
# difficulty=8 => 194.879434798434 sec, nreceivers=288, nsenders=736
# difficulty=9 => 194.879434798434 sec, nreceivers=288, nsenders=736
# =============================================
# difficulty=0 => 1233.09813547915 sec, nreceivers=320, nsenders=704
# difficulty=1 => 616.549067739573 sec, nreceivers=320, nsenders=704
# difficulty=2 => 308.274533869787 sec, nreceivers=320, nsenders=704
# difficulty=3 => 203.737590925636 sec, nreceivers=320, nsenders=704
# difficulty=4 => 203.737590925636 sec, nreceivers=320, nsenders=704
# difficulty=5 => 203.737590925636 sec, nreceivers=320, nsenders=704
# difficulty=6 => 203.737590925636 sec, nreceivers=320, nsenders=704
# difficulty=7 => 203.737590925636 sec, nreceivers=320, nsenders=704
# difficulty=8 => 203.737590925636 sec, nreceivers=320, nsenders=704
# difficulty=9 => 203.737590925636 sec, nreceivers=320, nsenders=704
# =============================================
# difficulty=0 => 1120.99830498104 sec, nreceivers=352, nsenders=672
# difficulty=1 => 560.499152490521 sec, nreceivers=352, nsenders=672
# difficulty=2 => 280.249576245260 sec, nreceivers=352, nsenders=672
# difficulty=3 => 213.439380969714 sec, nreceivers=352, nsenders=672
# difficulty=4 => 213.439380969714 sec, nreceivers=352, nsenders=672
# difficulty=5 => 213.439380969714 sec, nreceivers=352, nsenders=672
# difficulty=6 => 213.439380969714 sec, nreceivers=352, nsenders=672
# difficulty=7 => 213.439380969714 sec, nreceivers=352, nsenders=672
# difficulty=8 => 213.439380969714 sec, nreceivers=352, nsenders=672
# difficulty=9 => 213.439380969714 sec, nreceivers=352, nsenders=672
# =============================================
# difficulty=0 => 1027.58177956596 sec, nreceivers=384, nsenders=640
# difficulty=1 => 513.790889782978 sec, nreceivers=384, nsenders=640
# difficulty=2 => 256.895444891489 sec, nreceivers=384, nsenders=640
# difficulty=3 => 224.111350018199 sec, nreceivers=384, nsenders=640
# difficulty=4 => 224.111350018199 sec, nreceivers=384, nsenders=640
# difficulty=5 => 224.111350018199 sec, nreceivers=384, nsenders=640
# difficulty=6 => 224.111350018199 sec, nreceivers=384, nsenders=640
# difficulty=7 => 224.111350018199 sec, nreceivers=384, nsenders=640
# difficulty=8 => 224.111350018199 sec, nreceivers=384, nsenders=640
# difficulty=9 => 224.111350018199 sec, nreceivers=384, nsenders=640
# =============================================
# difficulty=0 => 948.537027291651 sec, nreceivers=416, nsenders=608
# difficulty=1 => 474.268513645825 sec, nreceivers=416, nsenders=608
# difficulty=2 => 237.134256822913 sec, nreceivers=416, nsenders=608
# difficulty=3 => 235.906684229683 sec, nreceivers=416, nsenders=608
# difficulty=4 => 235.906684229683 sec, nreceivers=416, nsenders=608
# difficulty=5 => 235.906684229683 sec, nreceivers=416, nsenders=608
# difficulty=6 => 235.906684229683 sec, nreceivers=416, nsenders=608
# difficulty=7 => 235.906684229683 sec, nreceivers=416, nsenders=608
# difficulty=8 => 235.906684229683 sec, nreceivers=416, nsenders=608
# difficulty=9 => 235.906684229683 sec, nreceivers=416, nsenders=608
# =============================================
# difficulty=0 => 880.784382485104 sec, nreceivers=448, nsenders=576
# difficulty=1 => 440.392191242552 sec, nreceivers=448, nsenders=576
# difficulty=2 => 249.012611131333 sec, nreceivers=448, nsenders=576
# difficulty=3 => 249.012611131333 sec, nreceivers=448, nsenders=576
# difficulty=4 => 249.012611131333 sec, nreceivers=448, nsenders=576
# difficulty=5 => 249.012611131333 sec, nreceivers=448, nsenders=576
# difficulty=6 => 249.012611131333 sec, nreceivers=448, nsenders=576
# difficulty=7 => 249.012611131333 sec, nreceivers=448, nsenders=576
# difficulty=8 => 249.012611131333 sec, nreceivers=448, nsenders=576
# difficulty=9 => 249.012611131333 sec, nreceivers=448, nsenders=576
# =============================================
# difficulty=0 => 822.065423652764 sec, nreceivers=480, nsenders=544
# difficulty=1 => 411.032711826382 sec, nreceivers=480, nsenders=544
# difficulty=2 => 263.660411786117 sec, nreceivers=480, nsenders=544
# difficulty=3 => 263.660411786117 sec, nreceivers=480, nsenders=544
# difficulty=4 => 263.660411786117 sec, nreceivers=480, nsenders=544
# difficulty=5 => 263.660411786117 sec, nreceivers=480, nsenders=544
# difficulty=6 => 263.660411786117 sec, nreceivers=480, nsenders=544
# difficulty=7 => 263.660411786117 sec, nreceivers=480, nsenders=544
# difficulty=8 => 263.660411786117 sec, nreceivers=480, nsenders=544
# difficulty=9 => 263.660411786117 sec, nreceivers=480, nsenders=544
# =============================================
# difficulty=0 => 770.686334674466 sec, nreceivers=512, nsenders=512
# difficulty=1 => 385.343167337233 sec, nreceivers=512, nsenders=512
# difficulty=2 => 280.139187522749 sec, nreceivers=512, nsenders=512
# difficulty=3 => 280.139187522749 sec, nreceivers=512, nsenders=512
# difficulty=4 => 280.139187522749 sec, nreceivers=512, nsenders=512
# difficulty=5 => 280.139187522749 sec, nreceivers=512, nsenders=512
# difficulty=6 => 280.139187522749 sec, nreceivers=512, nsenders=512
# difficulty=7 => 280.139187522749 sec, nreceivers=512, nsenders=512
# difficulty=8 => 280.139187522749 sec, nreceivers=512, nsenders=512
# difficulty=9 => 280.139187522749 sec, nreceivers=512, nsenders=512
# =============================================
# difficulty=0 => 725.351844399498 sec, nreceivers=544, nsenders=480
# difficulty=1 => 362.675922199749 sec, nreceivers=544, nsenders=480
# difficulty=2 => 298.815133357599 sec, nreceivers=544, nsenders=480
# difficulty=3 => 298.815133357599 sec, nreceivers=544, nsenders=480
# difficulty=4 => 298.815133357599 sec, nreceivers=544, nsenders=480
# difficulty=5 => 298.815133357599 sec, nreceivers=544, nsenders=480
# difficulty=6 => 298.815133357599 sec, nreceivers=544, nsenders=480
# difficulty=7 => 298.815133357599 sec, nreceivers=544, nsenders=480
# difficulty=8 => 298.815133357599 sec, nreceivers=544, nsenders=480
# difficulty=9 => 298.815133357599 sec, nreceivers=544, nsenders=480
# =============================================
# difficulty=0 => 685.054519710637 sec, nreceivers=576, nsenders=448
# difficulty=1 => 342.527259855318 sec, nreceivers=576, nsenders=448
# difficulty=2 => 320.159071454570 sec, nreceivers=576, nsenders=448
# difficulty=3 => 320.159071454570 sec, nreceivers=576, nsenders=448
# difficulty=4 => 320.159071454570 sec, nreceivers=576, nsenders=448
# difficulty=5 => 320.159071454570 sec, nreceivers=576, nsenders=448
# difficulty=6 => 320.159071454570 sec, nreceivers=576, nsenders=448
# difficulty=7 => 320.159071454570 sec, nreceivers=576, nsenders=448
# difficulty=8 => 320.159071454570 sec, nreceivers=576, nsenders=448
# difficulty=9 => 320.159071454570 sec, nreceivers=576, nsenders=448
# =============================================
# difficulty=0 => 648.999018673235 sec, nreceivers=608, nsenders=416
# difficulty=1 => 344.786692335691 sec, nreceivers=608, nsenders=416
# difficulty=2 => 344.786692335691 sec, nreceivers=608, nsenders=416
# difficulty=3 => 344.786692335691 sec, nreceivers=608, nsenders=416
# difficulty=4 => 344.786692335691 sec, nreceivers=608, nsenders=416
# difficulty=5 => 344.786692335691 sec, nreceivers=608, nsenders=416
# difficulty=6 => 344.786692335691 sec, nreceivers=608, nsenders=416
# difficulty=7 => 344.786692335691 sec, nreceivers=608, nsenders=416
# difficulty=8 => 344.786692335691 sec, nreceivers=608, nsenders=416
# difficulty=9 => 344.786692335691 sec, nreceivers=608, nsenders=416
# =============================================
# difficulty=0 => 616.549067739573 sec, nreceivers=640, nsenders=384
# difficulty=1 => 373.518916696999 sec, nreceivers=640, nsenders=384
# difficulty=2 => 373.518916696999 sec, nreceivers=640, nsenders=384
# difficulty=3 => 373.518916696999 sec, nreceivers=640, nsenders=384
# difficulty=4 => 373.518916696999 sec, nreceivers=640, nsenders=384
# difficulty=5 => 373.518916696999 sec, nreceivers=640, nsenders=384
# difficulty=6 => 373.518916696999 sec, nreceivers=640, nsenders=384
# difficulty=7 => 373.518916696999 sec, nreceivers=640, nsenders=384
# difficulty=8 => 373.518916696999 sec, nreceivers=640, nsenders=384
# difficulty=9 => 373.518916696999 sec, nreceivers=640, nsenders=384
# =============================================
# difficulty=0 => 587.189588323403 sec, nreceivers=672, nsenders=352
# difficulty=1 => 407.475181851271 sec, nreceivers=672, nsenders=352
# difficulty=2 => 407.475181851271 sec, nreceivers=672, nsenders=352
# difficulty=3 => 407.475181851271 sec, nreceivers=672, nsenders=352
# difficulty=4 => 407.475181851271 sec, nreceivers=672, nsenders=352
# difficulty=5 => 407.475181851271 sec, nreceivers=672, nsenders=352
# difficulty=6 => 407.475181851271 sec, nreceivers=672, nsenders=352
# difficulty=7 => 407.475181851271 sec, nreceivers=672, nsenders=352
# difficulty=8 => 407.475181851271 sec, nreceivers=672, nsenders=352
# difficulty=9 => 407.475181851271 sec, nreceivers=672, nsenders=352
# =============================================
# difficulty=0 => 560.499152490521 sec, nreceivers=704, nsenders=320
# difficulty=1 => 448.222700036399 sec, nreceivers=704, nsenders=320
# difficulty=2 => 448.222700036399 sec, nreceivers=704, nsenders=320
# difficulty=3 => 448.222700036399 sec, nreceivers=704, nsenders=320
# difficulty=4 => 448.222700036399 sec, nreceivers=704, nsenders=320
# difficulty=5 => 448.222700036399 sec, nreceivers=704, nsenders=320
# difficulty=6 => 448.222700036399 sec, nreceivers=704, nsenders=320
# difficulty=7 => 448.222700036399 sec, nreceivers=704, nsenders=320
# difficulty=8 => 448.222700036399 sec, nreceivers=704, nsenders=320
# difficulty=9 => 448.222700036399 sec, nreceivers=704, nsenders=320
# =============================================
# difficulty=0 => 536.129624121368 sec, nreceivers=736, nsenders=288
# difficulty=1 => 498.025222262665 sec, nreceivers=736, nsenders=288
# difficulty=2 => 498.025222262665 sec, nreceivers=736, nsenders=288
# difficulty=3 => 498.025222262665 sec, nreceivers=736, nsenders=288
# difficulty=4 => 498.025222262665 sec, nreceivers=736, nsenders=288
# difficulty=5 => 498.025222262665 sec, nreceivers=736, nsenders=288
# difficulty=6 => 498.025222262665 sec, nreceivers=736, nsenders=288
# difficulty=7 => 498.025222262665 sec, nreceivers=736, nsenders=288
# difficulty=8 => 498.025222262665 sec, nreceivers=736, nsenders=288
# difficulty=9 => 498.025222262665 sec, nreceivers=736, nsenders=288
# =============================================
# difficulty=0 => 560.278375045498 sec, nreceivers=768, nsenders=256
# difficulty=1 => 560.278375045498 sec, nreceivers=768, nsenders=256
# difficulty=2 => 560.278375045498 sec, nreceivers=768, nsenders=256
# difficulty=3 => 560.278375045498 sec, nreceivers=768, nsenders=256
# difficulty=4 => 560.278375045498 sec, nreceivers=768, nsenders=256
# difficulty=5 => 560.278375045498 sec, nreceivers=768, nsenders=256
# difficulty=6 => 560.278375045498 sec, nreceivers=768, nsenders=256
# difficulty=7 => 560.278375045498 sec, nreceivers=768, nsenders=256
# difficulty=8 => 560.278375045498 sec, nreceivers=768, nsenders=256
# difficulty=9 => 560.278375045498 sec, nreceivers=768, nsenders=256
# =============================================
# difficulty=0 => 640.318142909141 sec, nreceivers=800, nsenders=224
# difficulty=1 => 640.318142909141 sec, nreceivers=800, nsenders=224
# difficulty=2 => 640.318142909141 sec, nreceivers=800, nsenders=224
# difficulty=3 => 640.318142909141 sec, nreceivers=800, nsenders=224
# difficulty=4 => 640.318142909141 sec, nreceivers=800, nsenders=224
# difficulty=5 => 640.318142909141 sec, nreceivers=800, nsenders=224
# difficulty=6 => 640.318142909141 sec, nreceivers=800, nsenders=224
# difficulty=7 => 640.318142909141 sec, nreceivers=800, nsenders=224
# difficulty=8 => 640.318142909141 sec, nreceivers=800, nsenders=224
# difficulty=9 => 640.318142909141 sec, nreceivers=800, nsenders=224
# =============================================
# difficulty=0 => 747.037833393998 sec, nreceivers=832, nsenders=192
# difficulty=1 => 747.037833393998 sec, nreceivers=832, nsenders=192
# difficulty=2 => 747.037833393998 sec, nreceivers=832, nsenders=192
# difficulty=3 => 747.037833393998 sec, nreceivers=832, nsenders=192
# difficulty=4 => 747.037833393998 sec, nreceivers=832, nsenders=192
# difficulty=5 => 747.037833393998 sec, nreceivers=832, nsenders=192
# difficulty=6 => 747.037833393998 sec, nreceivers=832, nsenders=192
# difficulty=7 => 747.037833393998 sec, nreceivers=832, nsenders=192
# difficulty=8 => 747.037833393998 sec, nreceivers=832, nsenders=192
# difficulty=9 => 747.037833393998 sec, nreceivers=832, nsenders=192
# =============================================
# difficulty=0 => 896.445400072797 sec, nreceivers=864, nsenders=160
# difficulty=1 => 896.445400072797 sec, nreceivers=864, nsenders=160
# difficulty=2 => 896.445400072797 sec, nreceivers=864, nsenders=160
# difficulty=3 => 896.445400072797 sec, nreceivers=864, nsenders=160
# difficulty=4 => 896.445400072797 sec, nreceivers=864, nsenders=160
# difficulty=5 => 896.445400072797 sec, nreceivers=864, nsenders=160
# difficulty=6 => 896.445400072797 sec, nreceivers=864, nsenders=160
# difficulty=7 => 896.445400072797 sec, nreceivers=864, nsenders=160
# difficulty=8 => 896.445400072797 sec, nreceivers=864, nsenders=160
# difficulty=9 => 896.445400072797 sec, nreceivers=864, nsenders=160
# =============================================
# difficulty=0 => 1120.55675009100 sec, nreceivers=896, nsenders=128
# difficulty=1 => 1120.55675009100 sec, nreceivers=896, nsenders=128
# difficulty=2 => 1120.55675009100 sec, nreceivers=896, nsenders=128
# difficulty=3 => 1120.55675009100 sec, nreceivers=896, nsenders=128
# difficulty=4 => 1120.55675009100 sec, nreceivers=896, nsenders=128
# difficulty=5 => 1120.55675009100 sec, nreceivers=896, nsenders=128
# difficulty=6 => 1120.55675009100 sec, nreceivers=896, nsenders=128
# difficulty=7 => 1120.55675009100 sec, nreceivers=896, nsenders=128
# difficulty=8 => 1120.55675009100 sec, nreceivers=896, nsenders=128
# difficulty=9 => 1120.55675009100 sec, nreceivers=896, nsenders=128
# =============================================
# difficulty=0 => 1494.07566678800 sec, nreceivers=928, nsenders=96
# difficulty=1 => 1494.07566678800 sec, nreceivers=928, nsenders=96
# difficulty=2 => 1494.07566678800 sec, nreceivers=928, nsenders=96
# difficulty=3 => 1494.07566678800 sec, nreceivers=928, nsenders=96
# difficulty=4 => 1494.07566678800 sec, nreceivers=928, nsenders=96
# difficulty=5 => 1494.07566678800 sec, nreceivers=928, nsenders=96
# difficulty=6 => 1494.07566678800 sec, nreceivers=928, nsenders=96
# difficulty=7 => 1494.07566678800 sec, nreceivers=928, nsenders=96
# difficulty=8 => 1494.07566678800 sec, nreceivers=928, nsenders=96
# difficulty=9 => 1494.07566678800 sec, nreceivers=928, nsenders=96
# =============================================
# difficulty=0 => 2241.11350018199 sec, nreceivers=960, nsenders=64
# difficulty=1 => 2241.11350018199 sec, nreceivers=960, nsenders=64
# difficulty=2 => 2241.11350018199 sec, nreceivers=960, nsenders=64
# difficulty=3 => 2241.11350018199 sec, nreceivers=960, nsenders=64
# difficulty=4 => 2241.11350018199 sec, nreceivers=960, nsenders=64
# difficulty=5 => 2241.11350018199 sec, nreceivers=960, nsenders=64
# difficulty=6 => 2241.11350018199 sec, nreceivers=960, nsenders=64
# difficulty=7 => 2241.11350018199 sec, nreceivers=960, nsenders=64
# difficulty=8 => 2241.11350018199 sec, nreceivers=960, nsenders=64
# difficulty=9 => 2241.11350018199 sec, nreceivers=960, nsenders=64
# =============================================

# %%
def regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored):
    
    """ return number of seconds needed to regenerate the long message"""
    nsecs_sender = nhashes_stored / (nsenders*hashes_sec_core)
    nsecs_receiver = (nhashes_stored/(2**difficulty)) 
    nsecs_receiver = nsecs_receiver / (nreceivers*dict_add_sec)
    
    return max(nsecs_receiver, nsecs_sender)


def regen_msg_l(difficulty,
                nhashes_stored):
    """ return the max l can be constructed with difficulty """
    from math import log2
    
    return log2( (nhashes_stored/(2**difficulty)) )
    
def nqueries_sender(nsenders, hashes_sec_core, difficulty):
    """ Return how many queries senders can generate per second """

    return nsenders*hashes_sec_core/(2**difficulty)


def nqueries_receiver(nreceivers, dict_queries_sec):
    """
    Return how many queries receivers can make in a second
    """
    return nreceivers * dict_queries_sec

def phase_i_time(l, difficulty, hashes_sec_phase_i):
    """
    Return how many seconds it takes to complete phase_i
    """
    return 2^l * 2^difficulty / (hashes_sec_phase_i)


def largest_n(l,
              nsenders,
              nreceivers,
              dict_queries_sec,
              hashes_sec_core,
              difficulty,
              t_sec):

    """
    Given an attack parameter what is the largest n can be attacked in t_sec
    """
    from math import log2

    nqueries_sec = min(nqueries_sender(nsenders, hashes_sec_core, difficulty),
                   nqueries_receiver(nreceivers, dict_queries_sec))

    return log2(nqueries_sec*t_sec) + l + difficulty



def find_best_parameters(nservers,
              server_memory,
              ncores_per_server,
              nhashes_stored,
              dict_queries_sec,
              dict_add_sec,
              hashes_sec_core,
              hashes_sec_phase_i,
              t_sec,
              phase_i_timeout=365*24*60*60):
    """
    Find the attack parameters that can attack the largest possible n in t_sec
    return dictionary contains attack parameters.
    phase_i_timeout by default 365 days, since it can be done offline
    phase_ii_reconstruct_timeout 
    """

    from math import log2
    from itertools import product

    memory = nservers * server_memory
    val_size_bytes = 4 # one entry size in the dictionary
    filling_rate = 0.93 # how many slots of the dictionary are used
    l_max = log2(filling_rate * memory / val_size_bytes)

    ncores = nservers * ncores_per_server

    best_difficulty = 0
    best_n = 0 # optimize: find largest n
    best_nsenders = 0
    best_time_phase_i = float('inf')
    largest_difficulty = 40
    best_l = 0
    
    for nsenders, difficulty in product(range(1, ncores-nservers + 1), range(0, largest_difficulty)):
        nreceivers = ncores - nsenders
        l = min(l_max, regen_msg_l(difficulty, nhashes_stored))

        #print(f"l={l}, nsenders={nsenders}, difficulty={difficulty}, l_regen = {regen_msg_l( difficulty, nhashes_stored)}")
        t_rgen_msg = regen_msg_time(nsenders,
                                    nreceivers,
                                    hashes_sec_core,
                                    dict_add_sec,
                                    difficulty,
                                    nhashes_stored)
        
        t_sec_after_regen_msg = t_sec - t_rgen_msg
        if ( t_sec_after_regen_msg <= 0):
            continue # skip this iteration since all time have been spent on regenrating the long message
        
        
        n = largest_n(l,
                      nsenders,
                      nreceivers,
                      dict_queries_sec,
                      hashes_sec_core,
                      difficulty,
                      t_sec_after_regen_msg)


        # better n, always update
        t_phase_i = phase_i_time(l, difficulty, hashes_sec_phase_i)
        
        if (n > best_n  and t_phase_i <= phase_i_timeout):
            best_n = n
            best_l = l
            best_difficulty = difficulty
            best_nsenders = nsenders
            #print(f"better_n = {best_n}, better_l={best_l}, better_difficulty={best_difficulty}, better_nsenders={best_nsenders}, t_phase_i={seconds_2_time(t_phase_i)}")
            


    return {"n": best_n, "l": best_l,
            "difficulty": best_difficulty,
            "nsenders": best_nsenders,
            "nreceivers": ncores - nsenders}

# %%
# %%time
# best parameters
best_parms = find_best_parameters(nservers,
                     server_memory,
                     ncores_per_server,
                     nhashes_stored,
                     dict_queries_sec,
                     dict_add_sec,
                     hashes_sec_core,
                     hashes_sec_phase_i,
                     t_sec)

print(best_parms)

nsenders = best_parms["nsenders"]
nreceivers = best_parms["nreceivers"]
difficulty = best_parms["difficulty"]
l = best_parms["l"]
# Out:
# {'n': 0, 'l': 0, 'difficulty': 0, 'nsenders': 0, 'nreceivers': 8}
# CPU times: user 34.8 ms, sys: 0 ns, total: 34.8 ms
# Wall time: 34.1 ms

# %%
# how long phase_i will take using the best parameters?
seconds_2_time(phase_i_time(l, difficulty, hashes_sec_phase_i))
# Out:
# '0 days, 0 hours, 0 mins, 0 sec'

# %%
# how long regenerating the long message again will take?
seconds_2_time(regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 # how long regenerating the long message again will take?
# ----> 2 seconds_2_time(regen_msg_time(nsenders,
#       3                    nreceivers,
#       4                    hashes_sec_core,
#       5                    dict_add_sec,
#       6                    difficulty,
#       7                    nhashes_stored))
#
# Input In [2], in seconds_2_time(t)
#       9 from math import floor
#      11 t = float(t)
# ---> 12 days  = floor(t/(Integer(3600)*Integer(24)))
#      13 t = t - days*Integer(24)*Integer(3600)
#      15 hours = floor(t/Integer(3600))
#
# OverflowError: cannot convert float infinity to integer

# %%
from math import log2
dict_queries_sec = 2^22.963350
log2(33767312.397134)
