# %% [markdown]
# # Best attack parameters given a hardware
#
# We assume the attack parameters are $n$ and $l$. Also, denote $g$ to be the number of ignored bits.
#
# $p = \frac{2^l}{2^n}$ , this is a geometric random variable, thus we expect a collision after   $\#queries = \frac{2^n}{2^l} $
#
# Assume, we only accept digests that have certain number of zeros, denoted as $d$. Thus, we can pretend as we are working on small digests
# $$
# \begin{align}
# &\#queries = \frac{2^n}{2^l} \\
# &\#queries_{sec} \cdot t_{sec} = \frac{2^n}{2^l} \\
# \Rightarrow &n = log2\left(\#queries_{sec} \cdot t_{sec} \cdot 2^{n-l-d}  \right)
# \end{align}
# $$
#
#
# We have three point of views of $\#queries$
# - Senders: How many hashes they generate?
#     - Their speed will be affected by difficulty, but from their perspective the overall attack time doesn't change if the difficulty change (add explanation, later)
#     - $\#snd\_queries_{sec} = \frac{\#senders \cdot \#gen\_hashes_{sec}} {2^{d}}$
#
# - Receivers: How many hashes they can query the dicitonary.
#     - In their world, the higher the difficulty the better chance of hitting collision (since digests are technically shorter).
#     - $\#rcv\_queries_{sec} = \#receivers \cdot \#dict\_queries_{sec} $
#
# - Bandwith: This is how many hashes the network can carry in a second.
#     - From their perspective, difficulty reduces the rate of transmitted messages.
#     - $bdwth_queries_{sec} $
#
#
# Thus,
#
# $$\#queries_{sec} := min\left(snd\_queries_{sec}, rcv\_queries_{sec}, bdwth\_queries_{sec}\right)$$

# %%
# Numbers from Gros cluster, nancy, grid5000.fr
# find_dist overhead = 7%-9%
# hash_16x_avx (nancy: gros) ≈ 2^24.87hash/sec
# dict_add≈2^23.41 elm/sec
# dict_lookup ≈ 2^24.9337 elm/sec
# mpi_recv overhead = 10.71% (for regenerating message)


nservers = 124
server_memory = (96 - 20)*10^9 # 96 GB
ncores_per_server = 18
hashes_sec_core = 2^24.87
dict_queries_sec = 2^21.963350
t_sec =  2 * 24 * 3600
# how many hashes can oure compressed file 
nhashes_stored = 2^60
hashes_sec_phase_i = 2^24.72
dict_add_sec = 2^23.41

# %%
# 1 core hashing power
# thd2 sha_avx512_16way  elapsed 1.78sec i.e. 898392.92 hashes/sec = 2^19.777 hashes, 57.4971 M


# Querying 100000000, took 2.22 sec i.e. 44977939.99 elm/sec = 2^25.4227 elm/sec 


def seconds_2_time(t):
    from math import floor

    t = float(t)
    days  = floor(t/(3600*24))
    t = t - days*24*3600

    hours = floor(t/3600)
    t = t - hours*3600
    minutes = floor(t/60)
    t = t - minutes*60

    return f"{days} days, {hours} hours, {minutes} mins, {floor(t)} sec"

print(f"server_memory={server_memory}")
# Out:
# server_memory=76000000000

# %%
def regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored):
    """ return number of seconds needed to regenerate the long message"""
    nsecs_sender = nhashes_stored / (nsenders*hashes_sec_core)
    nsecs_receiver = (nhashes_stored/(2**difficulty)) 
    nsecs_receiver = nsecs_receiver / (nreceivers*dict_add_sec)
    
    return max(nsecs_receiver, nsecs_sender)


def regen_msg_l(difficulty,
                nhashes_stored):
    """ return the max l can be constructed with difficulty """
    from math import log2
    
    return log2( (nhashes_stored/(2**difficulty)) )
    
def nqueries_sender(nsenders, hashes_sec_core, difficulty):
    """ Return how many queries senders can generate per second """

    return nsenders*hashes_sec_core/(2**difficulty)


def nqueries_receiver(nreceivers, dict_queries_sec):
    """
    Return how many queries receivers can make in a second
    """
    return nreceivers * dict_queries_sec

def phase_i_time(l, difficulty, hashes_sec_phase_i):
    """
    Return how many seconds it takes to complete phase_i
    """
    return 2^l * 2^difficulty / (hashes_sec_phase_i)

# %%
regen_msg_time(1,
               1,
               hashes_sec_core,
               dict_add_sec,
               6,
               2^29)
# Out:
# 17.5086992201718

# %%
print("Regenerating the long message will take ... ")
from math import log2
nservers = 64
ncores_per_server = 18
for nreceivers in range(nservers, nservers*ncores_per_server - nservers, nservers):
    nsenders = (ncores_per_server)*nservers - nreceivers
    #nreceivers = 2*nservers
    for diff in range(10):

        time_needed = regen_msg_time(nsenders,
                                     nreceivers, # nsenders
                                     hashes_sec_core,
                                     dict_add_sec,
                                     diff, # difficulty
                                     2^(27+4+log2(nsenders)) # nhashes stored
                                    ) # 25 our experimented interval, 4 because sha2-16way, log2(nsenders) that how  we truncate the #states 

        print(f"difficulty={diff} => {time_needed} sec, nreceivers={nreceivers}, nsenders={nsenders}")
    print("=============================================")
# Out:
# Regenerating the long message will take ...
# difficulty=0 => 3275.41692236649 sec, nreceivers=64, nsenders=1088
# difficulty=1 => 1637.70846118324 sec, nreceivers=64, nsenders=1088
# difficulty=2 => 818.854230591622 sec, nreceivers=64, nsenders=1088
# difficulty=3 => 409.427115295811 sec, nreceivers=64, nsenders=1088
# difficulty=4 => 204.713557647906 sec, nreceivers=64, nsenders=1088
# difficulty=5 => 102.356778823953 sec, nreceivers=64, nsenders=1088
# difficulty=6 => 70.0347968806875 sec, nreceivers=64, nsenders=1088
# difficulty=7 => 70.0347968806875 sec, nreceivers=64, nsenders=1088
# difficulty=8 => 70.0347968806875 sec, nreceivers=64, nsenders=1088
# difficulty=9 => 70.0347968806875 sec, nreceivers=64, nsenders=1088
# =============================================
# difficulty=0 => 1541.37266934893 sec, nreceivers=128, nsenders=1024
# difficulty=1 => 770.686334674466 sec, nreceivers=128, nsenders=1024
# difficulty=2 => 385.343167337233 sec, nreceivers=128, nsenders=1024
# difficulty=3 => 192.671583668617 sec, nreceivers=128, nsenders=1024
# difficulty=4 => 96.3357918343083 sec, nreceivers=128, nsenders=1024
# difficulty=5 => 70.0347968806873 sec, nreceivers=128, nsenders=1024
# difficulty=6 => 70.0347968806873 sec, nreceivers=128, nsenders=1024
# difficulty=7 => 70.0347968806873 sec, nreceivers=128, nsenders=1024
# difficulty=8 => 70.0347968806873 sec, nreceivers=128, nsenders=1024
# difficulty=9 => 70.0347968806873 sec, nreceivers=128, nsenders=1024
# =============================================
# difficulty=0 => 963.357918343081 sec, nreceivers=192, nsenders=960
# difficulty=1 => 481.678959171541 sec, nreceivers=192, nsenders=960
# difficulty=2 => 240.839479585770 sec, nreceivers=192, nsenders=960
# difficulty=3 => 120.419739792885 sec, nreceivers=192, nsenders=960
# difficulty=4 => 70.0347968806872 sec, nreceivers=192, nsenders=960
# difficulty=5 => 70.0347968806872 sec, nreceivers=192, nsenders=960
# difficulty=6 => 70.0347968806872 sec, nreceivers=192, nsenders=960
# difficulty=7 => 70.0347968806872 sec, nreceivers=192, nsenders=960
# difficulty=8 => 70.0347968806872 sec, nreceivers=192, nsenders=960
# difficulty=9 => 70.0347968806872 sec, nreceivers=192, nsenders=960
# =============================================
# difficulty=0 => 674.350542840159 sec, nreceivers=256, nsenders=896
# difficulty=1 => 337.175271420079 sec, nreceivers=256, nsenders=896
# difficulty=2 => 168.587635710040 sec, nreceivers=256, nsenders=896
# difficulty=3 => 84.2938178550199 sec, nreceivers=256, nsenders=896
# difficulty=4 => 70.0347968806874 sec, nreceivers=256, nsenders=896
# difficulty=5 => 70.0347968806874 sec, nreceivers=256, nsenders=896
# difficulty=6 => 70.0347968806874 sec, nreceivers=256, nsenders=896
# difficulty=7 => 70.0347968806874 sec, nreceivers=256, nsenders=896
# difficulty=8 => 70.0347968806874 sec, nreceivers=256, nsenders=896
# difficulty=9 => 70.0347968806874 sec, nreceivers=256, nsenders=896
# =============================================
# difficulty=0 => 500.946117538403 sec, nreceivers=320, nsenders=832
# difficulty=1 => 250.473058769201 sec, nreceivers=320, nsenders=832
# difficulty=2 => 125.236529384601 sec, nreceivers=320, nsenders=832
# difficulty=3 => 70.0347968806872 sec, nreceivers=320, nsenders=832
# difficulty=4 => 70.0347968806872 sec, nreceivers=320, nsenders=832
# difficulty=5 => 70.0347968806872 sec, nreceivers=320, nsenders=832
# difficulty=6 => 70.0347968806872 sec, nreceivers=320, nsenders=832
# difficulty=7 => 70.0347968806872 sec, nreceivers=320, nsenders=832
# difficulty=8 => 70.0347968806872 sec, nreceivers=320, nsenders=832
# difficulty=9 => 70.0347968806872 sec, nreceivers=320, nsenders=832
# =============================================
# difficulty=0 => 385.343167337233 sec, nreceivers=384, nsenders=768
# difficulty=1 => 192.671583668616 sec, nreceivers=384, nsenders=768
# difficulty=2 => 96.3357918343082 sec, nreceivers=384, nsenders=768
# difficulty=3 => 70.0347968806872 sec, nreceivers=384, nsenders=768
# difficulty=4 => 70.0347968806872 sec, nreceivers=384, nsenders=768
# difficulty=5 => 70.0347968806872 sec, nreceivers=384, nsenders=768
# difficulty=6 => 70.0347968806872 sec, nreceivers=384, nsenders=768
# difficulty=7 => 70.0347968806872 sec, nreceivers=384, nsenders=768
# difficulty=8 => 70.0347968806872 sec, nreceivers=384, nsenders=768
# difficulty=9 => 70.0347968806872 sec, nreceivers=384, nsenders=768
# =============================================
# difficulty=0 => 302.769631479254 sec, nreceivers=448, nsenders=704
# difficulty=1 => 151.384815739627 sec, nreceivers=448, nsenders=704
# difficulty=2 => 75.6924078698136 sec, nreceivers=448, nsenders=704
# difficulty=3 => 70.0347968806872 sec, nreceivers=448, nsenders=704
# difficulty=4 => 70.0347968806872 sec, nreceivers=448, nsenders=704
# difficulty=5 => 70.0347968806872 sec, nreceivers=448, nsenders=704
# difficulty=6 => 70.0347968806872 sec, nreceivers=448, nsenders=704
# difficulty=7 => 70.0347968806872 sec, nreceivers=448, nsenders=704
# difficulty=8 => 70.0347968806872 sec, nreceivers=448, nsenders=704
# difficulty=9 => 70.0347968806872 sec, nreceivers=448, nsenders=704
# =============================================
# difficulty=0 => 240.839479585771 sec, nreceivers=512, nsenders=640
# difficulty=1 => 120.419739792885 sec, nreceivers=512, nsenders=640
# difficulty=2 => 70.0347968806873 sec, nreceivers=512, nsenders=640
# difficulty=3 => 70.0347968806873 sec, nreceivers=512, nsenders=640
# difficulty=4 => 70.0347968806873 sec, nreceivers=512, nsenders=640
# difficulty=5 => 70.0347968806873 sec, nreceivers=512, nsenders=640
# difficulty=6 => 70.0347968806873 sec, nreceivers=512, nsenders=640
# difficulty=7 => 70.0347968806873 sec, nreceivers=512, nsenders=640
# difficulty=8 => 70.0347968806873 sec, nreceivers=512, nsenders=640
# difficulty=9 => 70.0347968806873 sec, nreceivers=512, nsenders=640
# =============================================
# difficulty=0 => 192.671583668616 sec, nreceivers=576, nsenders=576
# difficulty=1 => 96.3357918343081 sec, nreceivers=576, nsenders=576
# difficulty=2 => 70.0347968806871 sec, nreceivers=576, nsenders=576
# difficulty=3 => 70.0347968806871 sec, nreceivers=576, nsenders=576
# difficulty=4 => 70.0347968806871 sec, nreceivers=576, nsenders=576
# difficulty=5 => 70.0347968806871 sec, nreceivers=576, nsenders=576
# difficulty=6 => 70.0347968806871 sec, nreceivers=576, nsenders=576
# difficulty=7 => 70.0347968806871 sec, nreceivers=576, nsenders=576
# difficulty=8 => 70.0347968806871 sec, nreceivers=576, nsenders=576
# difficulty=9 => 70.0347968806871 sec, nreceivers=576, nsenders=576
# =============================================
# difficulty=0 => 154.137266934893 sec, nreceivers=640, nsenders=512
# difficulty=1 => 77.0686334674466 sec, nreceivers=640, nsenders=512
# difficulty=2 => 70.0347968806873 sec, nreceivers=640, nsenders=512
# difficulty=3 => 70.0347968806873 sec, nreceivers=640, nsenders=512
# difficulty=4 => 70.0347968806873 sec, nreceivers=640, nsenders=512
# difficulty=5 => 70.0347968806873 sec, nreceivers=640, nsenders=512
# difficulty=6 => 70.0347968806873 sec, nreceivers=640, nsenders=512
# difficulty=7 => 70.0347968806873 sec, nreceivers=640, nsenders=512
# difficulty=8 => 70.0347968806873 sec, nreceivers=640, nsenders=512
# difficulty=9 => 70.0347968806873 sec, nreceivers=640, nsenders=512
# =============================================
# difficulty=0 => 122.609189607302 sec, nreceivers=704, nsenders=448
# difficulty=1 => 70.0347968806874 sec, nreceivers=704, nsenders=448
# difficulty=2 => 70.0347968806874 sec, nreceivers=704, nsenders=448
# difficulty=3 => 70.0347968806874 sec, nreceivers=704, nsenders=448
# difficulty=4 => 70.0347968806874 sec, nreceivers=704, nsenders=448
# difficulty=5 => 70.0347968806874 sec, nreceivers=704, nsenders=448
# difficulty=6 => 70.0347968806874 sec, nreceivers=704, nsenders=448
# difficulty=7 => 70.0347968806874 sec, nreceivers=704, nsenders=448
# difficulty=8 => 70.0347968806874 sec, nreceivers=704, nsenders=448
# difficulty=9 => 70.0347968806874 sec, nreceivers=704, nsenders=448
# =============================================
# difficulty=0 => 96.3357918343082 sec, nreceivers=768, nsenders=384
# difficulty=1 => 70.0347968806872 sec, nreceivers=768, nsenders=384
# difficulty=2 => 70.0347968806872 sec, nreceivers=768, nsenders=384
# difficulty=3 => 70.0347968806872 sec, nreceivers=768, nsenders=384
# difficulty=4 => 70.0347968806872 sec, nreceivers=768, nsenders=384
# difficulty=5 => 70.0347968806872 sec, nreceivers=768, nsenders=384
# difficulty=6 => 70.0347968806872 sec, nreceivers=768, nsenders=384
# difficulty=7 => 70.0347968806872 sec, nreceivers=768, nsenders=384
# difficulty=8 => 70.0347968806872 sec, nreceivers=768, nsenders=384
# difficulty=9 => 70.0347968806872 sec, nreceivers=768, nsenders=384
# =============================================
# difficulty=0 => 74.1044552571602 sec, nreceivers=832, nsenders=320
# difficulty=1 => 70.0347968806873 sec, nreceivers=832, nsenders=320
# difficulty=2 => 70.0347968806873 sec, nreceivers=832, nsenders=320
# difficulty=3 => 70.0347968806873 sec, nreceivers=832, nsenders=320
# difficulty=4 => 70.0347968806873 sec, nreceivers=832, nsenders=320
# difficulty=5 => 70.0347968806873 sec, nreceivers=832, nsenders=320
# difficulty=6 => 70.0347968806873 sec, nreceivers=832, nsenders=320
# difficulty=7 => 70.0347968806873 sec, nreceivers=832, nsenders=320
# difficulty=8 => 70.0347968806873 sec, nreceivers=832, nsenders=320
# difficulty=9 => 70.0347968806873 sec, nreceivers=832, nsenders=320
# =============================================
# difficulty=0 => 70.0347968806873 sec, nreceivers=896, nsenders=256
# difficulty=1 => 70.0347968806873 sec, nreceivers=896, nsenders=256
# difficulty=2 => 70.0347968806873 sec, nreceivers=896, nsenders=256
# difficulty=3 => 70.0347968806873 sec, nreceivers=896, nsenders=256
# difficulty=4 => 70.0347968806873 sec, nreceivers=896, nsenders=256
# difficulty=5 => 70.0347968806873 sec, nreceivers=896, nsenders=256
# difficulty=6 => 70.0347968806873 sec, nreceivers=896, nsenders=256
# difficulty=7 => 70.0347968806873 sec, nreceivers=896, nsenders=256
# difficulty=8 => 70.0347968806873 sec, nreceivers=896, nsenders=256
# difficulty=9 => 70.0347968806873 sec, nreceivers=896, nsenders=256
# =============================================
# difficulty=0 => 70.0347968806872 sec, nreceivers=960, nsenders=192
# difficulty=1 => 70.0347968806872 sec, nreceivers=960, nsenders=192
# difficulty=2 => 70.0347968806872 sec, nreceivers=960, nsenders=192
# difficulty=3 => 70.0347968806872 sec, nreceivers=960, nsenders=192
# difficulty=4 => 70.0347968806872 sec, nreceivers=960, nsenders=192
# difficulty=5 => 70.0347968806872 sec, nreceivers=960, nsenders=192
# difficulty=6 => 70.0347968806872 sec, nreceivers=960, nsenders=192
# difficulty=7 => 70.0347968806872 sec, nreceivers=960, nsenders=192
# difficulty=8 => 70.0347968806872 sec, nreceivers=960, nsenders=192
# difficulty=9 => 70.0347968806872 sec, nreceivers=960, nsenders=192
# =============================================
# difficulty=0 => 70.0347968806873 sec, nreceivers=1024, nsenders=128
# difficulty=1 => 70.0347968806873 sec, nreceivers=1024, nsenders=128
# difficulty=2 => 70.0347968806873 sec, nreceivers=1024, nsenders=128
# difficulty=3 => 70.0347968806873 sec, nreceivers=1024, nsenders=128
# difficulty=4 => 70.0347968806873 sec, nreceivers=1024, nsenders=128
# difficulty=5 => 70.0347968806873 sec, nreceivers=1024, nsenders=128
# difficulty=6 => 70.0347968806873 sec, nreceivers=1024, nsenders=128
# difficulty=7 => 70.0347968806873 sec, nreceivers=1024, nsenders=128
# difficulty=8 => 70.0347968806873 sec, nreceivers=1024, nsenders=128
# difficulty=9 => 70.0347968806873 sec, nreceivers=1024, nsenders=128
# =============================================

# %%
def regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored):
    
    """ return number of seconds needed to regenerate the long message"""
    nsecs_sender = nhashes_stored / (nsenders*hashes_sec_core)
    nsecs_receiver = (nhashes_stored/(2**difficulty)) 
    nsecs_receiver = nsecs_receiver / (nreceivers*dict_add_sec)
    
    return max(nsecs_receiver, nsecs_sender)


def regen_msg_l(difficulty,
                nhashes_stored):
    """ return the max l can be constructed with difficulty """
    from math import log2
    
    return log2( (nhashes_stored/(2**difficulty)) )
    
def nqueries_sender(nsenders, hashes_sec_core, difficulty):
    """ Return how many queries senders can generate per second """

    return nsenders*hashes_sec_core/(2**difficulty)


def nqueries_receiver(nreceivers, dict_queries_sec):
    """
    Return how many queries receivers can make in a second
    """
    return nreceivers * dict_queries_sec

def phase_i_time(l, difficulty, hashes_sec_phase_i):
    """
    Return how many seconds it takes to complete phase_i
    """
    return 2^l * 2^difficulty / (hashes_sec_phase_i)


def largest_n(l,
              nsenders,
              nreceivers,
              dict_queries_sec,
              hashes_sec_core,
              difficulty,
              t_sec):

    """
    Given an attack parameter what is the largest n can be attacked in t_sec
    """
    from math import log2

    nqueries_sec = min(nqueries_sender(nsenders, hashes_sec_core, difficulty),
                   nqueries_receiver(nreceivers, dict_queries_sec))

    return log2(nqueries_sec*t_sec) + l + difficulty



def find_best_parameters(nservers,
              server_memory,
              ncores_per_server,
              nhashes_stored,
              dict_queries_sec,
              dict_add_sec,
              hashes_sec_core,
              hashes_sec_phase_i,
              t_sec,
              phase_i_timeout=365*24*60*60):
    """
    Find the attack parameters that can attack the largest possible n in t_sec
    return dictionary contains attack parameters.
    phase_i_timeout by default 365 days, since it can be done offline
    phase_ii_reconstruct_timeout 
    """

    from math import log2
    from itertools import product

    memory = nservers * server_memory
    val_size_bytes = 4 # one entry size in the dictionary
    filling_rate = 0.93 # how many slots of the dictionary are used
    l_max = log2(filling_rate * memory / val_size_bytes)

    ncores = nservers * ncores_per_server

    best_difficulty = 0
    best_n = 0 # optimize: find largest n
    best_nsenders = 0
    best_time_phase_i = float('inf')
    largest_difficulty = 40
    best_l = 0
    
    for nsenders, difficulty in product(range(1, ncores-nservers + 1), range(0, largest_difficulty)):
        nreceivers = ncores - nsenders
        l = min(l_max, regen_msg_l(difficulty, nhashes_stored))

        #print(f"l={l}, nsenders={nsenders}, difficulty={difficulty}, l_regen = {regen_msg_l( difficulty, nhashes_stored)}")
        t_rgen_msg = regen_msg_time(nsenders,
                                    nreceivers,
                                    hashes_sec_core,
                                    dict_add_sec,
                                    difficulty,
                                    nhashes_stored)
        
        t_sec_after_regen_msg = t_sec - t_rgen_msg
        if ( t_sec_after_regen_msg <= 0):
            continue # skip this iteration since all time have been spent on regenrating the long message
        
        
        n = largest_n(l,
                      nsenders,
                      nreceivers,
                      dict_queries_sec,
                      hashes_sec_core,
                      difficulty,
                      t_sec_after_regen_msg)


        # better n, always update
        t_phase_i = phase_i_time(l, difficulty, hashes_sec_phase_i)
        
        if (n > best_n  and t_phase_i <= phase_i_timeout):
            best_n = n
            best_l = l
            best_difficulty = difficulty
            best_nsenders = nsenders
            #print(f"better_n = {best_n}, better_l={best_l}, better_difficulty={best_difficulty}, better_nsenders={best_nsenders}, t_phase_i={seconds_2_time(t_phase_i)}")
            


    return {"n": best_n, "l": best_l,
            "difficulty": best_difficulty,
            "nsenders": best_nsenders,
            "nreceivers": ncores - nsenders}

# %%
# %%time
# best parameters
best_parms = find_best_parameters(nservers,
                     server_memory,
                     ncores_per_server,
                     nhashes_stored,
                     dict_queries_sec,
                     dict_add_sec,
                     hashes_sec_core,
                     hashes_sec_phase_i,
                     t_sec)

print(best_parms)

nsenders = best_parms["nsenders"]
nreceivers = best_parms["nreceivers"]
difficulty = best_parms["difficulty"]
l = best_parms["l"]
# Out:
# {'n': 0, 'l': 0, 'difficulty': 0, 'nsenders': 0, 'nreceivers': 8}
# CPU times: user 34.8 ms, sys: 0 ns, total: 34.8 ms
# Wall time: 34.1 ms

# %%
# how long phase_i will take using the best parameters?
seconds_2_time(phase_i_time(l, difficulty, hashes_sec_phase_i))
# Out:
# '0 days, 0 hours, 0 mins, 0 sec'

# %%
# how long regenerating the long message again will take?
seconds_2_time(regen_msg_time(nsenders,
                   nreceivers,
                   hashes_sec_core,
                   dict_add_sec,
                   difficulty,
                   nhashes_stored))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 # how long regenerating the long message again will take?
# ----> 2 seconds_2_time(regen_msg_time(nsenders,
#       3                    nreceivers,
#       4                    hashes_sec_core,
#       5                    dict_add_sec,
#       6                    difficulty,
#       7                    nhashes_stored))
#
# Input In [2], in seconds_2_time(t)
#       9 from math import floor
#      11 t = float(t)
# ---> 12 days  = floor(t/(Integer(3600)*Integer(24)))
#      13 t = t - days*Integer(24)*Integer(3600)
#      15 hours = floor(t/Integer(3600))
#
# OverflowError: cannot convert float infinity to integer

# %%
from math import log2
dict_queries_sec = 2^22.963350
log2(33767312.397134)
